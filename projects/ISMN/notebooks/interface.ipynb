# %% [markdown]
# # Reading ISMN data (`ismn.interface.ISMN_Interface`)
# This example shows the basic functionality to read data downloaded from the International Soil Moisture Network (ISMN).
# Data for your study area can be selected and downloaded for free from <http://ismn.earth> after registration.

# %% [markdown]
# For this tutorial, data (all available variables) for ISMN networks 'REMEDHUS', 'SMOSMANIA', 'FMI', 'WEGENERNET', 'GTK', 'VAS' and 'RSMN' between 2009-08-04 and 2020-12-12 was downloaded from the ISMN website. Note that - depending on when you download the data  - available stations and measurement values can vary slightly from those shown in this example.
#
# <img src="ismn.png" style="height: 450px;"/>
#
# ISMN files are downloaded as a compressed `.zip` file after selecting the data from the website. You can extract it (with any zip software) locally into one (root) folder (in this case 'Data_separate_files'). The archive will be organised like this:
# ```shell
# Data_separate_files/
# ├── network/
# │   ├── station/
# │   │   ├── sensor.stm
# │   │   ├── sensor.stm
# │   │   ├── ...
# │   │   ├── sensor.stm
# │   │   ├── static_variables.csv
# │   ├── station/
# │   │   ├── ...
# ├── network/
# │   ├── ...
# ├── ISMN_qualityflags_description.txt
# ├── Metadata.xml
# ├── Provider_qualityflags_description.txt
# └── Readme.txt
# ```
# You can either read from this extracted root folder, or read from the .zip file directly (the reader will then unzip files temporarily when needed). Reading from zip is therefore slower than reading the extracted files. Extracted files are (much) larger than compressed files.

# %% [markdown]
# The class for reading data from extracted or compressed files is `ismn.interface.ISMN_Interface`. It provides functions to access single networks, stations and sensors and the measured time series for each sensor as well as metadata for each station/sensor.

# %% [markdown]
# `ISMN_Interface` expects the path to the downloaded and locally stored ISMN data (zip-file or extracted root folder) as the only required argument.

# %%
from ismn.interface import ISMN_Interface
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt  # matplotlib is not installed automatically
# %matplotlib inline

# Either a .zip file or one folder that contains all networks, here we read from .zip
data_path = Path('/Users/amfox/Desktop/ISMN_data')
ismn_data = ISMN_Interface(data_path, parallel=False)
# Out:
# Using the existing ismn metadata in /Users/amfox/Desktop/ISMN_data/python_metadata/ISMN_data.csv to set up ISMN_Interface.
# If there are issues with the data reader, you can remove the metadata csv file to repeat metadata collection.

# %% [markdown]
# The first time you initialize `ISMN_Interface` for a dataset, it will collect metadata for all sensors in your data collection from various files (this is **always** done for **all** available networks). The program will iterate through **all** files and collect information such as station names, sensor time coverage, measurement depths, landcover/climate classes, soil properties etc. for each sensor. Depending on the number of files and whether zipped/extracted files are used, this step can take a while. A log file is created in the displayed path. Parallel processing for this step can be activated manually by choosing `ISMN_Interface(data_path, parallel=True)` and will speed up metadata collection significantly. By default this step will create a folder called `python_metadata` (which contains the collected metadata as a `.csv` file) and place it inside the passed root directory. The next time the reader is created it will use `python_metadata` (if it is found) instead of generating it again (a different path to generate and search the metadata in can be passed via `ISMN_Interface(data_path, meta_path='/custom/meta/path')`.
#
# **Note: When changing the data (e.g. if you add or remove folders from the collection that is passed to the reader) make sure to delete the `python_metadata` folder and its content to force re-generating it. Otherwise data and metadata won't match anymore!!**

# %% [markdown]
# To limit reading to a selection of networks from the beginning (e.g. to load one network from a large collection, which is faster than loading all networks and then selecting one), their names can be passed to the reader (e.g. `ISMN_Interface(data_path, network=['REMEDHUS', 'SMOSMANIA'])`. Otherwise, all networks stored under the given path are loaded. Limiting the number of networks when calling the reader will result in faster initialization, because less files are loaded (this does **not** affect the one-time metadata collection, which is always done for all networks in `data_path`).

# %% [markdown]
# You can call `ISMN_Interface(data_path, keep_loaded_data=True)`, which will cause that all sensor time series - once read - are kept in memory for faster subsequent calls. This can fill up your memory and is only recommended for small data collections, respectively if only a few networks are initialized.
#
# Finally, you can define a custom temporary root folder, e.g. `ISMN_Interface(data_path, temp_root='/tmp/my_tempdata')`. By default this depends on your OS (e.g. `/tmp` for Linux), and is used by the reader to store some temporary files, e.g. when extracting while reading from `.zip`. The default `temp_root` is cleared automatically by your OS, so we recommend not to change this (unless necessary e.g. because of access restrictions).

# %% [markdown]
# ## ISMN Components (Overview)
# Here we give a short overview over the components that build a ISMN data set. Each component provides various functions to work with its data and access sub-components. See the python module docs for more details. This is just a basic overview of how to pick data out of the collection. In practice, it is often required to loop over certain stations. This is described later in this tutorial. The components (hierarchically ordered) are `NetworkCollection` <- `Network(s)` <- `Station(s)` <- `Sensor(s)`.

# %% [markdown]
# ### Collection
# The `ISMN_Interface` object holds all loaded networks (e.g. 'FMI', 'REMEDHUS', ...). Each Network contains multiple Stations (e.g. 'SAA111', 'SA112', ... for the 'FMI' network). Each Station contains multiple Sensors (names not shown in this overview). You can access Networks directly from the reader, and subsequently access Stations and their Sensors.

# %%
ismn_data
# Out:
# ismn.base.IsmnRoot Unzipped at /Users/amfox/Desktop/ISMN_data
# with Networks[Stations]:
# ------------------------
#   AACES: ['Farm01', 'Farm02', 'Farm03', 'Farm04', 'Farm06', 'Farm07', 'Farm08', 'Farm09', 'Farm10', 'Farm11', 'Farm12', 'Farm13', 'Farm14', 'Farm15', 'Farm16', 'Farm17', 'Farm18', 'Farm19', 'Farm20', 'Station01', 'Station02', 'Station05', 'Station06', 'Station07', 'Station08', 'Station09', 'Station10', 'Station11', 'Station12', 'Station13', 'Station14', 'Station15', 'Station16', 'Station17', 'Station18', 'Station19', 'Station20', 'Station25', 'Station26', 'Station27', 'Station28', 'Station29', 'Station30', 'Station31', 'Station32', 'Station34', 'Station36', 'Station37', 'Station39'],
#   AMMA-CATCH: ['Banizoumbou', 'Belefoungou-Mid', 'Belefoungou-Top', 'Nalohou-Mid', 'Nalohou-Top', 'Tondikiboro', 'Wankama'],
#   ARM: ['Anthony', 'Ashton', 'Byron', 'Coldwater', 'Cordell', 'Cyril', 'Earlsboro', 'ElReno', 'ElkFalls', 'Halstead', 'Hillsboro', 'Lamont-CF1', 'Lamont-CF2', 'Larned', 'LeRoy', 'MapleCity', 'Marshall', 'Medford', 'Meeker', 'Morris', 'Morrison', 'Newkirk', 'Okmulgee', 'Omega', 'Pawhuska', 'Pawnee', 'Plevna', 'Ringwood', 'Seminole', 'Towanda', 'Tryon', 'Tyro', 'ValleyFloor', 'Vici', 'Waukomis'],
#   AWDN: ['Ainsworth', 'AllianceWest', 'Arthur', 'Barta', 'Beatrice', 'BruleNorthTable', 'Brunswick', 'CedarPoint', 'CentralCity', 'Champion', 'ClayCenter(SC)', 'Concord(NE)', 'Cozad', 'Curtisunsta', 'Dickens', 'Elgin', 'Gordon', 'Gothenburg', 'GrandIsland', 'Gudmundsens', 'Halsey', 'HigginsRanch', 'Holdrege', 'Holdrege4N', 'IndianCaveStPark', 'Kearney', 'Lexington', 'Lincoln82E20S', 'McCook', 'Mead', 'MeadAgrofarm', 'Merna', 'Merritt', 'Minden', 'MitchellFarms', 'Monroe', 'NebraskaCity', 'NebraskaCity2N', 'Newport', 'NorthPlatte', 'ONeill', 'Ord', 'RedCloud', 'Scottsbluff', 'Shelton', 'Sidney', 'Smithfield', 'Sparks', 'WestPoint', 'York'],
#   BDF_Saxony: ['Hilbersdorf', 'Koellitsch', 'Lippen', 'Schmorren'],
#   BFG_Nw: ['BFG-Niederwerth-1-weighable'],
#   BIEBRZA_S-1: ['grassland-soil-1', 'grassland-soil-2', 'grassland-soil-3', 'grassland-soil-4', 'grassland-soil-5', 'grassland-soil-6', 'grassland-soil-7', 'grassland-soil-8', 'grassland-soil-9', 'marshland-soil-11', 'marshland-soil-12', 'marshland-soil-13', 'marshland-soil-14', 'marshland-soil-15', 'marshland-soil-16', 'marshland-soil-17', 'marshland-soil-18', 'marshland-soil-19', 'marshland-soil-21', 'marshland-soil-22', 'marshland-soil-23', 'marshland-soil-24', 'marshland-soil-25', 'marshland-soil-26', 'marshland-soil-27', 'marshland-soil-28', 'marshland-soil-29'],
#   BNZ-LTER: ['CRREL-Met', 'FP1A', 'FP2A', 'FP3A', 'FP4A', 'FP5A', 'HELMERS', 'LTER1', 'LTER2', 'UP1A', 'UP2A', 'UP3A'],
#   Berlin: ['DWDBerlin-Spaeth', 'DWDBerlinGlien', 'DWDBerlinMarx', 'DWDBerlinTempel', 'DWDmohrinerAllee', 'PSA14wiltinger', 'PSA15bucherchaus', 'PSA16krugwiesen', 'PSA17suedpark', 'PSA18Pfaueninsel', 'PSA1BerlinerStr', 'PSA2Tiergarten', 'PSA3Buergerpark', 'PSA4Heerstrasse', 'PSA5Sternenwarte', 'PSA6Plaenterwald', 'PSA7Ruebezahl', 'PSA8MueggelOst', 'PflABerlin10Schl', 'PflABerlin11Humb', 'PflABerlin12Schi', 'PflABerlin13Marz', 'PflABerlin9'],
#   CALABRIA: ['ChiaravalleCentrale', 'Fitterizzi', 'Mongrassano', 'Satriano', 'Torano'],
#   CAMPANIA: ['Bagnoli', 'Melizzano'],
#   CHINA: ['BAISE', 'BAOQING', 'BAYAN', 'BOLI', 'CHANGLIN', 'CHAOYANG', 'DUNHUA', 'FUYU', 'FUYU2', 'GUYUAN', 'HAERBIN', 'HAILUN', 'HAINONG', 'HUANXIAN', 'HULIN', 'HUMA', 'JIAMUSI', 'JIANPIN', 'JIAYIN', 'JINJIANG', 'JINXIAN', 'JINZHOU', 'LUSHI', 'NANCHONG', 'NANYANG', 'QINGGANG', 'SHACHE', 'SUXIAN', 'TIANSHUI', 'TONGWEI', 'TULUFAN', 'WULAWUSU', 'XIFENGZH', 'XILINGUO', 'XINMIN', 'XINXIAN', 'XUZHOU', 'YONGNING', 'ZHENJIA', 'ZHUMADIA'],
#   COSMOS: ['ARM-1', 'AustinCary', 'Baldry', 'Barrow-ARM', 'BaynesfieldProbe1', 'Beltsville', 'Biosphere', 'Bondville', 'Brookings', 'Bushland', 'CCPasture', 'CPTECINPE', 'CaribouBog', 'CathedralPeakC6', 'ChestnutRidgeNOAA', 'ChimneyMeadows', 'CoastalSageUCI', 'Coweeta', 'Daly', 'DanielForest', 'Derlo', 'DesertChaparralUCI', 'FlagPonderosaPine', 'FlagWildfire', 'FortPeck', 'Fox', 'FreemanRanch', 'GLEES', 'Gnangara', 'Gobabeb', 'GoodwinCreek', 'Griffith', 'HarvardForest', 'HauserFarmNorth', 'HauserFarmSouth', 'HavikpakMainMet', 'Hermosillo', 'Howland', 'IowaValidationSite', 'IslandDairy', 'JERC', 'Jonesboro', 'JornadaMixedShrubland', 'Juelich', 'KLEE', 'Kendall', 'Lichtenburgpotato', 'LowerSaltCreek', 'LuckyHills', 'ManitouForestGround', 'ManitouForestTower', 'Mapungubwe', 'MarshallColorado', 'Metolius', 'MineralBanks', 'MorganMonroe', 'MountLemmon', 'Mozark', 'MpalaNorth', 'NJMeadowlands', 'NamadgiNP', 'NebField3', 'Norwin', 'P301', 'ParkFalls', 'Pe-de-Gigante', 'Petzenkirchen', 'RanchoNoTengo', 'ReynoldsCreek', 'Rietholzbach', 'RobsonsCreek', 'RobsonsCreekDualTube', 'Rosemount', 'SMAP-OK', 'SanPedro', 'SantaFeWatershed-SF', 'SantaFeWatershed-SF1', 'SantaMariaUFSM', 'SantaRitaCriosote', 'SantaRitaMesquite', 'Saskatoon', 'SavannahRiver', 'SevilletaNewGrass', 'ShaleHills', 'SilverSword', 'Soaproot', 'Sterling', 'Temora', 'TenderfootCreek', 'TonziRanch', 'Toulouse', 'TowerRuin', 'TrailValleyForest', 'TrailValleyMainMet', 'TrailValleyUpperPlateau', 'Tullochgorum', 'Tumbarumba', 'TwoStreams', 'UMBS', 'UVA', 'VCNPCZO', 'Water4CropsBudrioIT', 'WeanyCreek', 'WindRiver', 'Yanco', 'YorkIrrigatedMaize', 'YorkIrrigatedSoybean', 'YorkRainfed'],
#   COSMOS-UK: ['AliceHolt', 'Balruddery', 'BickleyHall', 'BunnyPark', 'Cardington', 'ChimneyMeadows', 'ChobhamCommon', 'Cochno', 'CocklePark', 'Crichton', 'CwmGarw', 'EasterBush', 'Elmsett', 'Euston', 'Fincham', 'Fivemiletown', 'GisburnForest', 'Glensaugh', 'Glenwherry', 'Hadlow', 'HartwoodHome', 'HenfaesFarm', 'Heytesbury', 'Hillsborough', 'HollinHill', 'HolmeLacy', 'Loddington', 'LullingtonHeath', 'MoorHouse', 'MoretonMorrell', 'Morley', 'NorthWyke', 'Plynlimon', 'PortonDown', 'Redhill', 'Redmere', 'Riseholme', 'Rothamsted', 'Sheepdrove', 'Sourhope', 'SpenFarm', 'Stiperstones', 'Stoughton', 'Sydling', 'TheLizard', 'Waddesdon', 'Wimpole', 'Writtle', 'WythamWoods'],
#   CTP_SMTMN: ['L01', 'L02', 'L03', 'L04-M02', 'L05-M06', 'L06-M10', 'L07-M13', 'L08-M14', 'L09-M16', 'L10-M17', 'L11-M21', 'L12-M22', 'L13', 'L14', 'L15', 'L16', 'L17', 'L18', 'L19', 'L20', 'L21', 'L22', 'L23', 'L24', 'L25', 'L26', 'L27', 'L28', 'L29', 'L30', 'L31', 'L32', 'L33', 'L34', 'L35', 'L36', 'L37', 'L38', 'M01', 'M03', 'M04', 'M05', 'M07-S01', 'M08', 'M09', 'M11-S09', 'M12-S08', 'M15', 'M18', 'M19', 'M20', 'S02', 'S03', 'S04', 'S05', 'S06', 'S07'],
#   CW3E: ['BeaumontCherryValley', 'BoyesCreekCanyon', 'BrownsValleySchool', 'CarpenterRanch', 'Deerwood', 'Downieville', 'EtiwandaDownstream', 'FeatherRiverCollege', 'HeartKRanch', 'HellsDelightCanyon', 'HoweRanch', 'Ingram', 'KnottRanch', 'LowerElk', 'NorthCowMountain', 'Portola', 'PotterValleyCentral', 'PotterValleyNorth', 'RedwoodValleyPineview', 'SantaLuciaConservatory', 'SkylineHarvest', 'StagecoachSkiEast', 'WindyGap', 'YucaipaValley'],
#   DAHRA: ['DAHRA'],
#   DWD: ['Ahaus', 'Bad-Marienberg', 'Bamberg', 'Boltenhagen', 'Chieming', 'Elpersbuettel', 'Friesoythe-Altenoythe', 'Goettingen', 'Harzgerode', 'Hoyerswerda', 'Kyritz', 'Leutkirch-Herlazhofen', 'Putbus', 'Rheinstetten', 'Soltau', 'Stoetten', 'Tholey', 'Weihenstephan-Duernast', 'Wunsiedel-Schoenbrunn', 'Zinnwald-Georgenfeld'],
#   FLUXNET-AMERIFLUX: ['BouldinIslandAlfalfa', 'BouldinIslandcorn', 'ShermanBarn', 'ShermanIsland', 'TonziRanch', 'TwitchellAlfalfa', 'TwitchellCorn', 'VairaRanch'],
#   FMI: ['SAA111', 'SAA112', 'SAA120', 'SOD011', 'SOD012', 'SOD013', 'SOD021', 'SOD022', 'SOD023', 'SOD031', 'SOD032', 'SOD033', 'SOD071', 'SOD072', 'SOD073', 'SOD081', 'SOD082', 'SOD083', 'SOD091', 'SOD092', 'SOD093', 'SOD101', 'SOD102', 'SOD103', 'SOD130', 'SOD140', 'SODAWS'],
#   FR_Aqui: ['fraye', 'grandcal', 'hillan', 'hillan2', 'parcmeteo'],
#   GROW: ['06d7mhex', '0ednwhg5', '0j1g6k7t', '0rwqk7n9', '0wmxrc70', '17phaer1', '184b3mrn', '1e95h80r', '1jmz460j', '1ke3njhh', '228nf91g', '290hdmpp', '2k6s4hqy', '2t3ep8gm', '3en3xqb1', '3sh9gmem', '40nmrsbk', '43qrdbxw', '47emqp81', '4ajxh4nj', '4chmkpdz', '4ggvf18v', '4hpyyyb8', '4w257zzr', '54ggw8ft', '566xkgq2', '5h38tdbn', '5pga25ec', '5rfs4y7n', '5taprcx9', '5ybancsm', '611gphtp', '68x3rhdq', '6afsbt4v', '6h4czmce', '6jty48mq', '6rb2t5pm', '6sbmpr2j', '7a3s9ez1', '7ah00f8b', '7akdd5e0', '7n3gz2bx', '7pw547a1', '7swhp7rj', '812j972s', '89et815c', '8gbfyzmp', '8nqjvrj4', '8q7tddek', '9ay4ejtz', '9ggnsrj8', 'a1p061h6', 'abrx9sdz', 'aqq8yw1w', 'arftv7bp', 'bbb3wh9n', 'bch5cgrg', 'bf69cz0a', 'bf8nfx6h', 'br4tnkrw', 'c2kfmtgw', 'c4ngtxp2', 'c8w5a2z1', 'ev3r917w', 'f2ncka70', 'f6jyhzgf', 'f9aag2tj', 'fje20wzm', 'fr12jcsp', 'ft240mvk', 'fzyhgwdh', 'g068t0fs', 'gg7qkv4e', 'gq62d3j0', 'h1vm1t70', 'hfs5hee1', 'hpx5qr8g', 'hym3gxnd', 'j5ehdm60', 'jb8mtpya', 'jkwbxm5s', 'jp7adn80', 'jznfvpdc', 'khz98fgv', 'ktf8v2pz', 'm3kpc70z', 'm65ex1jn', 'm76jthbe', 'md233v7k', 'n4xrp1fz', 'n7z2r3cf', 'p18b77pa', 'p4pz2kd5', 'p9vbc55k', 'pcgwsq33', 'pvjvegpc', 'pwvxhaqg', 'q2gar4w5', 'q89fa24t', 'qfqdd9az', 'qjmrcyhx', 'qp90v9t5', 'r41d5090', 'rcqe7rwr', 'rtgyegn7', 's0bxcmmf', 'sb7kc01j', 'sbssctsn', 'sf7s18kj', 'sfjzwyse', 'sg467kvr', 'sqtxa0se', 'sxqnze7h', 't1st0pjc', 't35w59b3', 't640gc4e', 'tjvqp8t7', 'tyrxm6na', 'vfnfsmba', 'vqm6wfeb', 'vtchke83', 'vtpgs053', 'w2rjn3kx', 'w3sq2jh1', 'w5e4rdhq', 'wkwsdyhv', 'wm2pb36y', 'wv93jpfe', 'x9qxc7sm', 'xbysjrrr', 'xcsxg1wb', 'xffafcem', 'xjwzj2x0', 'xn67y732', 'xnnhbtpd', 'xs03cx4p', 'xy11zc8c', 'y09h8hsh', 'y0j3fw83', 'y2r6xsyq', 'y8errsyn', 'ybqaw0eb', 'yemnxdm9', 'yjdrr40m', 'yrh3tvvy', 'z11c6p67', 'z2yvnxry', 'z3eqrmk5', 'zj04kv3q', 'zmqpfs7f'],
#   GTK: ['Haapavesi', 'IlomantsiI', 'IlomantsiII', 'Kuusamo', 'PoriII', 'Sevettijaervi', 'Suomussalmi'],
#   HOAL: ['Hoal-01', 'Hoal-02', 'Hoal-04', 'Hoal-05', 'Hoal-06', 'Hoal-07', 'Hoal-08', 'Hoal-09', 'Hoal-10', 'Hoal-11', 'Hoal-12', 'Hoal-13', 'Hoal-14', 'Hoal-15', 'Hoal-16', 'Hoal-17', 'Hoal-18', 'Hoal-19', 'Hoal-21', 'Hoal-22', 'Hoal-23', 'Hoal-24', 'Hoal-25', 'Hoal-26', 'Hoal-27', 'Hoal-28', 'Hoal-29', 'Hoal-30', 'Hoal-32', 'Hoal-33', 'Hoal-34', 'Hoal-35', 'Hoal-36'],
#   HOBE: ['1.01', '1.02', '1.03', '1.04', '1.05', '1.06', '1.07', '1.08', '1.09', '1.10', '2.01', '2.02', '2.03', '2.04', '2.05', '2.06', '2.06b', '2.07', '2.08', '2.08b', '2.09', '2.10', '2.11', '3.01', '3.02', '3.03', '3.04', '3.05', '3.06', '3.07', '3.08', '3.09'],
#   HSC_SEOLMACHEON: ['Seolmacheon'],
#   HYDROL-NET_PERUGIA: ['Water-Engineering-Experimental-Field-1', 'Water-Engineering-Experimental-Field-2'],
#   HiWATER_EHWSN: ['BD-0002', 'BD-0003', 'BD-0004', 'BD-0005', 'BD-0006', 'BD-0007', 'BD-0010', 'BD-0011', 'BD-0014', 'BD-0015', 'BD-0016', 'BD-0017', 'BD-0018', 'BD-0019', 'BD-0020', 'BD-0021', 'BD-0022', 'BD-0024', 'BD-0028', 'BD-0029', 'BD-0030', 'BD-0032', 'BD-0034', 'BD-0035', 'BD-0036', 'BD-0037', 'BD-0038', 'BD-0039', 'BD-0040', 'BD-0041', 'BD-0043', 'BD-0045', 'BD-0046', 'BD-0048', 'BD-0049', 'HD-0001', 'HD-0002', 'HD-0003', 'HD-0004', 'HD-0006', 'HD-0007', 'HD-0009', 'HD-0010', 'HD-0011', 'HD-0012', 'HD-0014', 'HD-0015', 'HD-0016', 'HD-0017', 'HD-0018', 'HD-0020', 'HD-0022', 'HD-0024', 'HD-0026', 'HD-0028', 'HD-0029', 'HD-0031', 'HD-0033', 'HD-0034', 'HD-0036', 'HD-0038', 'HD-0039', 'HD-0042', 'HD-0044', 'HD-0045', 'HD-0046', 'HD-0048', 'HD-0051', 'HD-0054', 'HD-0056', 'HD-0057', 'HD-0058', 'HD-0059', 'SoilNET-001', 'SoilNET-002', 'SoilNET-003', 'SoilNET-004', 'SoilNET-005', 'SoilNET-006', 'SoilNET-007', 'SoilNET-008', 'SoilNET-009', 'SoilNET-010', 'SoilNET-011', 'SoilNET-012', 'SoilNET-013', 'SoilNET-014', 'SoilNET-015', 'SoilNET-016', 'SoilNET-017', 'SoilNET-018', 'SoilNET-019', 'SoilNET-020', 'SoilNET-021', 'SoilNET-022', 'SoilNET-023', 'SoilNET-024', 'SoilNET-025', 'SoilNET-026', 'SoilNET-027', 'SoilNET-028', 'SoilNET-029', 'SoilNET-030', 'SoilNET-031', 'SoilNET-032', 'SoilNET-033', 'SoilNET-034', 'SoilNET-035', 'SoilNET-036', 'SoilNET-037', 'SoilNET-038', 'SoilNET-039', 'SoilNET-040', 'SoilNET-041', 'SoilNET-042', 'SoilNET-043', 'SoilNET-044', 'SoilNET-045', 'SoilNET-046', 'SoilNET-047', 'SoilNET-048', 'SoilNET-049', 'SoilNET-050', 'SoilNET-051', 'WATERNET-01', 'WATERNET-02', 'WATERNET-03', 'WATERNET-04', 'WATERNET-06', 'WATERNET-07', 'WATERNET-10', 'WATERNET-12', 'WATERNET-14', 'WATERNET-15', 'WATERNET-16', 'WATERNET-17', 'WATERNET-18', 'WATERNET-19', 'WATERNET-20', 'WATERNET-21', 'WATERNET-22', 'WATERNET-23', 'WATERNET-24', 'WATERNET-25', 'WATERNET-26', 'WATERNET-27', 'WATERNET-28', 'WATERNET-29', 'WATERNET-30', 'WATERNET-31', 'WATERNET-32', 'WATERNET-33', 'WATERNET-34', 'WATERNET-35', 'WATERNET-36', 'WATERNET-37', 'WATERNET-38', 'WATERNET-39', 'WATERNET-40', 'WATERNET-41', 'WATERNET-42', 'WATERNET-43', 'WATERNET-44', 'WATERNET-45', 'WATERNET-46', 'WATERNET-47', 'WATERNET-48', 'WATERNET-49', 'WATERNET-50', 'WATERNET-51', 'WATERNET-52', 'WATERNET-53', 'WATERNET-54', 'WATERNET-55'],
#   ICN: ['Belleville', 'Bondville', 'Brownstown', 'Carbondale', 'Champaign', 'DeKalb', 'DixonSprings-Bare', 'DixonSprings-Grass', 'Fairfield', 'Freeport', 'Monmouth', 'OakRun', 'Olney', 'OrrCenter(Perry)', 'Peoria', 'RendLake(Ina)', 'Springfield', 'Stelle', 'Topeka'],
#   IIT_KANPUR: ['IITK-Airstrip'],
#   IMA_CAN1: ['station1', 'station10', 'station11', 'station12', 'station2', 'station3', 'station4', 'station5', 'station6', 'station7', 'station8', 'station9'],
#   IOWA: ['W2-1', 'W2-3', 'W2-4', 'W3-11', 'W3-14', 'W3-16'],
#   IPE: ['Aguero', 'Penaflor'],
#   KHOREZM: ['Station1', 'Station2', 'Station3', 'Station4', 'Station5', 'Station6', 'Station7'],
#   KIHS_CMC: ['Cheongmicheon-A1', 'Cheongmicheon-A2', 'Cheongmicheon-A3', 'Cheongmicheon-A4', 'Cheongmicheon-A5', 'Cheongmicheon-A6', 'Cheongmicheon-A7', 'Cheongmicheon-A8', 'Cheongmicheon-A9', 'Cheongmicheon-B1', 'Cheongmicheon-B2', 'Cheongmicheon-C1', 'Cheongmicheon-C2', 'Cheongmicheon-C3', 'Cheongmicheon-D1', 'Cheongmicheon-D2', 'Cheongmicheon-D3', 'Cheongmicheon-D4'],
#   KIHS_SMC: ['Seolmacheon-A1', 'Seolmacheon-A2', 'Seolmacheon-A3', 'Seolmacheon-A4', 'Seolmacheon-A5', 'Seolmacheon-A6', 'Seolmacheon-A6a', 'Seolmacheon-A7', 'Seolmacheon-B1', 'Seolmacheon-B2', 'Seolmacheon-B3', 'Seolmacheon-B4', 'Seolmacheon-B5', 'Seolmacheon-B6', 'Seolmacheon-B8', 'Seolmacheon-C1', 'Seolmacheon-C2', 'Seolmacheon-C5', 'Seolmacheon-C6'],
#   LAB-net: ['ChamonateCalibrationSite', 'NirehuaoSite', 'OromoCalibrationSite', 'SanPedroCalibrationSite'],
#   LABFLUX: ['Bussolenobosco', 'Bussolenoprato', 'Cogne', 'Nivolet'],
#   MAQU: ['CST-01', 'CST-02', 'CST-03', 'CST-04', 'CST-05', 'NST-01', 'NST-02', 'NST-03', 'NST-04', 'NST-05', 'NST-06', 'NST-07', 'NST-08', 'NST-09', 'NST-10', 'NST-11', 'NST-12', 'NST-13', 'NST-14', 'NST-15', 'NST-21', 'NST-22', 'NST-24', 'NST-25', 'NST-30', 'NST-31', 'NST-32'],
#   METEROBS: ['MontePino'],
#   MOL-RAO: ['Falkenberg', 'Kehrigk'],
#   MONGOLIA: ['Altai', 'Arvaikheer', 'Baitag', 'Baruun-urt', 'Baruunkharaa', 'Baruunturuun', 'Bayankhongor', 'Binder', 'Bogd', 'Bulgan', 'Choibalsan', 'Dalandzadgad', 'Darkhan', 'DarkhanII', 'Erdenesant', 'Eroo', 'Jargalant', 'Khalkhgol', 'KhalkhgolII', 'Kharkhorin', 'Khovd', 'Khutag-under', 'Khutagundur', 'Mandalgovi', 'Murun', 'Orkhon', 'Saikhan', 'Sainshand', 'Tarialan', 'TarialanII', 'Tosontsengel', 'Tsagaan-Ovoo', 'Tsagaannuur', 'Tsetserleg', 'Ugtaal', 'UgtaalII', 'Ulaistai', 'Ulgii', 'Undurkhaan', 'UndurkhaanII', 'Zuunburen', 'Zuunkharaa', 'Zuunmod'],
#   MySMNet: ['MARDI-L1', 'MARDI-L2', 'MARDI-L4', 'MPOB-BL1', 'MPOB-BL2', 'MPOB2012', 'MPOB401'],
#   NAQU: ['NQ01', 'NQ02', 'NQ03', 'NQ04', 'NQBJ', 'NQEast', 'NQKema', 'NQMS', 'NQNorth', 'NQSouth', 'NQWest'],
#   NGARI: ['ALI01', 'ALI02', 'ALI03', 'SQ01', 'SQ02', 'SQ03', 'SQ04', 'SQ05', 'SQ06', 'SQ07', 'SQ08', 'SQ09', 'SQ10', 'SQ11', 'SQ12', 'SQ13', 'SQ14', 'SQ16', 'SQ17', 'SQ18', 'SQ19', 'SQ20', 'SQ21'],
#   NVE: ['156.63.3Lappsaetra', '16.233.0Groset', '2.715.2Kvarstadseter', '2.725.0Abrahamsvoll', '2.727.0Kise', '28.13.0Saerheim', '5.7.0As'],
#   ORACLE: ['BOISSY', 'CERNEUX', 'CHEVRU', 'ESTERNAY', 'SUIZY', 'VOULTON'],
#   OZNET: ['Alabama', 'Balranald-Bolton-Park', 'Banandra', 'Benwerrin', 'Bundure', 'Canberra-Airport', 'Cheverelis', 'Cooma-Airfield', 'Cootamundra-Aerodrome', 'Cox', 'Crawford', 'Dry-Lake', 'Eulo', 'Evergreen', 'Ginninderra-K4', 'Ginninderra-K5', 'Griffith-Aerodrome', 'Hay-AWS', 'Keenan', 'Kyeamba-Downs', 'Kyeamba-Mouth', 'Kyeamba-Station', 'Rochedale', 'S-Coleambally', 'Samarra', 'Silver-Springs', 'Spring-Bank', 'Strathvale', 'Uri-Park', 'Waitara', 'Weeroona', 'West-Wyalong-Airfield', 'Widgiewa', 'Wollumbi', 'Wynella', 'Yamma-Road', 'Yammacoona', 'Yanco-Research-Station'],
#   PBO_H2O: ['AKRONARPT', 'ALKALILAKE', 'ANGELFIRE', 'ANGUS-PROP', 'ANTIMONYFL', 'ARKANSACRK', 'ARMINGTON', 'ATOMICCITY', 'AUBREYPEAK', 'AVILARANCH', 'BAKERCITY', 'BANDONARPT', 'BILLINGSAP', 'BIRCHIMCYN', 'BITTERWATR', 'BKAP-SCGN', 'BLACKROCK', 'BLINDSPRIN', 'BROTHERSDT', 'BUCKLEYFLT', 'BUCKSKINMT', 'BUTTERBRED', 'BUZZARDRST', 'Bethlehem', 'CABOROJO', 'CALAVERAS', 'CALCITYAPT', 'CALCITYPLR', 'CALIVALLEY', 'CAMPELLIOT', 'CARRIZORAN', 'CERREJON', 'CERRILLOS', 'CHILEOFLAT', 'CLAYTONARP', 'CN02', 'CN07', 'COXCOMBMTN', 'CRRS-SCGN', 'CSCI-SCGN', 'CTDM-SCGN', 'DELANO-AIR', 'DELTAMUNI', 'DELVALLE', 'DRI-RENO', 'DRYMOUNTAI', 'ENNISFISH', 'EcRockStPkTX2012', 'FALLBROOK', 'FGST-SCGN', 'FORDRA087G', 'FOUNTGREEN', 'FREEMONTAP', 'GLRS-SCGN', 'GNPS-SCGN', 'GRANITEMTN', 'GRANITEPK', 'GRANTS', 'GRAPEVINE', 'HARTMTNNWR', 'HAYSPEAK', 'HILL72', 'HILLMRANCHM', 'HLFISLPARK', 'HLFSTORYRN', 'HNSLVALLY', 'HORSHEAVEN', 'HUNT-SCGN', 'HVYS-SCGN', 'IMPERIALSP', 'IMPS-SCGN', 'INDIANPEAK', 'JACKASSBUT', 'KAMASLLOYD', 'KEMMERERLF', 'KNOLLSWEST', 'LAKHENSHAW', 'LAMARARPT', 'LASTCHANCE', 'LITTLEBALD', 'LITTLELOST', 'MARSHALL', 'MARSHALL2', 'MASW-SCGN', 'MATADORRCH', 'MCDERMITT', 'MCDNLDWELL', 'MEDICINELG', 'MIDDLEGATE', 'MONTICELLO', 'MOONEYCYN', 'MORROCREEK', 'MORROWAIR', 'MT-GLEASON', 'Mafikeng', 'NDAP-SCGN', 'NEWCASTLE-1', 'NIPOMO', 'NOMODESTO', 'Newcastle-2', 'OWENSGORGE', 'Okla2', 'PARKINSONF', 'POINT-LOMA', 'PORTALESAP', 'QCY2-BARD', 'QUILLAYUT', 'RANDOLPHLL', 'RAWLINSWWT', 'REDKNOLLS', 'REIDHILLVW', 'RIFLE-GCL', 'ROSASCYN', 'SAGEVALLEY', 'SALMONFALL', 'SANPETEVAL', 'SCIA-SCGN', 'SDHL-SCGN', 'SEVILLETA#1', 'SEVILLETA#2', 'SHANIKO', 'SHOSHONERV', 'SIERRAARMY', 'SILVERLAKE', 'SISTERSHSL', 'SLAVENCYN', 'SMAPSITEA2', 'SMAPSITEC', 'SMAPSITED', 'SPARLINRCH', 'SPIDERROCK', 'SPRECKLESS', 'SPRINGCREK', 'SanSalvador', 'Solarvilla', 'Sutherland', 'TENSLEEPTR', 'TEPUSQUET', 'TRESPIEDRA', 'TUBA-CITY', 'Upington', 'VAUGHNPTRL', 'VERNONHILL', 'VIDALJUNCT', 'VIGUSBUTTE', 'VIMT-SCGN', 'VINAHELITK', 'WAGONMOUND', 'WANSHIP2', 'WHEATLAND', 'WHITEWATER', 'WICKSRANCH', 'WILBURLEVA', 'WOODLANDFM', 'WRIGHTSPT'],
#   PTSMN: ['Site-1', 'Site-10', 'Site-11', 'Site-12', 'Site-13', 'Site-14', 'Site-15', 'Site-16', 'Site-17', 'Site-18', 'Site-19', 'Site-2', 'Site-20', 'Site-3', 'Site-4', 'Site-5', 'Site-6', 'Site-7', 'Site-8', 'Site-9'],
#   REMEDHUS: ['Canizal', 'Carramedina', 'Carretoro', 'CasaGorrizo', 'CasaPeriles', 'ConcejodelMonte', 'ElCoto', 'ElTomillar', 'Granja-g', 'GranjaToresana', 'Guarena', 'Guarrati', 'LaAtalaya', 'LaCruzdeElias', 'LasArenas', 'LasBodegas', 'LasBrozas', 'LasEritas', 'LasTresRayas', 'LasVacas', 'LasVictorias', 'LlanosdelaBoveda', 'Paredinas', 'Zamarron'],
#   RISMA: ['CEF', 'MB1', 'MB10', 'MB11', 'MB12', 'MB13', 'MB2', 'MB3', 'MB4', 'MB5', 'MB6', 'MB7', 'MB8', 'MB9', 'ON2', 'ON3', 'ON4', 'ON5', 'ON6', 'SK1', 'SK2', 'SK3', 'SK4'],
#   ROMPS: ['AbramovGlacier', 'Asai', 'Ayvadzh', 'Baytik', 'GolubinGlacier', 'Kokomeren', 'Maidanak', 'Maydantal', 'Taragay'],
#   RSMN: ['Adamclisi', 'Alexandria', 'Bacles', 'Banloc', 'Barlad', 'Calarasi', 'ChisineuCris', 'Corugea', 'Cotnari', 'Darabani', 'Dej', 'Dumbraveni', 'Iasi', 'Oradea', 'RosioriideVede', 'SannicolauMare', 'SatuMare', 'Slatina', 'Slobozia', 'Tecuci'],
#   RU-ADDFerti: ['ru-lse-01', 'ru-lse-02', 'ru-lse-03', 'ru-lse-04', 'ru-lse-05', 'ru-lse-06', 'ru-lse-07', 'ru-lse-08', 'ru-lse-09', 'ru-lse-10', 'ru-lse-11', 'ru-lse-12', 'ru-lse-13', 'ru-lse-14', 'ru-lse-15', 'ru-lse-16', 'ru-lse-17', 'ru-lse-18', 'ru-lse-19', 'ru-lse-20', 'ru-lse-21', 'ru-lse-22', 'ru-lse-23', 'ru-lse-24', 'ru-lse-25', 'ru-lse-26', 'ru-lse-27', 'ru-lse-28', 'ru-lse-29', 'ru-lse-30'],
#   RUSWET-AGRO: ['A-Ata#1', 'A-Ata#2', 'AdygeyaRepublic', 'Aktubinsk', 'Altai#1', 'Altai#2', 'Andizhanskaya', 'Arkhangelskaya#1', 'Arkhangelskaya#2', 'Arkhangelskaya#3', 'Arkhangelskaya#4', 'Arkhangelskaya#5', 'Astrakhanskaya#1', 'Astrakhanskaya#2', 'Balkanskaya', 'Bashkirrepublic#1', 'Bashkirrepublic#2', 'Belgorodskaya#1', 'Belgorodskaya#2', 'Brestskaya#1', 'Brestskaya#2', 'Brjanskaya#1', 'Brjanskaya#2', 'Bukharskaya', 'Burjatia', 'Chechnja#1', 'Chechnja#2', 'Chelyabinsk#1', 'Chelyabinsk#2', 'Chimkent#1', 'Chimkent#2', 'Chita#1', 'Chita#2', 'ChukotskiAvtonomnyiOkrug', 'Chuvashskayarepublic#1', 'Chuvashskayarepublic#2', 'DagestanRepublic#1', 'DagestanRepublic#2', 'Dzambul#1', 'Dzambul#2', 'Dzhalal-Abadskaya', 'Dzhezkazg#1', 'Dzhezkazg#2', 'East-Kaza', 'Estonia#1', 'Estonia#2', 'Ferganskaya#1', 'Ferganskaya#2', 'Gbao', 'Gomelskaya#1', 'Gomelskaya#2', 'Grodnenskaya#1', 'Grodnenskaya#2', 'Gruzia#1', 'Gruzia#2', 'Gurjvskaya', 'IngushskayaRepublic#1', 'IngushskayaRepublic#2', 'Irkut#1', 'Irkut#2', 'Ivanovskaya#1', 'Ivanovskaya#2', 'Kabardino-Balkarskaya', 'Kaliningradskaya#1', 'Kaliningradskaya#2', 'Kalmkskaya#1', 'Kalmkskaya#2', 'Kaluzhskaya#1', 'Kaluzhskaya#2', 'Kara-Kalpakskaya', 'Karachaevo-CherkesskayaRepu#1', 'Karachaevo-CherkesskayaRepu#2', 'Karaganda', 'KarelskayaRepublic#1', 'KarelskayaRepublic#2', 'Kashkadarinskaya', 'Kemer#1', 'Kemer#2', 'Khorezmskaya', 'Kirov#1', 'Kirov#2', 'Kokchetav', 'KomiRepublic#1', 'KomiRepublic#2', 'Kostromskaya#1', 'Kostromskaya#2', 'Krasnodarskaya#1', 'Krasnodarskaya#2', 'Krasnoja#1', 'Krasnoja#2', 'KrasnojarskiKrai#1', 'KrasnojarskiKrai#2', 'Ksyl-Ordinskaya#1', 'Ksyl-Ordinskaya#2', 'Kurgan#1', 'Kurgan#2', 'Kurskaya#1', 'Kurskaya#2', 'Kustanaj#1', 'Kustanaj#2', 'Latvia#1', 'Latvia#2', 'Leningradskaya#1', 'Leningradskaya#2', 'Lipetskaya#1', 'Lipetskaya#2', 'Litva#1', 'Litva#2', 'Marirepublic#1', 'Marirepublic#2', 'Minskaya#1', 'Minskaya#2', 'Mogilevskaya#1', 'Mogilevskaya#2', 'Moldova#1', 'Moldova#2', 'Mordovskayarepublic#1', 'Mordovskayarepublic#2', 'Moscowskaya#1', 'Moscowskaya#2', 'Murmanskaya#1', 'Murmanskaya#2', 'N-Kazahst#1', 'N-Kazahst#2', 'Navojskaya', 'NizhniNovgorodskaya#1', 'NizhniNovgorodskaya#2', 'Novgorodskaya#1', 'Novgorodskaya#2', 'Novosibi#1', 'Novosibi#2', 'Odesskaya#1', 'Odesskaya#2', 'Omsk#1', 'Omsk#2', 'Orenburgskaya#1', 'Orenburgskaya#2', 'Orlovskaya#1', 'Orlovskaya#2', 'Oshskaya#1', 'Oshskaya#2', 'Pavlodar#1', 'Pavlodar#2', 'Penzenskaya#1', 'Penzenskaya#2', 'Permskaya#1', 'Permskaya#2', 'Pskovskaya#1', 'Pskovskaya#2', 'RajonyRepublicanPodcinenia#1', 'RajonyRepublicanPodcinenia#2', 'Rostovskaya#1', 'Rostovskaya#2', 'Ryazanskaya#1', 'Ryazanskaya#2', 'Sakha(Yakutia)Republic#1', 'Sakha(Yakutia)Republic#2', 'Sakha(Yakutia)Republic#3', 'Samarkandskaya', 'Samarskaya(Kujbyshevskaya)#1', 'Samarskaya(Kujbyshevskaya)#2', 'Saratovskaya#1', 'Saratovskaya#2', 'Semipalat#1', 'Semipalat#2', 'Severo-OsetinskayaRepublic', 'Smolenskaya#1', 'Smolenskaya#2', 'Stavropolskaya#1', 'Stavropolskaya#2', 'Sverdlovsk(Ekaterin.)#1', 'Sverdlovsk(Ekaterin.)#2', 'SyrdarinskayaO.', 'Talasskaya', 'Taldi-Ku#1', 'Taldi-Ku#2', 'Tambovskaya#1', 'Tambovskaya#2', 'Tatarrepublic#1', 'Tatarrepublic#2', 'Tomsk#1', 'Tomsk#2', 'Tselinogr', 'Tulskaya#1', 'Tulskaya#2', 'Tumen#1', 'Tumen#2', 'Turgaj#1', 'Turgaj#2', 'TuvaRepublic#1', 'TuvaRepublic#2', 'Tverskaya#1', 'Tverskaya#2', 'Tyumenskaya', 'Udmurtrepublic#1', 'Udmurtrepublic#2', 'Ulyanovskaya#1', 'Ulyanovskaya#2', 'Uralsk#1', 'Uralsk#2', 'Vitebskaya#1', 'Vitebskaya#2', 'Vladimirskaya#1', 'Vladimirskaya#2', 'Volgogradskaya#1', 'Volgogradskaya#2', 'Vologodskaya#1', 'Vologodskaya#2', 'Voronezhskaya#1', 'Voronezhskaya#2', 'Yaroslavskaya#1', 'Yaroslavskaya#2'],
#   RUSWET-GRASS: ['AGLOS', 'AIDARLY', 'AKALTYN,COTTON', 'AKSHA', 'ALMA-ATA,APPL.GA', 'ASHCHE-UZEK', 'AYAK-KUM', 'BAIKADAM', 'BAIRKUM', 'BARGUZIN', 'BARNAUL', 'BEINEU', 'BELOGORKA', 'BEZHETSK', 'BOGUCHANY', 'BOROGONTSY', 'BORZJA', 'BOZSU', 'BRYANSK', 'DMITRIEVKA', 'DUKEN', 'DZHANYBEK', 'ENA', 'ERSHOV', 'FURMANOVO', 'GALLYA-ARAL', 'GEORGIEVKA', 'GIGANT', 'GISSARSKAYA', 'IOLOTAN', 'IZHEVSK', 'KABANSK', 'KACHUG', 'KAILASTUY', 'KALMYKOVO', 'KAMYSHEVATSKAYA', 'KAPAK', 'KARGOPOL', 'KEMEROVO', 'KHABAROVSK,AGRO', 'KHAKASSKAYA,GMO', 'KHOMUTOVO', 'KONSTANTINOVKA', 'KORZHASAY', 'KOSTROMA', 'KRASNOARMEIKA', 'KRASNYTCHIKOY', 'KURGAN-TYUBE', 'KUSTANAI,AGRO', 'KYZAN', 'KYZYLSKAYA,GMO', 'KYZYLTCHA', 'MATCHA', 'MAZANOVO', 'MITCHURINSK,APPL.', 'MUKHORSHIBIR', 'MUYA', 'NAMSTY', 'NAZAROVO', 'NIKOLAEVSKOYE', 'NYURBA', 'NYUYA', 'OGURTSOVO', 'OLEKMINSK', 'OLONETS', 'OLOVYANNAYA', 'OMSK', 'OREL', 'PENZA', 'PETRINKA', 'PHALENKI', 'PHEDTCHENKO,COTTON', 'PHROLOVO', 'PLAVSK', 'POKROVSK', 'PSKOV', 'PUDOZH', 'RODNIKOVKA', 'ROIKA', 'ROSTOSHY', 'SAM', 'SANYJAKHTAT', 'SEMIKARAKORSK', 'SHARKOVSHCHINA', 'SHELOPUGINO', 'SHORTANDY', 'SLAVGOROD', 'SOLYANKA', 'SOSNOVKA', 'SOSNOVO-OZERSK', 'SUNTAR', 'SURSKOE', 'SVERDLOVSK,ISTOK', 'TASTY', 'TAUP', 'TCHAGLY', 'TCHEBENKI', 'TCHERNIGOVKA', 'TCHIMKENT,AGRO13', 'TCHISHMY', 'TCHITA,AGRO', 'TCHURAPTCHA', 'TEREKTY', 'TOLUBAY', 'TOMMOT', 'TOREY', 'TROITSKO-PECHERSKOE', 'TSYVILSK', 'TULUN', 'TURA', 'TYUMEN', 'ULETY', 'URALSK', 'UST-MAJA', 'UST-TSILMA', 'VASILEVITCHI1', 'VERKHNEVILYUISK', 'VOLOGDA,SEMENKOVO', 'VORONEZ', 'YAKUTSK,GMO', 'ZHETY-ZHOL'],
#   RUSWET-VALDAI: ['SinayaGnilka', 'Tayozhniy', 'Usadievskiy'],
#   Ru_CFR: ['Fyodorovskoyedrysprucestand', 'Fyodorovskoyewetsprucestand'],
#   SASMAS: ['BlueWrenPk', 'Brunbrae', 'Cullingral', 'Cumbo', 'Dales', 'Illogan', 'Kilwirrin', 'MaramPk', 'MerriwaPk', 'Midlothian', 'Nagoli', 'PembrokeSth', 'Roscommon', 'Widden'],
#   SCAN: ['AAMU-JTG', 'Abrams', 'AdamsRanch#1', 'Adobe', 'AlabamaHills', 'Alcalde', 'AlkaliMesa', 'AllenFarms', 'Ames', 'AshValley', 'BeasleyLake', 'Beaumont', 'BlueCreek', 'BodieHills', 'BraggFarm', 'BroadAcres', 'Buckhorn', 'BuffaloJump', 'BusbyFarm', 'Bushland#1', 'CMRBLTAR-MO', 'CPER', 'CacheJunction', 'CanyonLake', 'CarverFarm', 'CaveValley', 'CentraliaLake', 'Charkiln', 'CheckersCreek', 'ChickenRidge', 'ChimneyCreek', 'Circleville', 'CochoraRanch', 'Combate', 'ConradAgRc', 'CookFarmFieldD', 'Corozal', 'CrescentLake#1', 'Crossroads', 'Cullman-NAHRC', 'DeathValleyJct', 'DeeRiverRanch', 'DeepSprings', 'DesertCenter', 'Dexter', 'DoeRidge', 'EagleLake', 'Eastland', 'EastviewFarm', 'ElsberryPMC', 'Enterprise', 'Ephraim', 'ErosDataCenter', 'Essex', 'EvergladesARS', 'FordDryLake', 'FortAssiniboine#1', 'FortReno#1', 'Fortuna', 'FrenchGulch', 'Geneva#1', 'GlacialRidge', 'GoodwinCkPasture', 'GoodwinCkTimber', 'Goshute', 'Grantsville', 'GreenRiver', 'GrouseCreek', 'GuilarteForest', 'HalsCanyon', 'HarmsWay', 'Hodges', 'Holden', 'HubbardBrook', 'InnokoCamp', 'Isabela', 'IsbellFarms', 'JohnsonFarm', 'Jordan', 'JordanValleyCwma', 'JornadaExpRange', 'JournaganRanch', 'Kainaliu', 'KanaryagakCamp', 'KemoleGulch', 'Kingsville', 'KnoxCity', 'KoptisFarms', 'Ku-Nesa', 'Kukuihaele', 'KyleCanyon', 'LTSP', 'Lehman', 'Levelland', 'Lind#1', 'Lindsay', 'LittleRedFox', 'LittleRiver', 'Livingston-UWA', 'LosLunasPMC', 'LovellSummit', 'LovelockNNR', 'LowerMulchatna', 'LyeBrook', 'MahantangoCk', 'MammothCave', 'ManaHouse', 'Mandan#1', 'Manderfield', 'MarbleCreek', 'MaricaoForest', 'MarkTwainHS', 'MascomaRiver', 'Mason#1', 'Mayday', 'McAllisterFarm', 'MccrackenMesa', 'Milford', 'Miradero', 'Moccasin', 'MollyCaren#1', 'MonoclineRidge', 'MooseInc', 'Morgan', 'MorrisFarms', 'MountMansfield', 'MountainHome', 'MtVernon', 'NPiedmontArec', 'Nacogdoches', 'NaknekRiver', 'Nephi', 'NorthIssaquena', 'Nunn#1', 'Onward', 'OrchardRangeSite', 'Panguitch', 'ParkValley', 'PeeDee', 'PerdidoRivFarms', 'Perthshire', 'Phillipsburg', 'PineNut', 'PowderMill', 'PowellGardens', 'PrairieView#1', 'Price', 'Princeton#1', 'PuaAkala', 'PuuwaiRanch', 'Rancheria', 'ReeseCenter', 'ReynoldsHomestead', 'Riesel', 'RiverRoadFarms', 'RockSpringsPa', 'RogersFarm#1', 'Ruby', 'SanAngelo', 'SandHollow', 'SandyRidge', 'Schell-Osage', 'SchorGarden', 'Scott', 'SellersLake#1', 'Selma', 'Sevilleta', 'ShadowMtns', 'ShagbarkHills', 'ShawNatureReserve', 'Shenandoah', 'Sidney', 'SilverCity', 'SilverSword', 'SinkinForest', 'Spickard', 'SplitMountain', 'Spooky', 'StanleyFarm', 'Starkville', 'Stephenville', 'Stubblefield', 'SudduthFarms', 'SunleafNursery', 'TableMountain', 'Thoreau', 'Tidewater#1', 'TidewaterArec', 'TncFortBayou', 'Torrington#1', 'TroughSprings', 'TuleValley', 'Tunica', 'Tuskegee', 'TwinPinesConservationArea', 'UWPlatteville', 'Uapb-Earle', 'Uapb-LonokeFarm', 'Uapb-Marianna', 'UapbCampus-PB', 'UapbDewitt', 'UapbPointRemove', 'Unalakleet', 'UpperBethlehem', 'Uvalde', 'Vallecitos', 'Vance', 'Vermillion', 'Vernon', 'Violett', 'Wabeno#1', 'WaimeaPlain', 'Wakulla#1', 'WalnutGulch#1', 'Watkinsville#1', 'WearyLake', 'Wedowee', 'Weslaco', 'WestSummit', 'WillowWells', 'Wtars', 'YoumansFarm'],
#   SD_DEM: ['Demokeya'],
#   SKKU: ['SKKU-FDR1', 'SKKU-FDR10', 'SKKU-FDR2', 'SKKU-FDR3', 'SKKU-FDR4', 'SKKU-FDR5', 'SKKU-FDR6', 'SKKU-FDR7', 'SKKU-FDR8', 'SKKU-FDR9', 'SKKU-Jinwicheon-1', 'SKKU-Jinwicheon-2', 'SKKU-Jinwicheon-3', 'SKKU-Jinwicheon-4', 'SKKU-Jinwicheon-6'],
#   SMN-SDR: ['L1', 'L10', 'L11', 'L12', 'L13', 'L14', 'L2', 'L3', 'L4', 'L5', 'L6', 'L7', 'L8', 'L9', 'M1', 'M10', 'M11', 'M12', 'M2', 'M3', 'M4', 'M5', 'M6', 'M7', 'M8', 'M9', 'S1', 'S2', 'S3', 'S4', 'S5', 'S6', 'S7', 'S8'],
#   SMOSMANIA: ['Barnas', 'Berzeme', 'CabrieresdAvignon', 'Condom', 'CreondArmagnac', 'LaGrandCombe', 'Lahas', 'LezignanCorbieres', 'Mazan-Abbaye', 'Mejannes-le-Clap', 'Montaut', 'Mouthoumet', 'Narbonne', 'PeyrusseGrande', 'Pezenas', 'Pezenas-old', 'Prades-le-Lez', 'Sabres', 'SaintFelixdeLauragais', 'Savenes', 'Urgons', 'Villevielle'],
#   SNOTEL: ['AguaCanyon', 'AmericanCreek', 'AnchorRiverDivide', 'Aniak', 'AnnieSprings', 'ArapahoRidge', 'AtigunPass', 'AtlantaSummit', 'Atwater', 'BakerButte', 'BakerButteSmt', 'Baldy', 'BannerSummit', 'BarM', 'BearCanyon', 'BearCreek', 'BearRiverRS', 'BeaverDams', 'BeaverDivide', 'BeaverPass', 'BenLomondPeak', 'BenLomondTrail', 'BerryCreek', 'BerthoudSummit', 'BevansCabin', 'BigBend', 'BigCreekSum', 'BigFlat', 'BigGoose', 'BigMeadow', 'BigSandyOpening', 'BillieCreekDivide', 'BirdCreek', 'BlackBear', 'BlackFlat-U.M.Ck', 'BlackMesa', 'BlackPine', 'BlackhallMtn', 'BlacksForkJct', 'BlacktailMtn', 'BlazedAlder', 'BlueLakes', 'BobsHollow', 'BogusBasin', 'BoneSpringsDiv', 'BostetterR.S.', 'Bourne', 'BoxCreek', 'BoxSprings', 'BrackettCreek', 'BrianHead', 'Brighton', 'BristleconeTrail', 'BrooklynLake', 'BrownDuck', 'BrownTop', 'Brumley', 'BuckFlat', 'BuckPasture', 'BuckboardFlat', 'Buckinghorse', 'BuckskinJoe', 'BuckskinLower', 'BugLake', 'BurgessJunction', 'BurnsideLake', 'BurntMountain', 'BurroMountain', 'BurtsMillerRanch', 'Butte', 'CampJackson', 'CarsonPass', 'Cascade#2', 'CascadeMountain', 'CastleCreek', 'CastlePeak', 'CastleValley', 'CaveMountain', 'CayusePass', 'Chalender', 'ChalkCreek#1', 'ChalkCreek#2', 'ChapmanTunnel', 'ChemultAlternate', 'Chepeta', 'Chisana', 'ChocolateGulch', 'CinnabarPark', 'ClackamasLake', 'ClaytonSprings', 'ClearCreek#1', 'ClearCreek#2', 'ClearLake', 'CloverMeadow', 'CochetopaPass', 'Coldfoot', 'ColumbiaBasin', 'CopperMountain', 'CorduroyFlat', 'Corral', 'CorralCanyon', 'CouchSummit', 'CrabCreek', 'CraterMeadows', 'CrowCreek', 'CssLab', 'Culebra#2', 'CurrantCreek', 'Daniels-Strawberry', 'DefianceMines', 'Derr.', 'DiamondPeak', 'DillsCamp', 'DisasterPeak', 'Divide', 'DollarhideSummit', 'DomeLake', 'DonkeyReservoir', 'DorseyBasin', 'DrawCreek', 'DryBreadPond', 'DryCreek', 'DryFork', 'DryLake', 'EFBlacksForkGS', 'EagleSummit', 'EastRimDivide', 'EastWillowCreek', 'EbbettsPass', 'EchoPeak', 'ElkButte', 'ElkCabin', 'ElkPeak', 'ElkRidge', 'ElwoodPass', 'ExitGlacier', 'FallenLeaf', 'Farmington', 'FarmingtonLower', 'FarnsworthLake', 'FawnCreek', 'FieldingLake', 'Fifteenmile', 'FishLakeUtah', 'FisherCreek', 'FivePointsLake', 'FlattopMtn.', 'ForestdaleCreek', 'FortValley', 'FranklinBasin', 'FredonyerPeak', 'FremontPass', 'FryCanyon', 'GBRCHQ', 'GBRCMeadows', 'GalenaAK', 'GalenaSummit', 'GallegosPeak', 'GardenCitySummit', 'GardnerPeak', 'GaritaPeak', 'GeorgeCreek', 'Giveout', 'GobblersKnob', 'Golconda', 'GoldAxeCamp', 'GoldBasin', 'GooseberryRS', 'GooseberryRSUp', 'GrandTarghee', 'GraniteCreek', 'GraniteCrk', 'GranitePeak', 'GreenMountain', 'GrizzlyPeak', 'GrouseCamp', 'GulkanaRiver', 'GunsightPass', 'GutzPeak', 'HagansMeadow', 'HappyJack', 'Hardscrabble', 'HarrisFlat', 'HartsPass', 'HawleyLake', 'HaydenFork', 'HeavenlyValley', 'Hewinta', 'HickersonPark', 'HighLonesome', 'HighRidge', 'HiltsCreek', 'HobbleCreek', 'Hole-in-Mountain', 'Hole-in-Rock', 'HollandMeadows', 'Hoonah', 'HoosierPass', 'Hopewell', 'HorseMeadow', 'HorseRidge', 'HuntingtonHorse', 'Hyndman', 'ImnaviatCreek', 'IndependenceCamp', 'IndependenceCreek', 'IndependenceLake', 'IndianRock', 'IrishTaylor', 'IslandPark', 'JackCreekUpper', 'JackWadeJct', 'JacksPeak', 'JacksonPeak', 'JackwhackerGulch', 'JakesCreek', 'JonesCorral', 'JonesPass', 'Kalamazoo', 'KelleyR.S.', 'KellyStation', 'KenaiMoosePens', 'KilfoilCreek', 'Kiln', 'KimberlyMine', 'KingsCabin', 'KlondikeNarrows', 'Kolob', 'Lakefork#1', 'Lakefork#3', 'LakeforkBasin', 'LakeviewRidge', 'LamanceCreek', 'Lamoille#3', 'LamoilleUpper', 'LapreleCreek', 'LarsenCreek', 'LasalMountain', 'LasalMountain-Lower', 'LaurelDraw', 'LeavittLake', 'LeavittMeadows', 'LeeCanyon', 'LewisLakeDivide', 'LewisPeak', 'LightningRidge', 'LilyLake', 'LilyPond', 'LittleBear', 'LittleChenaRidge', 'LittleGoose', 'LittleGrassy', 'LittleSnakeRiver', 'LittleValley', 'LizardHeadPass', 'LobdellLake', 'LoneCone', 'LonesomeBeaver', 'LongDrawResv', 'LongFlat', 'LongValley', 'LongValleyJct', 'Lookout', 'LookoutPeak', 'LostCreekResv', 'LostDo ...
#   SOILSCAPE: ['Ararimu-2601', 'Ararimu-2602', 'Ararimu-2603', 'Ararimu-2604', 'Ararimu-2605', 'CO-Z1-2001', 'CO-Z1-2002', 'CO-Z1-2003', 'CO-Z1-2004', 'CO-Z4-2101', 'CO-Z4-2102', 'CO-Z4-2103', 'CO-Z4-2104', 'CO-Z4-2105', 'JR-1-2301', 'JR-1-2302', 'JR-1-2303', 'JR-1-2304', 'JR-2-2401', 'JR-2-2402', 'JR-2-2403', 'JR-2-2404', 'JR-2-2405', 'JR-3-2501', 'JR-3-2502', 'JR-3-2503', 'JR-3-2504', 'Kendall-1401', 'Kendall-1402', 'Kendall-1403', 'Kendall-1404', 'Kendall-1405', 'Kendall-1406', 'Kendall-1407', 'Kendall-1408', 'Kendall-1409', 'Lucky-Hills-1501', 'Lucky-Hills-1502', 'Lucky-Hills-1503', 'Lucky-Hills-1504', 'Lucky-Hills-1505', 'Lucky-Hills-1506', 'Lucky-Hills-1507', 'Riverhead-2703', 'Riverhead-2704', 'Riverhead-2705', 'Wharekapua-2801', 'Wharekapua-2802', 'Wharekapua-2803', 'Wharekapua-2804', 'Wharekapua-2805', 'node1000', 'node101', 'node1017', 'node1018', 'node1019', 'node102', 'node1020', 'node1021', 'node1022', 'node1023', 'node1024', 'node1025', 'node1026', 'node1027', 'node1028', 'node1029', 'node103', 'node1030', 'node1031', 'node104', 'node105', 'node106', 'node107', 'node108', 'node109', 'node110', 'node111', 'node112', 'node113', 'node114', 'node115', 'node116', 'node117', 'node118', 'node119', 'node120', 'node1201', 'node1202', 'node1204', 'node1205', 'node1206', 'node121', 'node1400', 'node1401', 'node1402', 'node1403', 'node1404', 'node1405', 'node1406', 'node1407', 'node1408', 'node1409', 'node1500', 'node1501', 'node1502', 'node1503', 'node1504', 'node1505', 'node1506', 'node1507', 'node200', 'node204', 'node207', 'node208', 'node210', 'node211', 'node214', 'node217', 'node219', 'node222', 'node230', 'node401', 'node402', 'node403', 'node404', 'node405', 'node406', 'node408', 'node409', 'node410', 'node411', 'node412', 'node413', 'node414', 'node415', 'node416', 'node417', 'node418', 'node419', 'node420', 'node501', 'node502', 'node503', 'node504', 'node505', 'node506', 'node507', 'node508', 'node509', 'node510', 'node511', 'node512', 'node513', 'node514', 'node515', 'node516', 'node517', 'node518', 'node701', 'node702', 'node703', 'node704', 'node705', 'node706', 'node707', 'node708', 'node709', 'node710', 'node711', 'node712', 'node713', 'node715', 'node801', 'node802', 'node803', 'node804', 'node805', 'node806', 'node807', 'node808', 'node809', 'node810', 'node811', 'node812', 'node813', 'node814', 'node815', 'node816', 'node817', 'node818', 'node819', 'node820', 'node821', 'node822', 'node824', 'node825', 'node827', 'node828', 'node900', 'node901', 'node902', 'node903', 'node904', 'node905', 'node906', 'node907', 'node908', 'node909', 'node910', 'node911', 'node912', 'node913', 'node914', 'node915', 'node916'],
#   SONTE-China: ['GuYuan-01', 'GuYuan-02', 'GuYuan-03', 'GuYuan-04', 'GuYuan-05', 'GuYuan-06', 'GuYuan-07', 'GuYuan-08', 'GuYuan-09', 'GuYuan-10', 'MinQin-01', 'MinQin-02', 'MinQin-03', 'MinQin-04', 'MinQin-05', 'MinQin-06', 'MinQin-07', 'MinQin-08', 'MinQin-09', 'MinQin-10'],
#   STEMS: ['CarpenetoConventionalTillageNoTrackposition', 'CarpenetoConventionalTillageTrackposition', 'CarpenetopermanentGrassCoverNoTrackposition', 'CarpenetopermanentGrassCoverTrackposition', 'RocchettaLigureConventionalGrassCoverNoTrackposition', 'RocchettaLigureConventionalGrassCoverTrackposition', 'RocchettaLigureConventionalUnder-rowposition', 'RocchettaLigureCoverCropNoTrackposition', 'RocchettaLigureInnovativeGrassCoverNoTrackposition', 'RocchettaLigureInnovativeGrassCoverTrackposition', 'RocchettaLigureInnovativeUnder-rowposition'],
#   SW-WHU: ['BaoxieBDS-RSoilMoisture', 'BaoxieWeatherSoilStation1', 'BaoxieWeatherSoilStation2', 'BaoxieWeatherStation', 'HZAUWeatherStation', 'ZiguiLandslideStation01', 'ZiguiLandslideStation02'],
#   SWEX_POLAND: ['MarshBubnow,Polesie', 'P1', 'P2', 'P3', 'P4', 'Trzebieszow,Podlasie'],
#   TAHMO: ['ApakopeKayove', 'AtebubuSHS,Atebubu', 'BaseTitaniumDam', 'BiaSHTSDebiso', 'BimbillaSHS,Bimbilla', 'BongoSHS,Bongo', 'BuiPowerAuthority,Bui', 'CRIG(SoilMoistureStation1)', 'CRIG(SoilMoistureStation2)', 'CSIR-SARI,Nyankpala-Tamale', 'CSIR-SARI,Tanina', 'CollegedeRushaki', 'CoteDIvoireMeteoOffice', 'DaffiamaSHS,Daffiama', 'DedanKimathiUniversityofTechnology', 'DwaEstate', 'ESKigoma', 'ESMibiliziA', 'ESNyange', 'FedPolyIle-Oluji', 'GSMarieReineRwanza', 'GSStPierreNkombo', 'GbewaaCollegeofEducation,Pusiga', 'GgabaDemonstrationPrimarySchool-KCCA', 'HanSHS,Han', 'IPRCMusanze', 'ImurtottPrimaryschool', 'IrbaanPrimary', 'JuabosoSHS', 'KNUSTFarm,Kumasi', 'KajajiSHS,Kajaji', 'KenyaMeteorologicalDepartment', 'KibaaleBridge-RakaiCHAI', 'KibabiiUniversity', 'KibandaHydromet', 'KibisiSecondarySchool', 'KisasiPrimarySchool-KCCA', 'KitabiCollege', 'KpandaiSHS,Kpandai', 'KyambogoPrimarySchool-KCCA', 'LariakSecondarySchool', 'LikoniSchoolfortheBlind', 'LongisaHighSchool', 'MCS-FUTA-Akure', 'MagomanoSecondarySchool', 'MahaliMzuri', 'MaraTriangleAirstrip', 'MarariandaPrimary', 'MasenoUniversity', 'MateeteSubcountySembabule-CHAI', 'MengoSeniorSchool', 'MoiForcesAcademy', 'MurungaruSecondarySchool', 'NDMA-TanaRiverHola', 'NaboishoCamp', 'NakivuboBluePrimarySchool', 'NotreDameSeminary,SHS,Navrongo', 'NzukiniSecondarySchool', 'OlderkesiSecondarySchool', 'OleTipisGirlsSecondarySchool', 'RakaiDistrictHQ', 'SacredHeartSHSNsoatre', 'SembabuleDistrictHQ-CHAI', 'Semuto-CHAI', 'SenchuraSecondarySchool', 'St.PetersRCJHS,St.JohnsRCJHS,Tuna', 'StJohnsNyamagwa', 'UniversityofEmbu', 'WalembellePolyClinic', 'WenchiMethodistSHS,Wenchi'],
#   TERENO: ['Gevenich', 'Merzenhausen', 'Schoeneseiffen', 'Selhausen', 'Wildenrath'],
#   TWENTE: ['Hupsel', 'ITCSM-01a', 'ITCSM-01b', 'ITCSM-02a', 'ITCSM-02b', 'ITCSM-03a', 'ITCSM-03b', 'ITCSM-04a', 'ITCSM-04b', 'ITCSM-05a', 'ITCSM-05b', 'ITCSM-05c', 'ITCSM-05d', 'ITCSM-06a', 'ITCSM-06b', 'ITCSM-07a', 'ITCSM-07b', 'ITCSM-08a', 'ITCSM-08b', 'ITCSM-09', 'ITCSM-10a', 'ITCSM-10b', 'ITCSM-10c', 'ITCSM-11a', 'ITCSM-11b', 'ITCSM-11c', 'ITCSM-11d', 'ITCSM-12a', 'ITCSM-12b', 'ITCSM-13', 'ITCSM-14a', 'ITCSM-14b', 'ITCSM-14c', 'ITCSM-15a', 'ITCSM-15b', 'ITCSM-16a', 'ITCSM-16b', 'ITCSM-17a', 'ITCSM-17b', 'ITCSM-17c', 'ITCSM-18', 'ITCSM-19', 'ITCSM-20', 'Twenthe-A'],
#   TxSON: ['CR1000-1', 'CR1000-2', 'CR1000-3', 'CR1000-4', 'CR1000-5', 'CR1000-6', 'CR200-1', 'CR200-10', 'CR200-11', 'CR200-12', 'CR200-13', 'CR200-14', 'CR200-15', 'CR200-16', 'CR200-17', 'CR200-18', 'CR200-19', 'CR200-2', 'CR200-21', 'CR200-22', 'CR200-23', 'CR200-24', 'CR200-25', 'CR200-26', 'CR200-28', 'CR200-29', 'CR200-3', 'CR200-4', 'CR200-5', 'CR200-6', 'CR200-7', 'CR200-8', 'CR200-9', 'LCRA-1', 'LCRA-2', 'LCRA-3', 'LCRA-4', 'LCRA-5', 'LCRA-6', 'LCRA-7'],
#   UDC_SMOS: ['Engersdorf', 'Erlbach', 'Frieding', 'Harbach', 'Karolinenfeld', 'Lochheim', 'Neusling', 'Puch', 'Rothenfeld', 'Steinbeissen', 'Wettlkam'],
#   UMBRIA: ['C.Belfiore', 'C.Elceto', 'C.Rigone', 'Cerbara', 'Colorso', 'Ficulle', 'Foligno', 'Monterchi', 'Petrelle', 'PieveS.Stefano', 'S.Benedetto', 'Solomeo', 'Torre-Olmo'],
#   UMSUOL: ['SanPietroCapofiume'],
#   USCRN: ['Aberdeen-35-WNW', 'Arco-17-SW', 'Asheville-13-S', 'Asheville-8-SSW', 'Austin-33-NW', 'Avondale-2-N', 'Baker-5-W', 'Batesville-8-WNW', 'Bedford-5-WNW', 'Blackville-3-W', 'Bodega-6-WSW', 'Boulder-14-W', 'Bowling-Green-21-NNE', 'Brigham-City-28-WNW', 'Bronte-11-NNE', 'Brunswick-23-S', 'Buffalo-13-ESE', 'Cape-Charles-5-ENE', 'Champaign-9-SW', 'Charlottesville-2-SSE', 'Chatham-1-SE', 'Chillicothe-22-ENE', 'Coos-Bay-8-SW', 'Cortez-8-SE', 'Corvallis-10-SSW', 'Coshocton-8-NNE', 'Crossville-7-NW', 'Darrington-21-NNE', 'Denio-52-WSW', 'Des-Moines-17-E', 'Dillon-18-WSW', 'Dinosaur-2-E', 'Durham-11-W', 'Durham-2-N', 'Durham-2-SSW', 'Edinburg-17-NNE', 'Elgin-5-S', 'Elkins-21-ENE', 'Everglades-City-5-NE', 'Fairhope-3-NE', 'Fallbrook-5-NE', 'Gadsden-19-N', 'Gaylord-9-SSW', 'Goodridge-12-NNW', 'Goodwell-2-E', 'Goodwell-2-SE', 'Harrison-20-SSE', 'Holly-Springs-4-N', 'Ithaca-13-E', 'Jamestown-38-WSW', 'John-Day-35-WNW', 'Joplin-24-N', 'Kenai-29-ENE', 'Kingston-1-NW', 'Kingston-1-W', 'La-Junta-17-WSW', 'Lafayette-13-SE', 'Lander-11-SSE', 'Las-Cruces-20-N', 'Lewistown-42-WSW', 'Limestone-4-NNW', 'Lincoln-11-SW', 'Lincoln-8-ENE', 'Los-Alamos-13-W', 'Manhattan-6-SSW', 'McClellanville-7-NE', 'Medora-7-E', 'Merced-23-WSW', 'Mercury-3-SSW', 'Millbrook-3-W', 'Monahans-6-ENE', 'Monroe-26-N', 'Montrose-11-ENE', 'Moose-1-NNE', 'Muleshoe-19-S', 'Murphy-10-W', 'Necedah-5-WNW', 'Newton-11-SW', 'Newton-5-ENE', 'Newton-8-W', 'Northgate-5-ESE', 'Nunn-7-NNE', 'Oakley-19-SSW', 'Old-Town-2-W', 'Palestine-6-WNW', 'Panther-Junction-2-N', 'Pierre-24-S', 'Port-Aransas-32-NNE', 'Quinault-4-NE', 'Redding-12-WNW', 'Riley-10-WSW', 'Salem-10-W', 'Sandstone-6-W', 'Santa-Barbara-11-W', 'Sebring-23-SSE', 'Selma-13-WNW', 'Shabbona-5-NNE', 'Sioux-Falls-14-NNE', 'Socorro-20-N', 'Spokane-17-SSW', 'St.-Mary-1-SSW', 'Stillwater-2-W', 'Stillwater-5-WNW', 'Stovepipe-Wells-1-SW', 'Sundance-8-NNW', 'Titusville-7-E', 'Tucson-11-W', 'Versailles-3-NNW', 'Watkinsville-5-SSE', 'Whitman-5-ENE', 'Williams-35-NNW', 'Wolf-Point-29-ENE', 'Wolf-Point-34-NE', 'Yosemite-Village-12-W', 'Yuma-27-ENE'],
#   USDA-ARS: ['LittleRiver', 'LittleWashita', 'ReynoldsCreek', 'WalnutGulch'],
#   VAS: ['MelbexI', 'MelbexII'],
#   VDS: ['Alaigni', 'Hpayargyi', 'IrrigationTechnologyCentre', 'Thanatpin'],
#   WATERLINE: ['Kerasia', 'Komotini', 'Nymfaia'],
#   WEGENERNET: ['15', '19', '27', '34', '50', '54', '6', '77', '78', '83', '84', '85', '99'],
#   WIT-Network: ['AtGi10', 'AtGi11', 'AtGi12', 'AtGi13', 'AtGi5', 'AtGi6', 'AtGi7', 'AtGi8', 'AtGi9', 'OkZa1', 'OkZa2', 'OkZa3'],
#   WSMN: ['WSMN-1', 'WSMN-2', 'WSMN-3', 'WSMN-4', 'WSMN-5', 'WSMN-6', 'WSMN-7', 'WSMN-8'],
#   XMS-CAT: ['AguilardeSegarra', 'BatlliudeSort', 'Bolvir', 'BordaColl', 'CamidelsNerets', 'Cantallops', 'Clarella', 'ClotdelesPeresI', 'ClotdelesPeresII', 'ColldePaller', 'ElBoixer', 'ElMiracle', 'Garriguella', 'LaCultiadAreu', 'Llivia', 'LosCoscolls', 'Pessonada', 'PobladeCervoles', 'RiberadeSio', 'SerradeCostaAmpla', 'TorredelLluvia'],
#   iRON: ['BrushCreek', 'GlenwoodSprings', 'NorthstarAspenGrove', 'NorthstarTransitionZone', 'SkyMountain', 'SmugglerMountain', 'SpringValley']

# %% [markdown]
# ### Network

# %% [markdown]
# You can select a specific network from the collection above via its name. Here we pick the network 'SMOSMANIA' from our loaded set. Networks are sorted alphabetically, so you can also pass a number here, e.g. `ismn_data[4]` to get the fourth network from the list. This will (again) display all stations for that network.
# Note that we can call a network directly from `ismn_data` without using the collection.

# %%
ismn_data['SMOSMANIA']  #  overview over stations in SMOSMANIA network; same as ismn_data[4]
# Out:
# Network 'SMOSMANIA' with Stations: ['Barnas', 'Berzeme', 'CabrieresdAvignon', 'Condom', 'CreondArmagnac', 'LaGrandCombe', 'Lahas', 'LezignanCorbieres', 'Mazan-Abbaye', 'Mejannes-le-Clap', 'Montaut', 'Mouthoumet', 'Narbonne', 'PeyrusseGrande', 'Pezenas', 'Pezenas-old', 'Prades-le-Lez', 'Sabres', 'SaintFelixdeLauragais', 'Savenes', 'Urgons', 'Villevielle']

# %% [markdown]
# You can also convert all data in a network into an xarray Dataset object. You might have to run `conda install xarray dask`. You can also filter certain variables or depths in this processing step.

# %%
ismn_data['SMOSMANIA'].to_xarray(variable='soil_moisture')
# Out:
#   0%|          | 0/22 [00:00<?, ?it/s]/Users/amfox/mamba/envs/regrid/lib/python3.11/site-packages/ismn/components.py:407: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'date_time' ('date_time',) The recommendation is to set join explicitly for this case.
#   station = xr.concat(station, dim='sensor')
#   5%|▍         | 1/22 [00:24<08:26, 24.14s/it]/Users/amfox/mamba/envs/regrid/lib/python3.11/site-packages/ismn/components.py:407: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'date_time' ('date_time',) The recommendation is to set join explicitly for this case.
#   station = xr.concat(station, dim='sensor')
#   9%|▉         | 2/22 [00:24<03:27, 10.37s/it]/Users/amfox/mamba/envs/regrid/lib/python3.11/site-packages/ismn/components.py:407: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'date_time' ('date_time',) The recommendation is to set join explicitly for this case.
#   station = xr.concat(station, dim='sensor')
#  14%|█▎        | 3/22 [00:25<01:51,  5.87s/it]/Users/amfox/mamba/envs/regrid/lib/python3.11/site-packages/ismn/components.py:407: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'date_time' ('date_time',) The recommendation is to set join explicitly for this case.
#   station = xr.concat(station, dim='sensor')
#  18%|█▊        | 4/22 [00:26<01:08,  3.80s/it]/Users/amfox/mamba/envs/regrid/lib/python3.11/site-packages/ismn/components.py:407: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'date_time' ('date_time',) The recommendation is to set join explicitly for this case.
#   station = xr.concat(station, dim='sensor')
#  23%|██▎       | 5/22 [00:26<00:46,  2.74s/it]/Users/amfox/mamba/envs/regrid/lib/python3.11/site-packages/ismn/components.py:407: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'date_time' ('date_time',) The recommendation is to set join explicitly for this case.
#   station = xr.concat(station, dim='sensor')
#  27%|██▋       | 6/22 [00:27<00:32,  2.00s/it]/Users/amfox/mamba/envs/regrid/lib/python3.11/site-packages/ismn/components.py:407: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'date_time' ('date_time',) The recommendation is to set join explicitly for this case.
#   station = xr.concat(station, dim='sensor')
#  32%|███▏      | 7/22 [00:28<00:23,  1.58s/it]/Users/amfox/mamba/envs/regrid/lib/python3.11/site-packages/ismn/components.py:407: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'date_time' ('date_time',) The recommendation is to set join explicitly for this case.
#   station = xr.concat(station, dim='sensor')
#  36%|███▋      | 8/22 [00:28<00:17,  1.26s/it]/Users/amfox/mamba/envs/regrid/lib/python3.11/site-packages/ismn/components.py:407: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'date_time' ('date_time',) The recommendation is to set join explicitly for this case.
#   station = xr.concat(station, dim='sensor')
#  41%|████      | 9/22 [00:29<00:13,  1.02s/it]/Users/amfox/mamba/envs/regrid/lib/python3.11/site-packages/ismn/components.py:407: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'date_time' ('date_time',) The recommendation is to set join explicitly for this case.
#   station = xr.concat(station, dim='sensor')
#  45%|████▌     | 10/22 [00:29<00:10,  1.12it/s]/Users/amfox/mamba/envs/regrid/lib/python3.11/site-packages/ismn/components.py:407: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'date_time' ('date_time',) The recommendation is to set join explicitly for this case.
#   station = xr.concat(station, dim='sensor')
#  50%|█████     | 11/22 [00:30<00:09,  1.13it/s]/Users/amfox/mamba/envs/regrid/lib/python3.11/site-packages/ismn/components.py:407: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'date_time' ('date_time',) The recommendation is to set join explicitly for this case.
#   station = xr.concat(station, dim='sensor')
#  55%|█████▍    | 12/22 [00:31<00:08,  1.19it/s]/Users/amfox/mamba/envs/regrid/lib/python3.11/site-packages/ismn/components.py:407: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'date_time' ('date_time',) The recommendation is to set join explicitly for this case.
#   station = xr.concat(station, dim='sensor')
#  59%|█████▉    | 13/22 [00:32<00:07,  1.26it/s]/Users/amfox/mamba/envs/regrid/lib/python3.11/site-packages/ismn/components.py:407: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'date_time' ('date_time',) The recommendation is to set join explicitly for this case.
#   station = xr.concat(station, dim='sensor')
#  64%|██████▎   | 14/22 [00:32<00:05,  1.36it/s]/Users/amfox/mamba/envs/regrid/lib/python3.11/site-packages/ismn/components.py:407: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'date_time' ('date_time',) The recommendation is to set join explicitly for this case.
#   station = xr.concat(station, dim='sensor')
#  68%|██████▊   | 15/22 [00:32<00:04,  1.68it/s]/Users/amfox/mamba/envs/regrid/lib/python3.11/site-packages/ismn/components.py:407: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'date_time' ('date_time',) The recommendation is to set join explicitly for this case.
#   station = xr.concat(station, dim='sensor')
#  73%|███████▎  | 16/22 [00:33<00:02,  2.03it/s]/Users/amfox/mamba/envs/regrid/lib/python3.11/site-packages/ismn/components.py:407: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'date_time' ('date_time',) The recommendation is to set join explicitly for this case.
#   station = xr.concat(station, dim='sensor')
#  77%|███████▋  | 17/22 [00:33<00:02,  1.96it/s]/Users/amfox/mamba/envs/regrid/lib/python3.11/site-packages/ismn/components.py:407: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'date_time' ('date_time',) The recommendation is to set join explicitly for this case.
#   station = xr.concat(station, dim='sensor')
#  82%|████████▏ | 18/22 [00:34<00:02,  1.97it/s]/Users/amfox/mamba/envs/regrid/lib/python3.11/site-packages/ismn/components.py:407: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'date_time' ('date_time',) The recommendation is to set join explicitly for this case.
#   station = xr.concat(station, dim='sensor')
#  86%|████████▋ | 19/22 [00:34<00:01,  1.83it/s]/Users/amfox/mamba/envs/regrid/lib/python3.11/site-packages/ismn/components.py:407: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'date_time' ('date_time',) The recommendation is to set join explicitly for this case.
#   station = xr.concat(station, dim='sensor')
#  91%|█████████ | 20/22 [00:35<00:01,  1.56it/s]/Users/amfox/mamba/envs/regrid/lib/python3.11/site-packages/ismn/components.py:407: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'date_time' ('date_time',) The recommendation is to set join explicitly for this case.
#   station = xr.concat(station, dim='sensor')
#  95%|█████████▌| 21/22 [00:36<00:00,  1.57it/s]/Users/amfox/mamba/envs/regrid/lib/python3.11/site-packages/ismn/components.py:407: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'date_time' ('date_time',) The recommendation is to set join explicitly for this case.
#   station = xr.concat(station, dim='sensor')
# 100%|██████████| 22/22 [00:37<00:00,  1.68s/it]
# /Users/amfox/mamba/envs/regrid/lib/python3.11/site-packages/ismn/components.py:721: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'date_time' ('date_time',) The recommendation is to set join explicitly for this case.
#   net = xr.concat(net, dim="sensor")
# <xarray.Dataset> Size: 474MB
# Dimensions:                  (sensor: 125, date_time: 157428)
# Coordinates:
#   * date_time                (date_time) datetime64[ns] 1MB 2007-01-01 ... 20...
# Dimensions without coordinates: sensor
# Data variables: (12/25)
#     soil_moisture            (sensor, date_time) float64 157MB dask.array<chunksize=(1, 63534), meta=np.ndarray>
#     soil_moisture_flag       (sensor, date_time) object 157MB dask.array<chunksize=(1, 63534), meta=np.ndarray>
#     soil_moisture_orig_flag  (sensor, date_time) object 157MB dask.array<chunksize=(1, 63534), meta=np.ndarray>
#     depth_from               (sensor) float64 1kB dask.array<chunksize=(1,), meta=np.ndarray>
#     depth_to                 (sensor) float64 1kB dask.array<chunksize=(1,), meta=np.ndarray>
#     clay_fraction            (sensor) float64 1kB dask.array<chunksize=(1,), meta=np.ndarray>
#     ...                       ...
#     saturation               (sensor) float64 1kB dask.array<chunksize=(1,), meta=np.ndarray>
#     silt_fraction            (sensor) float64 1kB dask.array<chunksize=(1,), meta=np.ndarray>
#     station                  (sensor) <U21 10kB dask.array<chunksize=(1,), meta=np.ndarray>
#     timerange_from           (sensor) datetime64[ns] 1kB dask.array<chunksize=(1,), meta=np.ndarray>
#     timerange_to             (sensor) datetime64[ns] 1kB dask.array<chunksize=(1,), meta=np.ndarray>
#     variable                 (sensor) <U13 6kB dask.array<chunksize=(1,), meta=np.ndarray>
# Attributes:
#     n_sensors:   125
#     n_stations:  22
#     network:     SMOSMANIA

# %% [markdown]
# ### Station

# %% [markdown]
# A network consists of multiple stations, multiple variables can be measured by different sensors at a station. You can select a specific station for a network via its name (stations are also sorted alphabetically and can be accessed by index). Here we access the Station 'Saint_Felix_de_Lauragais' from the 'SMOSMANIA' network.

# %%
ismn_data['SMOSMANIA']['SaintFelixdeLauragais']  #  overview over sensors at Saint_Felix_de_Lauragais; same as ismn_data[4][18]
# Out:
# Station 'SaintFelixdeLauragais' with Sensors: ['ThetaProbe-ML2X_soil_moisture_0.050000_0.050000', 'ThetaProbe-ML2X_soil_moisture_0.100000_0.100000', 'ThetaProbe-ML2X_soil_moisture_0.200000_0.200000', 'PT-100_soil_temperature_0.100000_0.100000', 'PT-100_soil_temperature_0.050000_0.050000', 'ThetaProbe-ML3_soil_moisture_0.200000_0.200000', 'ThetaProbe-ML2X_soil_moisture_0.300000_0.300000', 'PT-100_soil_temperature_0.200000_0.200000', 'PT-100_soil_temperature_0.300000_0.300000']

# %% [markdown]
# Each station has a metadata attribute. The station metadata contains all metadata variables from all sensors that measure at the station (such as the sensor type, soil properties etc. per sensor). Therefore, the station metadata can be different for different depths. You can call `MetaData` directly, or convert it to either a DataFrame (`MetaData.to_pd()`) or a dictionary (`MetaData.to_dict()`) of form:
#
# ```
# {var_name: [(value, depth_from, depth_to),
#             ...],
# ...}
# ```
#
# In the example below, we read metadata without conversion. The first value in each Variable is the name of the metadata variable, the second the actual value for the variable. The third value is the depth range (depth_from, depth_to) that the value applies to - e.g. for soil properties (taken from the Harmonized World Soil Data Base) multiple layers are provided together with the ISMN data and during metadata generation the best matching depth for a sensor is selected. Some values apply to a specific depth (depth_from=depth_to) while others may apply to a depth range (usually depends on the network).

# %%
ismn_data['SMOSMANIA']['SaintFelixdeLauragais'].metadata  #  Get metadata for the station
# Out:
# MetaData([
#   MetaVar([clay_fraction, 22.8, Depth([0.05, 0.05])]),
#   MetaVar([climate_KG, Cfb, None]),
#   MetaVar([climate_insitu, unknown, None]),
#   MetaVar([elevation, 337.0, None]),
#   MetaVar([instrument, ThetaProbe-ML2X, Depth([0.05, 0.05])]),
#   MetaVar([latitude, 43.4417, None]),
#   MetaVar([lc_2000, 10, None]),
#   MetaVar([lc_2005, 10, None]),
#   MetaVar([lc_2010, 10, None]),
#   MetaVar([lc_insitu, unknown, None]),
#   MetaVar([longitude, 1.88, None]),
#   MetaVar([network, SMOSMANIA, None]),
#   MetaVar([organic_carbon, 1.15, Depth([0.05, 0.05])]),
#   MetaVar([sand_fraction, 43.5, Depth([0.05, 0.05])]),
#   MetaVar([saturation, 0.44, Depth([0.05, 0.05])]),
#   MetaVar([silt_fraction, 33.7, Depth([0.05, 0.05])]),
#   MetaVar([station, SaintFelixdeLauragais, None]),
#   MetaVar([timerange_from, 2007-01-07 05:00:00, None]),
#   MetaVar([timerange_to, 2025-01-01 00:00:00, None]),
#   MetaVar([variable, soil_moisture, Depth([0.05, 0.05])]),
#   MetaVar([clay_fraction, 22.4, Depth([0.1, 0.1])]),
#   MetaVar([instrument, ThetaProbe-ML2X, Depth([0.1, 0.1])]),
#   MetaVar([organic_carbon, 0.84, Depth([0.1, 0.1])]),
#   MetaVar([sand_fraction, 40.3, Depth([0.1, 0.1])]),
#   MetaVar([saturation, 0.43, Depth([0.1, 0.1])]),
#   MetaVar([silt_fraction, 37.3, Depth([0.1, 0.1])]),
#   MetaVar([variable, soil_moisture, Depth([0.1, 0.1])]),
#   MetaVar([clay_fraction, 23.9, Depth([0.2, 0.2])]),
#   MetaVar([instrument, ThetaProbe-ML2X, Depth([0.2, 0.2])]),
#   MetaVar([organic_carbon, 0.97, Depth([0.2, 0.2])]),
#   MetaVar([sand_fraction, 39.7, Depth([0.2, 0.2])]),
#   MetaVar([saturation, 0.44, Depth([0.2, 0.2])]),
#   MetaVar([silt_fraction, 36.4, Depth([0.2, 0.2])]),
#   MetaVar([timerange_to, 2017-09-01 11:00:00, None]),
#   MetaVar([variable, soil_moisture, Depth([0.2, 0.2])]),
#   MetaVar([instrument, PT-100, Depth([0.1, 0.1])]),
#   MetaVar([timerange_from, 2008-01-01 00:00:00, None]),
#   MetaVar([variable, soil_temperature, Depth([0.1, 0.1])]),
#   MetaVar([instrument, PT-100, Depth([0.05, 0.05])]),
#   MetaVar([variable, soil_temperature, Depth([0.05, 0.05])]),
#   MetaVar([instrument, ThetaProbe-ML3, Depth([0.2, 0.2])]),
#   MetaVar([timerange_from, 2017-10-16 13:00:00, None]),
#   MetaVar([clay_fraction, 29.4, Depth([0.3, 0.3])]),
#   MetaVar([instrument, ThetaProbe-ML2X, Depth([0.3, 0.3])]),
#   MetaVar([organic_carbon, 0.7, Depth([0.3, 0.3])]),
#   MetaVar([sand_fraction, 32.0, Depth([0.3, 0.3])]),
#   MetaVar([saturation, 0.44, Depth([0.3, 0.3])]),
#   MetaVar([silt_fraction, 38.6, Depth([0.3, 0.3])]),
#   MetaVar([timerange_to, 2024-11-09 23:00:00, None]),
#   MetaVar([variable, soil_moisture, Depth([0.3, 0.3])]),
#   MetaVar([instrument, PT-100, Depth([0.2, 0.2])]),
#   MetaVar([variable, soil_temperature, Depth([0.2, 0.2])]),
#   MetaVar([instrument, PT-100, Depth([0.3, 0.3])]),
#   MetaVar([timerange_to, 2024-05-08 11:00:00, None]),
#   MetaVar([variable, soil_temperature, Depth([0.3, 0.3])])
# ])

# %% [markdown]
# Also the station object can be transformed into a xarray Dataset. It will contain all measurement time series at the station.

# %%
ismn_data['SMOSMANIA']['SaintFelixdeLauragais'].to_xarray()
# Out:
# /Users/amfox/mamba/envs/regrid/lib/python3.11/site-packages/ismn/components.py:407: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'date_time' ('date_time',) The recommendation is to set join explicitly for this case.
#   station = xr.concat(station, dim='sensor')
# <xarray.Dataset> Size: 68MB
# Dimensions:                     (sensor: 9, date_time: 153693)
# Coordinates:
#   * date_time                   (date_time) datetime64[ns] 1MB 2007-01-07T05:...
# Dimensions without coordinates: sensor
# Data variables: (12/28)
#     soil_moisture               (sensor, date_time) float64 11MB 0.289 ... nan
#     soil_moisture_flag          (sensor, date_time) object 11MB 'G' 'G' ... nan
#     soil_moisture_orig_flag     (sensor, date_time) object 11MB 'M' 'M' ... nan
#     depth_from                  (sensor) float64 72B 0.05 0.1 0.2 ... 0.2 0.3
#     depth_to                    (sensor) float64 72B 0.05 0.1 0.2 ... 0.2 0.3
#     clay_fraction               (sensor) float64 72B 22.8 22.4 ... 23.9 29.4
#     ...                          ...
#     timerange_from              (sensor) datetime64[ns] 72B 2007-01-07T05:00:...
#     timerange_to                (sensor) datetime64[ns] 72B 2025-01-01 ... 20...
#     variable                    (sensor) <U16 576B 'soil_moisture' ... 'soil_...
#     soil_temperature            (sensor, date_time) float64 11MB nan nan ... nan
#     soil_temperature_flag       (sensor, date_time) object 11MB nan nan ... nan
#     soil_temperature_orig_flag  (sensor, date_time) object 11MB nan nan ... nan
# Attributes:
#     station_name:  SaintFelixdeLauragais
#     lat:           43.4417
#     lon:           1.88
#     n_sensors:     9

# %% [markdown]
# ### Sensor

# %% [markdown]
# Accessing sensors at a station works similar to accessing stations in a network. By default, the name is created from the instrument type, the measured variable and the depth layer that the sensor operates in.

# %%
ismn_data['SMOSMANIA']['SaintFelixdeLauragais']['ThetaProbe-ML2X_soil_moisture_0.050000_0.050000'] #  equivalent to ismn_data[4][18][4]
# Out:
# ThetaProbe-ML2X_soil_moisture_0.050000_0.050000

# %% [markdown]
# Each sensor has a measurement time series (access via `Sensor.data`) and sensor specific metadata (via `Sensor.metadata`) assigned. Here we convert metadata to a data frame.

# %%
sensor = ismn_data['SMOSMANIA']['SaintFelixdeLauragais']['ThetaProbe-ML2X_soil_moisture_0.050000_0.050000']
print(sensor.metadata.to_pd())
ax = sensor.data.plot(figsize=(12,4))
ax.set_xlabel("Time [year]")
ax.set_ylabel("Soil Moisture [$m^3 m^{-3}$]")
# Out:
# variable        key
# clay_fraction   val                            22.8
#                 depth_from                     0.05
#                 depth_to                       0.05
# climate_KG      val                             Cfb
# climate_insitu  val                         unknown
# elevation       val                           337.0
# instrument      val                 ThetaProbe-ML2X
#                 depth_from                     0.05
#                 depth_to                       0.05
# latitude        val                         43.4417
# lc_2000         val                              10
# lc_2005         val                              10
# lc_2010         val                              10
# lc_insitu       val                         unknown
# longitude       val                            1.88
# network         val                       SMOSMANIA
# organic_carbon  val                            1.15
#                 depth_from                     0.05
#                 depth_to                       0.05
# sand_fraction   val                            43.5
#                 depth_from                     0.05
#                 depth_to                       0.05
# saturation      val                            0.44
#                 depth_from                     0.05
#                 depth_to                       0.05
# silt_fraction   val                            33.7
#                 depth_from                     0.05
#                 depth_to                       0.05
# station         val           SaintFelixdeLauragais
# timerange_from  val             2007-01-07 05:00:00
# timerange_to    val             2025-01-01 00:00:00
# variable        val                   soil_moisture
#                 depth_from                     0.05
#                 depth_to                       0.05
# Name: data, dtype: object
# Text(0, 0.5, 'Soil Moisture [$m^3 m^{-3}$]')

# %% [markdown]
# Some metadata is different for each sensor (e.g. time series range), some depends on the location of the station and is therefore shared by multiple sensors at one station (landcover and climate classes etc.). Sometime metadata is missing (if not provided, indicated by 'unknown', or NaN). Some meta data depends on the depth of a sensor (e.g. soil properties), during metadata collection (in the beginning) these values were collected and assigned.

# %%
sensor.metadata.to_dict()
# Out:
# {np.str_('clay_fraction'): [(22.8, 0.05, 0.05)],
#  np.str_('climate_KG'): [('Cfb', None, None)],
#  np.str_('climate_insitu'): [('unknown', None, None)],
#  np.str_('elevation'): [(337.0, None, None)],
#  np.str_('instrument'): [('ThetaProbe-ML2X', 0.05, 0.05)],
#  np.str_('latitude'): [(43.4417, None, None)],
#  np.str_('lc_2000'): [(10, None, None)],
#  np.str_('lc_2005'): [(10, None, None)],
#  np.str_('lc_2010'): [(10, None, None)],
#  np.str_('lc_insitu'): [('unknown', None, None)],
#  np.str_('longitude'): [(1.88, None, None)],
#  np.str_('network'): [('SMOSMANIA', None, None)],
#  np.str_('organic_carbon'): [(1.15, 0.05, 0.05)],
#  np.str_('sand_fraction'): [(43.5, 0.05, 0.05)],
#  np.str_('saturation'): [(0.44, 0.05, 0.05)],
#  np.str_('silt_fraction'): [(33.7, 0.05, 0.05)],
#  np.str_('station'): [('SaintFelixdeLauragais', None, None)],
#  np.str_('timerange_from'): [(Timestamp('2007-01-07 05:00:00'), None, None)],
#  np.str_('timerange_to'): [(Timestamp('2025-01-01 00:00:00'), None, None)],
#  np.str_('variable'): [('soil_moisture', 0.05, 0.05)]}

# %% [markdown]
# ## Some other important functions
# Each component (network, station, sensor) contains different functions to handle its data. `ISMN_Interface` provides general functions to filter and iterate over its components and visualize them.

# %% [markdown]
# ### Find nearest station
# The data collection in `ISMN_Interface` contains a grid object that lists the locations of all **stations** in all active networks. For more details see https://github.com/TUW-GEO/pygeogrids

# %%
import pandas as pd
grid = ismn_data.collection.grid
gpis, lons, lats, _ = grid.get_grid_points()
pd.DataFrame(index=pd.Index(gpis, name='gpi'), 
             data={'lon': lons, 'lat': lats}).T
# Out:
# gpi       0          1          2          3          4          5     \
# lon  143.66369  143.89634  144.31351  144.43211  144.79570  145.47188
# lat  -34.77682  -34.77832  -34.65276  -34.74041  -35.03008  -34.67459
#
# gpi       6          7          8          9     ...      3269     3270  \
# lon  145.41483  146.07833  145.99335  146.58227  ...   0.90969   0.8939
# lat  -34.95988  -34.65475  -34.95354  -34.90187  ...  41.80319  42.2112
#
# gpi      3271       3272       3273       3274       3275       3276  \
# lon   1.79065 -106.90815 -107.34133 -106.79944 -106.79917 -106.91313
# lat  41.72531   39.23353   39.54418   39.17067   39.17114   39.22098
#
# gpi       3277       3278
# lon -106.80083 -107.22222
# lat   39.20015   39.47217
#
# [2 rows x 3279 columns]

# %%
# Using the GPI or coordinates, a station from **all** stations in **all** networks in the collection can be selected.
station, dist = ismn_data.collection.get_nearest_station(27.0, 68.0)
print(f'Station {station.name} is {int(dist)} metres away from the passed coordinates:')
assert ismn_data.collection.station4gpi(0) == station # same result when selecting with GPI

# %%
station

# %% [markdown]
# ### Find network for a specific station
# `ISMN_Interface` provides a function to find the network when only the name of a station is known. Here we simply read data for the first available sensor at the fist station in the found network.

# %%
network = ismn_data.network_for_station('SAA111', name_only=False)
display(network)
display(network[0][0].data)

# %% [markdown]
# ### Metadata overview
# To get an overview over all metadata for the currently loaded networks, the attribute `ISMN_Interface.metadata` can be called. This will return a pandas DataFrame with all available metadata variables for different depths as (multi-index) columns and sensors as rows. The first column `idx` is the index of the sensor/filehandler, in line with what `ISMN_Interface.get_dataset_ids()` returns, and can therefore be used to read data via `ISMN_Interface.read()` as shown in the next section.

# %%
ismn_data.metadata

# %% [markdown]
# ### Selecting and reading specific sensors <a id='read_from_meta'></a>

# %% [markdown]
# We can filter the dataset a priori and get IDs of sensors that measure a specific variable. The ID can then be used to read the data directly. Here we extract the IDs of sensors in our data set that measure 'soil_temperature' in 0 to 1 meter depth and within a specific land cover and climate class (all conditions must be fulfilled).

# %%
ids = ismn_data.get_dataset_ids(variable='soil_temperature', 
                                max_depth=1, 
                                filter_meta_dict={'lc_2005': 130, 'climate_KG': 'Csb'})
ids

# %% [markdown]
# We can get the same IDs from the full metadata frame held by ISMN_Interface. Filtering the full metadata dataframe is more flexible but needs some some knowlegde on filtering with pandas. In the end we find the same IDs as for the other method.

# %%
conditions = (ismn_data.metadata['variable'].val == 'soil_temperature') & \
             (ismn_data.metadata['instrument'].depth_to <= 1) & \
             (ismn_data.metadata['lc_2005'].val == 130) & \
             (ismn_data.metadata['climate_KG'].val == 'Csb') 

ismn_data.metadata[conditions].index.to_list()

# %% [markdown]
# Now we can use the so found IDs to read data from the according sensors.

# %%
ts, meta = ismn_data.read(ids, return_meta=True)
ax = ts.plot(figsize=(12,4), title=f'Time series for ID {ids[1]}', xlabel="Time [year]", ylabel="Soil Temp. [°C]")

# %% [markdown]
# ### Plot station locations
# We can define a similar query to plot station locations for a specific variable on a map. If a min/max depth is passed, only stations with a sensor that measures within the passed range are included. Note that this kind of visualisation needs additional (optional) packages installed (use `conda` to install `matplotlib` and `cartopy`).

# %%
import cartopy.crs as ccrs
#plot available station on a map
fig, axs = plt.subplots(1, 2, figsize=(16,10), subplot_kw={'projection': ccrs.Robinson()})
ismn_data.plot_station_locations('soil_moisture', min_depth=0., max_depth=0.1, ax=axs[0], markersize=5, text_scalefactor=2)
ismn_data.plot_station_locations('soil_temperature', min_depth=0.5, ax=axs[1], markersize=5, text_scalefactor=3)
axs[0].set_extent([-10, 35, 34, 71])
axs[1].set_extent([-10, 35, 34, 71])
plt.show()

# %% [markdown]
# ### Network data citations/references
# When using ISMN data in a publication, please cite:
#
# - Dorigo, W., Himmelbauer, I., Aberer, D., Schremmer, L., Petrakovic, I., Zappa, L., Preimesberger, W., Xaver, A., Annor, F., Ardö, J., Baldocchi, D., Bitelli, M., Blöschl, G., Bogena, H., Brocca, L., Calvet, J.-C., Camarero, J. J., Capello, G., Choi, M., Cosh, M. C., van de Giesen, N., Hajdu, I., Ikonen, J., Jensen, K. H., Kanniah, K. D., de Kat, I., Kirchengast, G., Kumar Rai, P., Kyrouac, J., Larson, K., Liu, S., Loew, A., Moghaddam, M., Martínez Fernández, J., Mattar Bader, C., Morbidelli, R., Musial, J. P., Osenga, E., Palecki, M. A., Pellarin, T., Petropoulos, G. P., Pfeil, I., Powers, J., Robock, A., Rüdiger, C., Rummel, U., Strobel, M., Su, Z., Sullivan, R., Tagesson, T., Varlagin, A., Vreugdenhil, M., Walker, J., Wen, J., Wenger, F., Wigneron, J. P., Woods, M., Yang, K., Zeng, Y., Zhang, X., Zreda, M., Dietrich, S., Gruber, A., van Oevelen, P., Wagner, W., Scipal, K., Drusch, M., and Sabia, R.: **The International Soil Moisture Network: serving Earth system science for over a decade, Hydrol. Earth Syst. Sci., 25, 5749–5804, https://doi.org/10.5194/hess-25-5749-2021, 2021.**
#
# In addition, it is required that you cite the networks you use. Information on how to cite a network can be found on https://ismn.earth/en/networks/ and in the downloaded README file that is provided together with the data.
# The ISMN package provides functions to export citations for a single network, and for all networks in a collection (e.g. in case you don't use all the networks you downloaded before) as plain text.

# %%
ismn_data['WEGENERNET'].get_citations()

# %%
ismn_data.collection.export_citations(out_file='/tmp/citations_for_my_subset.txt')

# %% [markdown]
# ## Selecting and iterating over sensors

# %% [markdown]
# It is often desired to iterate over all sensors that fulfill certain requirements (e.g. that measure soil moisture in a certain depth, and/or for a certain land cover class). For these cases the `collection` (and other components) provide iterators that take keywords and values for filtering the loaded networks/stations/sensor and iterating over the filtered data (of a whole collection, a network, or a station).

# %% [markdown]
# ### Select by variable and depth
# In this example we iterate over all sensors in the previously loaded collection (i.e. over all activated networks) that measure 'soil_moisture' in any depth (range) between 0 and 0.05 meters.

# %%
for network, station, sensor in ismn_data.collection.iter_sensors(variable='soil_moisture', 
                                                                  depth=[0., 0.05]):
    display(network)
    display(station)
    display(sensor)

    print('\033[1m' + f'Metadata for sensor {sensor}:'+ '\033[0m')
    display(sensor.metadata.to_pd())
    ax = sensor.data.plot(figsize=(12,4), title=f'Time series for sensor {sensor.name}')
    ax.set_xlabel("Time [year]")
    ax.set_ylabel("Soil Moisture [$m^3 m^{-3}$]")
    break  # for this example we stop after the first sensor

# %% [markdown]
# ### Selecting by variable and other metadata (1)
# In this example we iterate over all sensors for the network 'RMSN' and filter out those that measure precipitation within an ESA CCI Landcover pixel that is marked as 'Cropland, rainfed' (10) or 'Grassland' (130). Available land cover classes to choose are:

# %%
ismn_data.print_landcover_dict()

# %%
for station, sensor in ismn_data['RSMN'].iter_sensors(variable='precipitation', 
                                                      filter_meta_dict={'lc_2010': [10, 130]}):
    display(station)
    display(sensor)
    
    data = sensor.read_data()
    metadata = sensor.metadata
    
    print('\033[1m' + f'Metadata for sensor {sensor}:' + '\033[0m')
    display(metadata.to_pd())
    ax = data.plot(figsize=(12,4), title=f'Time series for sensor {sensor.name}')
    ax.set_xlabel("Time [year]")
    ax.set_ylabel("Precipitation [mm]")
    break # for this example we stop after the first sensor

# %% [markdown]
# ### Selecting by variable, depth and metadata (2)
# In this example we iterate over all sensors in the collection and filter those that measure 'soil_moisture' between 0 and 10 cm within an ESA CCI Landcover pixel that is marked as 'Cropland, rainfed' (10) or 'Grassland' (130), and has one of the following climate classes assigned: 'Csc', 'Cfa', 'Dfc'. In addition, we set all those soil moisture values that are **not** flagged as 'good' (G) to 'NaN'.

# %%
ismn_data.print_climate_dict()

# %%
from ismn.meta import Depth
for network, station, sensor in ismn_data.collection \
    .iter_sensors(variable='soil_moisture',
                  depth=Depth(0.,0.05),
                  filter_meta_dict={'lc_2010': [10, 130],
                                    'climate_KG':['Csc', 'Cfa', 'Dfc']}):
    
    display(network)
    display(station)
    display(sensor)
    
    data = sensor.read_data()
    data.loc[data['soil_moisture_flag'] != 'G', 'soil_moisture'] = np.nan
    metadata = sensor.metadata

    print('\033[1m' + f'Metadata for sensor {sensor}:'+ '\033[0m')
    display(metadata.to_pd())
    ax = data.plot(figsize=(12,4), title=f"G-flagged SM for '{sensor.name}' at station '{station.name}' in network '{network.name}''")
    ax.set_xlabel("Time [year]")
    ax.set_ylabel("Soil Moisture [$m^3 m^{-3}$]")
    break # for this example we stop after the first sensor

# %% [markdown]
# ### Creating subset Interface
# `ISMN_Interface` has a method to create a subset of itself. A subset can consist of any number of sensors from any stations or networks that were in the original object. A subset is again created by passing a number of IDs. IDs can again be retrieved either from the metadata frame (which hold all the information on the sensors) or the `ISMN_Interface.get_dataset_ids` method see chapter [Selecting and reading specific sensors](#read_from_meta)). Here we randomly pick 10 soil moisture sensors. We then create a subset for these ids and use all the available `ISMN_Interface` functions, e.g. to plot the subset.

# %%
metadata = ismn_data.metadata[ismn_data.metadata[('variable', 'val')] == 'soil_moisture']
np.random.seed(123)
ids = np.random.choice(metadata.index, 10)
subset = ismn_data.subset_from_ids(ids)
subset

# %%
import cartopy.crs as ccrs
#plot available station on a map
fig, ax = plt.subplots(1, 1, figsize=(6,10), subplot_kw={'projection': ccrs.Robinson()})
subset.plot_station_locations(ax=ax, markersize=7, text_scalefactor=3)
ax.set_extent([-10, 35, 34, 71])
plt.show()
