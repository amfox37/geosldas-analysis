# %%
import os
import numpy as np
from datetime import datetime, timedelta
import matplotlib.pyplot as plt

from mapper_functions import plot_global_contour

from my_functions import read_obsfcstana

# %%
# Define the list of paths
paths = ['/discover/nobackup/amfox/Experiments/ASCAT_new_scaling_innov/ASCAT_new_scaling_innov/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2015/M04',
         '/discover/nobackup/amfox/Experiments/ASCAT_new_scaling_innov/ASCAT_new_scaling_innov/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2015/M05',
         '/discover/nobackup/amfox/Experiments/ASCAT_new_scaling_innov/ASCAT_new_scaling_innov/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2015/M06',
         '/discover/nobackup/amfox/Experiments/ASCAT_new_scaling_innov/ASCAT_new_scaling_innov/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2015/M07',
         '/discover/nobackup/amfox/Experiments/ASCAT_new_scaling_innov/ASCAT_new_scaling_innov/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2015/M08',
         '/discover/nobackup/amfox/Experiments/ASCAT_new_scaling_innov/ASCAT_new_scaling_innov/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2015/M09',
         '/discover/nobackup/amfox/Experiments/ASCAT_new_scaling_innov/ASCAT_new_scaling_innov/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2015/M10',
         '/discover/nobackup/amfox/Experiments/ASCAT_new_scaling_innov/ASCAT_new_scaling_innov/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2015/M11',
         '/discover/nobackup/amfox/Experiments/ASCAT_new_scaling_innov/ASCAT_new_scaling_innov/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2015/M12',
         '/discover/nobackup/amfox/Experiments/ASCAT_new_scaling_innov/ASCAT_new_scaling_innov/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2016/M01',
         '/discover/nobackup/amfox/Experiments/ASCAT_new_scaling_innov/ASCAT_new_scaling_innov/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2016/M02',
         '/discover/nobackup/amfox/Experiments/ASCAT_new_scaling_innov/ASCAT_new_scaling_innov/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2016/M03'
        ]

# Define the common file name start
file_name_start = 'ASCAT_new_scaling_innov.ens_avg.ldas_ObsFcstAna.201'

# Define the print flag
printflag = False

# Initialize lists to store the returned values
date_times = []
obs_species_list = []
obs_tilenum_list = []
obs_lon_list = []
obs_lat_list = []
obs_obs_list = []
obs_fcst_list = []


# Loop over the paths
for path in paths:
    # Call the read_obsfcstana function for the current path
    date_time, obs_species, obs_tilenum, obs_lon, obs_lat, obs_obs, obs_obsvar, obs_fcst, obs_fcstvar, obs_ana, obs_anavar = read_obsfcstana(path, file_name_start, printflag)
    
    # Append the returned values to the lists
    date_times.append(date_time)
    obs_species_list.append(obs_species)
    obs_tilenum_list.append(obs_tilenum)
    obs_lon_list.append(obs_lon)
    obs_lat_list.append(obs_lat)
    obs_obs_list.append(obs_obs)
    obs_fcst_list.append(obs_fcst)

# Combine the returned values from all paths
date_time = np.concatenate(date_times)
obs_species = np.concatenate(obs_species_list)
obs_tilenum = np.concatenate(obs_tilenum_list)
obs_lon = np.concatenate(obs_lon_list)
obs_lat = np.concatenate(obs_lat_list)
obs_obs = np.concatenate(obs_obs_list)
obs_fcst = np.concatenate(obs_fcst_list)

# Save the combined values to a file
np.savez('combined_values_innov_1_12_mnth.npz', date_time=date_time, obs_species=obs_species, obs_tilenum=obs_tilenum, obs_lon=obs_lon, obs_lat=obs_lat, 
         obs_obs=obs_obs, obs_obsvar=obs_obsvar, obs_fcst=obs_fcst, obs_fcstvar=obs_fcstvar, obs_ana=obs_ana, obs_anavar=obs_anavar)

# %%
# Define the list of paths
paths = ['/discover/nobackup/amfox/Experiments/ASCAT_new_scaling_innov/ASCAT_new_scaling_innov/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2016/M04',
         '/discover/nobackup/amfox/Experiments/ASCAT_new_scaling_innov/ASCAT_new_scaling_innov/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2016/M05',
         '/discover/nobackup/amfox/Experiments/ASCAT_new_scaling_innov/ASCAT_new_scaling_innov/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2016/M06',
         '/discover/nobackup/amfox/Experiments/ASCAT_new_scaling_innov/ASCAT_new_scaling_innov/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2016/M07',
         '/discover/nobackup/amfox/Experiments/ASCAT_new_scaling_innov/ASCAT_new_scaling_innov/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2016/M08',
         '/discover/nobackup/amfox/Experiments/ASCAT_new_scaling_innov/ASCAT_new_scaling_innov/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2016/M09',
         '/discover/nobackup/amfox/Experiments/ASCAT_new_scaling_innov/ASCAT_new_scaling_innov/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2016/M10',
         '/discover/nobackup/amfox/Experiments/ASCAT_new_scaling_innov/ASCAT_new_scaling_innov/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2016/M11',
         '/discover/nobackup/amfox/Experiments/ASCAT_new_scaling_innov/ASCAT_new_scaling_innov/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2016/M12',
         '/discover/nobackup/amfox/Experiments/ASCAT_new_scaling_innov/ASCAT_new_scaling_innov/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2017/M01',
         '/discover/nobackup/amfox/Experiments/ASCAT_new_scaling_innov/ASCAT_new_scaling_innov/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2017/M02',
         '/discover/nobackup/amfox/Experiments/ASCAT_new_scaling_innov/ASCAT_new_scaling_innov/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2017/M03'
        ]

# Define the common file name start
file_name_start = 'ASCAT_new_scaling_innov.ens_avg.ldas_ObsFcstAna.201'

# Define the print flag
printflag = False

# Initialize lists to store the returned values
date_times = []
obs_species_list = []
obs_tilenum_list = []
obs_lon_list = []
obs_lat_list = []
obs_obs_list = []
obs_fcst_list = []


# Loop over the paths
for path in paths:
    # Call the read_obsfcstana function for the current path
    date_time, obs_species, obs_tilenum, obs_lon, obs_lat, obs_obs, obs_obsvar, obs_fcst, obs_fcstvar, obs_ana, obs_anavar = read_obsfcstana(path, file_name_start, printflag)
    
    # Append the returned values to the lists
    date_times.append(date_time)
    obs_species_list.append(obs_species)
    obs_tilenum_list.append(obs_tilenum)
    obs_lon_list.append(obs_lon)
    obs_lat_list.append(obs_lat)
    obs_obs_list.append(obs_obs)
    obs_fcst_list.append(obs_fcst)

# Combine the returned values from all paths
date_time = np.concatenate(date_times)
obs_species = np.concatenate(obs_species_list)
obs_tilenum = np.concatenate(obs_tilenum_list)
obs_lon = np.concatenate(obs_lon_list)
obs_lat = np.concatenate(obs_lat_list)
obs_obs = np.concatenate(obs_obs_list)
obs_fcst = np.concatenate(obs_fcst_list)

# Save the combined values to a file
np.savez('combined_values_innov_13_24_mnth.npz', date_time=date_time, obs_species=obs_species, obs_tilenum=obs_tilenum, obs_lon=obs_lon, obs_lat=obs_lat, 
         obs_obs=obs_obs, obs_obsvar=obs_obsvar, obs_fcst=obs_fcst, obs_fcstvar=obs_fcstvar, obs_ana=obs_ana, obs_anavar=obs_anavar)

# %%
# Define the list of paths
paths = ['/discover/nobackup/amfox/Experiments/ASCAT_new_scaling_innov/ASCAT_new_scaling_innov/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2017/M04',
         '/discover/nobackup/amfox/Experiments/ASCAT_new_scaling_innov/ASCAT_new_scaling_innov/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2017/M05',
         '/discover/nobackup/amfox/Experiments/ASCAT_new_scaling_innov/ASCAT_new_scaling_innov/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2017/M06',
         '/discover/nobackup/amfox/Experiments/ASCAT_new_scaling_innov/ASCAT_new_scaling_innov/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2017/M07',
         '/discover/nobackup/amfox/Experiments/ASCAT_new_scaling_innov/ASCAT_new_scaling_innov/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2017/M08',
         '/discover/nobackup/amfox/Experiments/ASCAT_new_scaling_innov/ASCAT_new_scaling_innov/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2017/M09',
         '/discover/nobackup/amfox/Experiments/ASCAT_new_scaling_innov/ASCAT_new_scaling_innov/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2017/M10',
         '/discover/nobackup/amfox/Experiments/ASCAT_new_scaling_innov/ASCAT_new_scaling_innov/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2017/M11',
         '/discover/nobackup/amfox/Experiments/ASCAT_new_scaling_innov/ASCAT_new_scaling_innov/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2017/M12',
         '/discover/nobackup/amfox/Experiments/ASCAT_new_scaling_innov/ASCAT_new_scaling_innov/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2018/M01',
         '/discover/nobackup/amfox/Experiments/ASCAT_new_scaling_innov/ASCAT_new_scaling_innov/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2018/M02',
         '/discover/nobackup/amfox/Experiments/ASCAT_new_scaling_innov/ASCAT_new_scaling_innov/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2018/M03',
        ]

# Define the common file name start
file_name_start = 'ASCAT_new_scaling_innov.ens_avg.ldas_ObsFcstAna.201'

# Define the print flag
printflag = False

# Initialize lists to store the returned values
date_times = []
obs_species_list = []
obs_tilenum_list = []
obs_lon_list = []
obs_lat_list = []
obs_obs_list = []
obs_fcst_list = []


# Loop over the paths
for path in paths:
    # Call the read_obsfcstana function for the current path
    date_time, obs_species, obs_tilenum, obs_lon, obs_lat, obs_obs, obs_obsvar, obs_fcst, obs_fcstvar, obs_ana, obs_anavar = read_obsfcstana(path, file_name_start, printflag)
    
    # Append the returned values to the lists
    date_times.append(date_time)
    obs_species_list.append(obs_species)
    obs_tilenum_list.append(obs_tilenum)
    obs_lon_list.append(obs_lon)
    obs_lat_list.append(obs_lat)
    obs_obs_list.append(obs_obs)
    obs_fcst_list.append(obs_fcst)

# Combine the returned values from all paths
date_time = np.concatenate(date_times)
obs_species = np.concatenate(obs_species_list)
obs_tilenum = np.concatenate(obs_tilenum_list)
obs_lon = np.concatenate(obs_lon_list)
obs_lat = np.concatenate(obs_lat_list)
obs_obs = np.concatenate(obs_obs_list)
obs_fcst = np.concatenate(obs_fcst_list)

# Save the combined values to a file
np.savez('combined_values_innov_25_36_mnth.npz', date_time=date_time, obs_species=obs_species, obs_tilenum=obs_tilenum, obs_lon=obs_lon, obs_lat=obs_lat, 
         obs_obs=obs_obs, obs_obsvar=obs_obsvar, obs_fcst=obs_fcst, obs_fcstvar=obs_fcstvar, obs_ana=obs_ana, obs_anavar=obs_anavar)

# %%
# Load the saved values from the file
data = np.load('combined_values_innov_1_12_mnth.npz', allow_pickle=True)

# Access the variables
date_time1 = data['date_time']
obs_species1 = data['obs_species']
obs_tilenum1 = data['obs_tilenum']
obs_lon1 = data['obs_lon']
obs_lat1 = data['obs_lat']
obs_obs1 = data['obs_obs']
obs_fcst1 = data['obs_fcst']

# %%
# Load the saved values from the file
data = np.load('combined_values_innov_13_24_mnth.npz', allow_pickle=True)

# Access the variables
date_time2 = data['date_time']
obs_species2 = data['obs_species']
obs_tilenum2 = data['obs_tilenum']
obs_lon2 = data['obs_lon']
obs_lat2 = data['obs_lat']
obs_obs2 = data['obs_obs']
obs_fcst2 = data['obs_fcst']

# %%
# Load the saved values from the file
data = np.load('combined_values_innov_25_36_mnth.npz', allow_pickle=True)

# Access the variables
date_time3 = data['date_time']
obs_species3 = data['obs_species']
obs_tilenum3 = data['obs_tilenum']
obs_lon3 = data['obs_lon']
obs_lat3 = data['obs_lat']
obs_obs3 = data['obs_obs']
obs_fcst3 = data['obs_fcst']

# %%
nodata = -9999

obs_obs1[obs_obs1 == nodata] = np.nan
obs_fcst1[obs_fcst1 == nodata] = np.nan

obs_obs2[obs_obs2 == nodata] = np.nan
obs_fcst2[obs_fcst2 == nodata] = np.nan

obs_obs3[obs_obs3 == nodata] = np.nan
obs_fcst3[obs_fcst3 == nodata] = np.nan

# %%
# Put the observation data into a 2D array

#Calculate i,j
ll_lon = -180.0
ll_lat = -90.0
dlon = 0.25
dlat = 0.25

# Calculate the number of grid cells in the x direction
nx = int((180.0 - ll_lon) / dlon)

# Calculate the number of grid cells in the y direction
ny = int((90.0 - ll_lat) / dlat)

# Calculate lon and lat
lon = np.linspace(ll_lon, ll_lon + nx * dlon, nx)
lat = np.linspace(ll_lat, ll_lat + ny * dlat, ny)

# Create 2D grid of lons and lats
lon2d, lat2d = np.meshgrid(lon, lat)

# %%
length = len(obs_obs1)
first = int(len(obs_obs1)*0.5)
second = len(obs_obs1) - first
print('len(obs_obs1)', len(obs_obs1), 'first = ', first, 'second = ', second)

# %%
n_obs = first

i_out = np.zeros(n_obs)
j_out = np.zeros(n_obs)

for i in range(n_obs):
    i_out[i] = np.floor((obs_lon1[i] - ll_lon)/dlon)
    j_out[i] = np.floor((obs_lat1[i] - ll_lat)/dlat)

# %%
# Initialize a list of lists to store the observations for each grid cell
obs_list = [[[] for i in range(ny)] for j in range(nx)]
fcst_list = [[[] for i in range(ny)] for j in range(nx)]
omf_list = [[[] for i in range(ny)] for j in range(nx)]

# Find all the observations that fall into each grid cell
for i in range(n_obs):
    obs_list[int(i_out[i])][int(j_out[i])].append(obs_obs1[i])
    fcst_list[int(i_out[i])][int(j_out[i])].append(obs_fcst1[i])
    omf_list[int(i_out[i])][int(j_out[i])].append(obs_obs1[i] - obs_fcst1[i])

# %%
# np.savez('innov_lists_1.npz', obs_list=obs_list, fcst_list=fcst_list, omf_list=omf_list)
obs_list1=obs_list
fcst_list1=fcst_list
omf_list1=omf_list

# %%
# Calculate the mean of the observations in each grid cell
obs_mean = np.zeros([nx, ny])
obs_count = np.zeros([nx, ny])
fcst_mean = np.zeros([nx, ny])
omf_mean = np.zeros([nx, ny])
omf_max = np.zeros([nx, ny])
omf_std = np.zeros([nx, ny])

for i in range(nx):
    for j in range(ny):
        if len(obs_list[i][j]) > 0:
            obs_mean[i, j] = np.nanmean(obs_list[i][j])
            obs_count[i, j] = len(obs_list[i][j])
            fcst_mean[i, j] = np.nanmean(fcst_list[i][j])
            omf_mean[i, j] = np.nanmean(omf_list[i][j])
            omf_max[i, j] = np.nanmax(abs(np.array(omf_list[i][j])))
            omf_std[i, j] = np.nanstd(omf_list[i][j])
        else:
            obs_mean[i, j] = np.nan
            obs_count[i, j] = np.nan
            fcst_mean[i, j] = np.nan
            omf_mean[i, j] = np.nan
            omf_max[i, j] = np.nan
            omf_std[i, j] = np.nan

# %%
np.savez('innov_2D_grids_1.npz', obs_mean=obs_mean, obs_count=obs_count, fcst_mean=fcst_mean, omf_mean=omf_mean, omf_max=omf_max, omf_std=omf_std)

# %%
n_obs = second

i_out = np.zeros(n_obs)
j_out = np.zeros(n_obs)

for i in range(second):
    i_out[i] = np.floor((obs_lon1[i + first] - ll_lon)/dlon)
    j_out[i] = np.floor((obs_lat1[i + first] - ll_lat)/dlat)

# %%
# Initialize a list of lists to store the observations for each grid cell
obs_list = [[[] for i in range(ny)] for j in range(nx)]
fcst_list = [[[] for i in range(ny)] for j in range(nx)]
omf_list = [[[] for i in range(ny)] for j in range(nx)]

# Find all the observations that fall into each grid cell
for i in range(n_obs):
    obs_list[int(i_out[i])][int(j_out[i])].append(obs_obs1[i + first])
    fcst_list[int(i_out[i])][int(j_out[i])].append(obs_fcst1[i + first])
    omf_list[int(i_out[i])][int(j_out[i])].append(obs_obs1[i + first] - obs_fcst1[i + first])

# %%
# np.savez('innov_lists_2.npz', obs_list=obs_list, fcst_list=fcst_list, omf_list=omf_list)
obs_list2=obs_list
fcst_list2=fcst_list
omf_list2=omf_list

# %%
# Calculate the mean of the observations in each grid cell
obs_mean = np.zeros([nx, ny])
obs_count = np.zeros([nx, ny])
fcst_mean = np.zeros([nx, ny])
omf_mean = np.zeros([nx, ny])
omf_max = np.zeros([nx, ny])
omf_std = np.zeros([nx, ny])

for i in range(nx):
    for j in range(ny):
        if len(obs_list[i][j]) > 0:
            obs_mean[i, j] = np.nanmean(obs_list[i][j])
            obs_count[i, j] = len(obs_list[i][j])
            fcst_mean[i, j] = np.nanmean(fcst_list[i][j])
            omf_mean[i, j] = np.nanmean(omf_list[i][j])
            omf_max[i, j] = np.nanmax(abs(np.array(omf_list[i][j])))
            omf_std[i, j] = np.nanstd(omf_list[i][j])
        else:
            obs_mean[i, j] = np.nan
            obs_count[i, j] = np.nan
            fcst_mean[i, j] = np.nan
            omf_mean[i, j] = np.nan
            omf_max[i, j] = np.nan
            omf_std[i, j] = np.nan

# %%
np.savez('innov_2D_grids_2.npz', obs_mean=obs_mean, obs_count=obs_count, fcst_mean=fcst_mean, omf_mean=omf_mean, omf_max=omf_max, omf_std=omf_std)

# %%
length = len(obs_obs2)
first = int(len(obs_obs2)*0.5)
second = len(obs_obs2) - first
print('len(obs_obs2)', len(obs_obs2), 'first = ', first, 'second = ', second)

# %%
n_obs = first

i_out = np.zeros(n_obs)
j_out = np.zeros(n_obs)

for i in range(n_obs):
    i_out[i] = np.floor((obs_lon2[i] - ll_lon)/dlon)
    j_out[i] = np.floor((obs_lat2[i] - ll_lat)/dlat)

# %%
# Initialize a list of lists to store the observations for each grid cell
obs_list = [[[] for i in range(ny)] for j in range(nx)]
fcst_list = [[[] for i in range(ny)] for j in range(nx)]
omf_list = [[[] for i in range(ny)] for j in range(nx)]

# Find all the observations that fall into each grid cell
for i in range(n_obs):
    obs_list[int(i_out[i])][int(j_out[i])].append(obs_obs2[i])
    fcst_list[int(i_out[i])][int(j_out[i])].append(obs_fcst2[i])
    omf_list[int(i_out[i])][int(j_out[i])].append(obs_obs2[i] - obs_fcst2[i])

# %%
# np.savez('innov_lists_3.npz', obs_list=obs_list, fcst_list=fcst_list, omf_list=omf_list)

# %%
obs_list3=obs_list
fcst_list3=fcst_list
omf_list3=omf_list

# %%
# Calculate the mean of the observations in each grid cell
obs_mean = np.zeros([nx, ny])
obs_count = np.zeros([nx, ny])
fcst_mean = np.zeros([nx, ny])
omf_mean = np.zeros([nx, ny])
omf_max = np.zeros([nx, ny])
omf_std = np.zeros([nx, ny])

for i in range(nx):
    for j in range(ny):
        if len(obs_list[i][j]) > 0:
            obs_mean[i, j] = np.nanmean(obs_list[i][j])
            obs_count[i, j] = len(obs_list[i][j])
            fcst_mean[i, j] = np.nanmean(fcst_list[i][j])
            omf_mean[i, j] = np.nanmean(omf_list[i][j])
            omf_max[i, j] = np.nanmax(abs(np.array(omf_list[i][j])))
            omf_std[i, j] = np.nanstd(omf_list[i][j])
        else:
            obs_mean[i, j] = np.nan
            obs_count[i, j] = np.nan
            fcst_mean[i, j] = np.nan
            omf_mean[i, j] = np.nan
            omf_max[i, j] = np.nan
            omf_std[i, j] = np.nan

# %%
np.savez('innov_2D_grids_3.npz', obs_mean=obs_mean, obs_count=obs_count, fcst_mean=fcst_mean, omf_mean=omf_mean, omf_max=omf_max, omf_std=omf_std)

# %%
n_obs = second

i_out = np.zeros(n_obs)
j_out = np.zeros(n_obs)

for i in range(second):
    i_out[i] = np.floor((obs_lon2[i + first] - ll_lon)/dlon)
    j_out[i] = np.floor((obs_lat2[i + first] - ll_lat)/dlat)

# %%
# Initialize a list of lists to store the observations for each grid cell
obs_list = [[[] for i in range(ny)] for j in range(nx)]
fcst_list = [[[] for i in range(ny)] for j in range(nx)]
omf_list = [[[] for i in range(ny)] for j in range(nx)]

# Find all the observations that fall into each grid cell
for i in range(n_obs - 2):
    obs_list[int(i_out[i])][int(j_out[i])].append(obs_obs2[i + first])
    fcst_list[int(i_out[i])][int(j_out[i])].append(obs_fcst2[i + first])
    omf_list[int(i_out[i])][int(j_out[i])].append(obs_obs2[i + first] - obs_fcst2[i + first])

# %%
# np.savez('innov_lists_4.npz', obs_list=obs_list, fcst_list=fcst_list, omf_list=omf_list)
obs_list4=obs_list
fcst_list4=fcst_list
omf_list4=omf_list

# %%
# Calculate the mean of the observations in each grid cell
obs_mean = np.zeros([nx, ny])
obs_count = np.zeros([nx, ny])
fcst_mean = np.zeros([nx, ny])
omf_mean = np.zeros([nx, ny])
omf_max = np.zeros([nx, ny])
omf_std = np.zeros([nx, ny])

for i in range(nx):
    for j in range(ny):
        if len(obs_list[i][j]) > 0:
            obs_mean[i, j] = np.nanmean(obs_list[i][j])
            obs_count[i, j] = len(obs_list[i][j])
            fcst_mean[i, j] = np.nanmean(fcst_list[i][j])
            omf_mean[i, j] = np.nanmean(omf_list[i][j])
            omf_max[i, j] = np.nanmax(abs(np.array(omf_list[i][j])))
            omf_std[i, j] = np.nanstd(omf_list[i][j])
        else:
            obs_mean[i, j] = np.nan
            obs_count[i, j] = np.nan
            fcst_mean[i, j] = np.nan
            omf_mean[i, j] = np.nan
            omf_max[i, j] = np.nan
            omf_std[i, j] = np.nan

# %%
np.savez('innov_2D_grids_4.npz', obs_mean=obs_mean, obs_count=obs_count, fcst_mean=fcst_mean, omf_mean=omf_mean, omf_max=omf_max, omf_std=omf_std)

# %%
length = len(obs_obs3)
first = int(len(obs_obs3)*0.5)
second = len(obs_obs3) - first
print('len(obs_obs3)', len(obs_obs3), 'first = ', first, 'second = ', second)

# %%
n_obs = first

i_out = np.zeros(n_obs)
j_out = np.zeros(n_obs)

for i in range(n_obs):
    i_out[i] = np.floor((obs_lon3[i] - ll_lon)/dlon)
    j_out[i] = np.floor((obs_lat3[i] - ll_lat)/dlat)

# %%
# Initialize a list of lists to store the observations for each grid cell
obs_list = [[[] for i in range(ny)] for j in range(nx)]
fcst_list = [[[] for i in range(ny)] for j in range(nx)]
omf_list = [[[] for i in range(ny)] for j in range(nx)]

# Find all the observations that fall into each grid cell
for i in range(n_obs):
    obs_list[int(i_out[i])][int(j_out[i])].append(obs_obs3[i])
    fcst_list[int(i_out[i])][int(j_out[i])].append(obs_fcst3[i])
    omf_list[int(i_out[i])][int(j_out[i])].append(obs_obs3[i] - obs_fcst3[i])

# %%
# np.savez('innov_lists_5.npz', obs_list=obs_list, fcst_list=fcst_list, omf_list=omf_list)
obs_list5=obs_list
fcst_list5=fcst_list
omf_list5=omf_list

# %%
# Calculate the mean of the observations in each grid cell
obs_mean = np.zeros([nx, ny])
obs_count = np.zeros([nx, ny])
fcst_mean = np.zeros([nx, ny])
omf_mean = np.zeros([nx, ny])
omf_max = np.zeros([nx, ny])
omf_std = np.zeros([nx, ny])

for i in range(nx):
    for j in range(ny):
        if len(obs_list[i][j]) > 0:
            obs_mean[i, j] = np.nanmean(obs_list[i][j])
            obs_count[i, j] = len(obs_list[i][j])
            fcst_mean[i, j] = np.nanmean(fcst_list[i][j])
            omf_mean[i, j] = np.nanmean(omf_list[i][j])
            omf_max[i, j] = np.nanmax(abs(np.array(omf_list[i][j])))
            omf_std[i, j] = np.nanstd(omf_list[i][j])
        else:
            obs_mean[i, j] = np.nan
            obs_count[i, j] = np.nan
            fcst_mean[i, j] = np.nan
            omf_mean[i, j] = np.nan
            omf_max[i, j] = np.nan
            omf_std[i, j] = np.nan

# %%
np.savez('innov_2D_grids_5.npz', obs_mean=obs_mean, obs_count=obs_count, fcst_mean=fcst_mean, omf_mean=omf_mean, omf_max=omf_max, omf_std=omf_std)

# %%
n_obs = second

i_out = np.zeros(n_obs)
j_out = np.zeros(n_obs)

for i in range(second):
    i_out[i] = np.floor((obs_lon3[i + first] - ll_lon)/dlon)
    j_out[i] = np.floor((obs_lat3[i + first] - ll_lat)/dlat)

# %%
# Initialize a list of lists to store the observations for each grid cell
obs_list = [[[] for i in range(ny)] for j in range(nx)]
fcst_list = [[[] for i in range(ny)] for j in range(nx)]
omf_list = [[[] for i in range(ny)] for j in range(nx)]

# Find all the observations that fall into each grid cell
for i in range(n_obs - 2):
    obs_list[int(i_out[i])][int(j_out[i])].append(obs_obs3[i + first])
    fcst_list[int(i_out[i])][int(j_out[i])].append(obs_fcst3[i + first])
    omf_list[int(i_out[i])][int(j_out[i])].append(obs_obs3[i + first] - obs_fcst3[i + first])

# %%
# np.savez('innov_lists_6.npz', obs_list=obs_list, fcst_list=fcst_list, omf_list=omf_list)
obs_list6=obs_list
fcst_list6=fcst_list
omf_list6=omf_list

# %%
# Calculate the mean of the observations in each grid cell
obs_mean = np.zeros([nx, ny])
obs_count = np.zeros([nx, ny])
fcst_mean = np.zeros([nx, ny])
omf_mean = np.zeros([nx, ny])
omf_max = np.zeros([nx, ny])
omf_std = np.zeros([nx, ny])

for i in range(nx):
    for j in range(ny):
        if len(obs_list[i][j]) > 0:
            obs_mean[i, j] = np.nanmean(obs_list[i][j])
            obs_count[i, j] = len(obs_list[i][j])
            fcst_mean[i, j] = np.nanmean(fcst_list[i][j])
            omf_mean[i, j] = np.nanmean(omf_list[i][j])
            omf_max[i, j] = np.nanmax(abs(np.array(omf_list[i][j])))
            omf_std[i, j] = np.nanstd(omf_list[i][j])
        else:
            obs_mean[i, j] = np.nan
            obs_count[i, j] = np.nan
            fcst_mean[i, j] = np.nan
            omf_mean[i, j] = np.nan
            omf_max[i, j] = np.nan
            omf_std[i, j] = np.nan

# %%
np.savez('innov_2D_grids_6.npz', obs_mean=obs_mean, obs_count=obs_count, fcst_mean=fcst_mean, omf_mean=omf_mean, omf_max=omf_max, omf_std=omf_std)

# %%
# Load the saved values from the file
data = np.load('innov_2D_grids_1.npz', allow_pickle=True)

# Access the variables
obs_mean = data['obs_mean']
obs_count = data['obs_count']
fcst_mean = data['fcst_mean']
omf_mean = data['omf_mean']
omf_max = data['omf_max']
omf_std = data['omf_std']

# %%
# Plot the mean of the observations in each grid cell
plot_global_contour(lon2d, lat2d, obs_count.T, True, 'Innov Obs count 042015', '(Count)')
plot_global_contour(lon2d, lat2d, obs_mean.T, True, 'Innov Obs - mean 042015', '(m3 m3-1)',0,1)
plot_global_contour(lon2d, lat2d, fcst_mean.T, True, 'Innov Fcst - mean 042015', '(m3 m3-1)',0,1)
plot_global_contour(lon2d, lat2d, omf_mean.T, True, 'OmF - mean 042015', '(m3 m3-1)',-0.1,0.1)
plot_global_contour(lon2d, lat2d, omf_max.T, True, 'OmF - max 042015', '(m3 m3-1)',0,np.nanmax(omf_max))
plot_global_contour(lon2d, lat2d, omf_std.T, True, 'Omf - stddev 042015', '(m3 m3-1)',0,np.nanmax(omf_std))

# %%
# Load the saved values from the file
data = np.load('innov_2D_grids_2.npz', allow_pickle=True)

# Access the variables
obs_mean = data['obs_mean']
obs_count = data['obs_count']
fcst_mean = data['fcst_mean']
omf_mean = data['omf_mean']
omf_max = data['omf_max']
omf_std = data['omf_std']

# Plot the mean of the observations in each grid cell
plot_global_contour(lon2d, lat2d, obs_count.T, True, 'Innov Obs count 102015', '(Count)')
plot_global_contour(lon2d, lat2d, obs_mean.T, True, 'Innov Obs - mean 102015', '(m3 m3-1)',0,1)
plot_global_contour(lon2d, lat2d, fcst_mean.T, True, 'Innov Fcst - mean 102015', '(m3 m3-1)',0,1)
plot_global_contour(lon2d, lat2d, omf_mean.T, True, 'OmF - mean 102015', '(m3 m3-1)',-0.1,0.1)
plot_global_contour(lon2d, lat2d, omf_max.T, True, 'OmF - max 102015', '(m3 m3-1)',0,np.nanmax(omf_max))
plot_global_contour(lon2d, lat2d, omf_std.T, True, 'Omf - stddev 102015', '(m3 m3-1)',0,np.nanmax(omf_std))

# %%
# Load the saved values from the file
data = np.load('innov_2D_grids_3.npz', allow_pickle=True)

# Access the variables
obs_mean = data['obs_mean']
obs_count = data['obs_count']
fcst_mean = data['fcst_mean']
omf_mean = data['omf_mean']
omf_max = data['omf_max']
omf_std = data['omf_std']

# Plot the mean of the observations in each grid cell
plot_global_contour(lon2d, lat2d, obs_count.T, True, 'Innov Obs count 042016', '(Count)')
plot_global_contour(lon2d, lat2d, obs_mean.T, True, 'Innov Obs - mean 042016', '(m3 m3-1)',0,1)
plot_global_contour(lon2d, lat2d, fcst_mean.T, True, 'Innov Fcst - mean 042016', '(m3 m3-1)',0,1)
plot_global_contour(lon2d, lat2d, omf_mean.T, True, 'OmF - mean 042016', '(m3 m3-1)',-0.1,0.1)
plot_global_contour(lon2d, lat2d, omf_max.T, True, 'OmF - max 042016', '(m3 m3-1)',0,np.nanmax(omf_max))
plot_global_contour(lon2d, lat2d, omf_std.T, True, 'Omf - stddev 042016', '(m3 m3-1)',0,np.nanmax(omf_std))

# %%
# Load the saved values from the file
data = np.load('innov_2D_grids_4.npz', allow_pickle=True)

# Access the variables
obs_mean = data['obs_mean']
obs_count = data['obs_count']
fcst_mean = data['fcst_mean']
omf_mean = data['omf_mean']
omf_max = data['omf_max']
omf_std = data['omf_std']

# Plot the mean of the observations in each grid cell
plot_global_contour(lon2d, lat2d, obs_count.T, True, 'Innov Obs count 102016', '(Count)')
plot_global_contour(lon2d, lat2d, obs_mean.T, True, 'Innov Obs - mean 102016', '(m3 m3-1)',0,1)
plot_global_contour(lon2d, lat2d, fcst_mean.T, True, 'Innov Fcst - mean 102016', '(m3 m3-1)',0,1)
plot_global_contour(lon2d, lat2d, omf_mean.T, True, 'OmF - mean 102016', '(m3 m3-1)',-0.1,0.1)
plot_global_contour(lon2d, lat2d, omf_max.T, True, 'OmF - max 102016', '(m3 m3-1)',0,np.nanmax(omf_max))
plot_global_contour(lon2d, lat2d, omf_std.T, True, 'Omf - stddev 102016', '(m3 m3-1)',0,np.nanmax(omf_std))

# %%
# Load the saved values from the file
data = np.load('innov_2D_grids_5.npz', allow_pickle=True)

# Access the variables
obs_mean = data['obs_mean']
obs_count = data['obs_count']
fcst_mean = data['fcst_mean']
omf_mean = data['omf_mean']
omf_max = data['omf_max']
omf_std = data['omf_std']

# Plot the mean of the observations in each grid cell
plot_global_contour(lon2d, lat2d, obs_count.T, True, 'Innov Obs count 042017', '(Count)')
plot_global_contour(lon2d, lat2d, obs_mean.T, True, 'Innov Obs - mean 042017', '(m3 m3-1)',0,1)
plot_global_contour(lon2d, lat2d, fcst_mean.T, True, 'Innov Fcst - mean 042017', '(m3 m3-1)',0,1)
plot_global_contour(lon2d, lat2d, omf_mean.T, True, 'OmF - mean 042017', '(m3 m3-1)',-0.1,0.1)
plot_global_contour(lon2d, lat2d, omf_max.T, True, 'OmF - max 042017', '(m3 m3-1)',0,np.nanmax(omf_max))
plot_global_contour(lon2d, lat2d, omf_std.T, True, 'Omf - stddev 042017', '(m3 m3-1)',0,np.nanmax(omf_std))

# %%
# Load the saved values from the file
data = np.load('innov_2D_grids_6.npz', allow_pickle=True)

# Access the variables
obs_mean = data['obs_mean']
obs_count = data['obs_count']
fcst_mean = data['fcst_mean']
omf_mean = data['omf_mean']
omf_max = data['omf_max']
omf_std = data['omf_std']

# Plot the mean of the observations in each grid cell
plot_global_contour(lon2d, lat2d, obs_count.T, True, 'Innov Obs count 102017', '(Count)')
plot_global_contour(lon2d, lat2d, obs_mean.T, True, 'Innov Obs - mean 102017', '(m3 m3-1)',0,1)
plot_global_contour(lon2d, lat2d, fcst_mean.T, True, 'Innov Fcst - mean 102017', '(m3 m3-1)',0,1)
plot_global_contour(lon2d, lat2d, omf_mean.T, True, 'OmF - mean 102017', '(m3 m3-1)',-0.1,0.1)
plot_global_contour(lon2d, lat2d, omf_max.T, True, 'OmF - max 102017', '(m3 m3-1)',0,np.nanmax(omf_max))
plot_global_contour(lon2d, lat2d, omf_std.T, True, 'Omf - stddev 102017', '(m3 m3-1)',0,np.nanmax(omf_std))

# %%
# Load the saved values from the file
data = np.load('innov_2D_grids_1.npz', allow_pickle=True)
omf_mean1 = data['omf_mean']
data = np.load('innov_2D_grids_2.npz', allow_pickle=True)
omf_mean2 = data['omf_mean']
data = np.load('innov_2D_grids_3.npz', allow_pickle=True)
omf_mean3 = data['omf_mean']
data = np.load('innov_2D_grids_4.npz', allow_pickle=True)
omf_mean4 = data['omf_mean']
data = np.load('innov_2D_grids_5.npz', allow_pickle=True)
omf_mean5 = data['omf_mean']
data = np.load('innov_2D_grids_6.npz', allow_pickle=True)
omf_mean6 = data['omf_mean']

# %%
# Calculate the mean of the three arrays on the same grid
omf_mean = np.mean([omf_mean1, omf_mean2, omf_mean3, omf_mean4, omf_mean5, omf_mean6], axis=0)

plot_global_contour(lon2d, lat2d, omf_mean.T, True, 'OmF - mean all years', '(m3 m3-1)',-0.1,0.1)

# %%
# Load the saved values from the file
data = np.load('innov_2D_grids_1.npz', allow_pickle=True)

# Access the variables
obs_list1 = data['obs_list']
fcst_list1 = data['fcst_list']
omf_list1 = data['omf_list']
