# %%
import os
import numpy as np
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import xarray as xr

from mapper_functions import plot_global_contour

from my_functions import read_obsfcstana
from my_functions import read_obsfcstana_extend_datetime

# %%
# Define the list of years
years = ['2015', '2016', '2017', '2018', '2019', '2020', '2021']

# Define the common file name start
file_name_start = 'DAv7_M36_ASCAT_type_2.ens_avg.ldas_ObsFcstAna.20'

# Define the print flag
printflag = False

# Loop over the years
for i in range(len(years)-1):
    # Define the current and next year
    current_year = years[i]
    next_year = years[i+1]
    # Define the list of paths
    paths = []
    for month in range(4, 13):
        path = f'/discover/nobackup/amfox/Experiments/DAv7_M36_ASCAT_type_2/DAv7_M36_ASCAT_type_2/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y{current_year}/M{month:02d}'
        paths.append(path)

    for month in range(1, 4):
        path = f'/discover/nobackup/amfox/Experiments/DAv7_M36_ASCAT_type_2/DAv7_M36_ASCAT_type_2/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y{next_year}/M{month:02d}'
        paths.append(path)
    
    # Initialize lists to store the returned values
    date_times = []
    obs_species_list = []
    obs_tilenum_list = []
    obs_lon_list = []
    obs_lat_list = []
    obs_obs_list = []
    obs_fcst_list = []
    obs_ana_list = []
    
    # Loop over the paths for the current year
    for path in paths:
        # Print the current path
        print("Current path:", path)

        # Call the read_obsfcstana function for the current path
        date_time, obs_species, obs_tilenum, obs_lon, obs_lat, obs_obs, obs_obsvar, obs_fcst, obs_fcstvar, obs_ana, obs_anavar = read_obsfcstana(path, file_name_start, printflag)
        
        # Append the returned values to the lists
        date_times.append(date_time)
        obs_species_list.append(obs_species)
        obs_tilenum_list.append(obs_tilenum)
        obs_lon_list.append(obs_lon)
        obs_lat_list.append(obs_lat)
        obs_obs_list.append(obs_obs)
        obs_fcst_list.append(obs_fcst)
        obs_ana_list.append(obs_ana)
    
    # Combine the returned values from all paths
    date_time_out = np.concatenate(date_times)
    obs_species_out = np.concatenate(obs_species_list)
    obs_tilenum_out = np.concatenate(obs_tilenum_list)
    obs_lon_out = np.concatenate(obs_lon_list)
    obs_lat_out = np.concatenate(obs_lat_list)
    obs_obs_out = np.concatenate(obs_obs_list)
    obs_fcst_out = np.concatenate(obs_fcst_list)
    obs_ana_out = np.concatenate(obs_ana_list)
    
    # Save the returned values to a file including the current year in the file name
    np.savez(f'DAv7_M36_ASCAT_type_2_obsfcstana_{current_year}.npz', date_time=date_time_out, obs_species=obs_species_out, obs_tilenum=obs_tilenum_out, obs_lon=obs_lon_out, obs_lat=obs_lat_out, obs_obs=obs_obs_out, obs_fcst=obs_fcst_out, obs_ana=obs_ana_out)

# %%
# Define the list of years
years = ['2015', '2016', '2017', '2018', '2019', '2020', '2021']

# Define the common file name start
file_name_start = 'smap_ascat_multivariate_test.ens_avg.ldas_ObsFcstAna.20'

# Define the print flag
printflag = False

# Loop over the years
for i in range(len(years)-1):
    # Define the current and next year
    current_year = years[i]
    next_year = years[i+1]
    # Define the list of paths
    paths = []
    for month in range(4, 13):
        path = f'/discover/nobackup/amfox/Experiments/smap_ascat_multivariate_test/smap_ascat_multivariate_test/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y{current_year}/M{month:02d}'
        paths.append(path)

    for month in range(1, 4):
        path = f'/discover/nobackup/amfox/Experiments/smap_ascat_multivariate_test/smap_ascat_multivariate_test/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y{next_year}/M{month:02d}'
        paths.append(path)
    
    # Initialize lists to store the returned values
    date_times = []
    obs_species_list = []
    obs_tilenum_list = []
    obs_lon_list = []
    obs_lat_list = []
    obs_obs_list = []
    obs_fcst_list = []
    obs_ana_list = []
    
    # Loop over the paths for the current year
    for path in paths:
        # Print the current path
        print("Current path:", path)

        # Call the read_obsfcstana function for the current path
        date_time, obs_species, obs_tilenum, obs_lon, obs_lat, obs_obs, obs_obsvar, obs_fcst, obs_fcstvar, obs_ana, obs_anavar = read_obsfcstana(path, file_name_start, printflag)
        
        # Append the returned values to the lists
        date_times.append(date_time)
        obs_species_list.append(obs_species)
        obs_tilenum_list.append(obs_tilenum)
        obs_lon_list.append(obs_lon)
        obs_lat_list.append(obs_lat)
        obs_obs_list.append(obs_obs)
        obs_fcst_list.append(obs_fcst)
        obs_ana_list.append(obs_ana)
    
    # Combine the returned values from all paths
    date_time_out = np.concatenate(date_times)
    obs_species_out = np.concatenate(obs_species_list)
    obs_tilenum_out = np.concatenate(obs_tilenum_list)
    obs_lon_out = np.concatenate(obs_lon_list)
    obs_lat_out = np.concatenate(obs_lat_list)
    obs_obs_out = np.concatenate(obs_obs_list)
    obs_fcst_out = np.concatenate(obs_fcst_list)
    obs_ana_out = np.concatenate(obs_ana_list)
    
    # Save the returned values to a file including the current year in the file name
    np.savez(f'smap_ascat_multivariate_test_obsfcstana_{current_year}.npz', date_time=date_time_out, obs_species=obs_species_out, obs_tilenum=obs_tilenum_out, obs_lon=obs_lon_out, obs_lat=obs_lat_out, obs_obs=obs_obs_out, obs_fcst=obs_fcst_out, obs_ana=obs_ana_out)

# %%
# Produce with extended date_time
# Define the list of years
years = ['2015', '2016', '2017', '2018', '2019', '2020', '2021']

# Define the common file name start
file_name_start = 'smap_ascat_multivariate_test.ens_avg.ldas_ObsFcstAna.20'

# Define the print flag
printflag = False

# Loop over the years
for i in range(len(years)-1):
    # Define the current and next year
    current_year = years[i]
    next_year = years[i+1]
    # Define the list of paths
    paths = []
    for month in range(4, 13):
        path = f'/discover/nobackup/amfox/Experiments/smap_ascat_multivariate_test/smap_ascat_multivariate_test/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y{current_year}/M{month:02d}'
        paths.append(path)

    for month in range(1, 4):
        path = f'/discover/nobackup/amfox/Experiments/smap_ascat_multivariate_test/smap_ascat_multivariate_test/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y{next_year}/M{month:02d}'
        paths.append(path)
    
    # Initialize lists to store the returned values
    date_times = []
    obs_species_list = []
    obs_tilenum_list = []
    obs_lon_list = []
    obs_lat_list = []
    obs_obs_list = []
    obs_fcst_list = []
    obs_ana_list = []
    
    # Loop over the paths for the current year
    for path in paths:
        # Print the current path
        print("Current path:", path)

        # Call the read_obsfcstana function for the current path
        date_time, obs_species, obs_tilenum, obs_lon, obs_lat, obs_obs, obs_obsvar, obs_fcst, obs_fcstvar, obs_ana, obs_anavar = read_obsfcstana_extend_datetime(path, file_name_start, printflag)
        
        # Append the returned values to the lists
        date_times.append(date_time)
        obs_species_list.append(obs_species)
        obs_tilenum_list.append(obs_tilenum)
        obs_lon_list.append(obs_lon)
        obs_lat_list.append(obs_lat)
        obs_obs_list.append(obs_obs)
        obs_fcst_list.append(obs_fcst)
        obs_ana_list.append(obs_ana)
    
    # Combine the returned values from all paths
    date_time_out = np.concatenate(date_times)
    obs_species_out = np.concatenate(obs_species_list)
    obs_tilenum_out = np.concatenate(obs_tilenum_list)
    obs_lon_out = np.concatenate(obs_lon_list)
    obs_lat_out = np.concatenate(obs_lat_list)
    obs_obs_out = np.concatenate(obs_obs_list)
    obs_fcst_out = np.concatenate(obs_fcst_list)
    obs_ana_out = np.concatenate(obs_ana_list)
    
    # Save the returned values to a file including the current year in the file name
    np.savez(f'smap_ascat_multivariate_test_obsfcstana_extend_datetime_{current_year}.npz', date_time=date_time_out, obs_species=obs_species_out, obs_tilenum=obs_tilenum_out, obs_lon=obs_lon_out, obs_lat=obs_lat_out, obs_obs=obs_obs_out, obs_fcst=obs_fcst_out, obs_ana=obs_ana_out)

# %%
# Produce with extended date_time
# Define the list of years
years = ['2015', '2016', '2017', '2018', '2019', '2020', '2021']

# Define the common file name start
file_name_start = 'smap_ascat_multivariate_test.ens_avg.ldas_ObsFcstAna.20'

# Define the print flag
printflag = False

# Loop over the years
for i in range(len(years)-1):
    # Define the current and next year
    current_year = years[i]
    next_year = years[i+1]
    # Define the list of paths
    paths = []
    for month in range(4, 13):
        path = f'/discover/nobackup/amfox/Experiments/smap_ascat_multivariate_test/smap_ascat_multivariate_test/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y{current_year}/M{month:02d}'
        paths.append(path)

    for month in range(1, 4):
        path = f'/discover/nobackup/amfox/Experiments/smap_ascat_multivariate_test/smap_ascat_multivariate_test/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y{next_year}/M{month:02d}'
        paths.append(path)
    
    # Initialize lists to store the returned values
    date_times = []
    obs_species_list = []
    obs_tilenum_list = []
    obs_lon_list = []
    obs_lat_list = []
    obs_obs_list = []
    obs_fcst_list = []
    obs_ana_list = []
    
    # Loop over the paths for the current year
    for path in paths:
        # Print the current path
        print("Current path:", path)

        # Call the read_obsfcstana function for the current path
        date_time, obs_species, obs_tilenum, obs_lon, obs_lat, obs_obs, obs_obsvar, obs_fcst, obs_fcstvar, obs_ana, obs_anavar = read_obsfcstana_extend_datetime(path, file_name_start, printflag)
        
        # Append the returned values to the lists
        date_times.append(date_time)
        obs_species_list.append(obs_species)
        obs_tilenum_list.append(obs_tilenum)
        obs_lon_list.append(obs_lon)
        obs_lat_list.append(obs_lat)
        obs_obs_list.append(obs_obs)
        obs_fcst_list.append(obs_fcst)
        obs_ana_list.append(obs_ana)
    
    # Combine the returned values from all paths
    date_time_out = np.concatenate(date_times)
    obs_species_out = np.concatenate(obs_species_list)
    obs_tilenum_out = np.concatenate(obs_tilenum_list)
    obs_lon_out = np.concatenate(obs_lon_list)
    obs_lat_out = np.concatenate(obs_lat_list)
    obs_obs_out = np.concatenate(obs_obs_list)
    obs_fcst_out = np.concatenate(obs_fcst_list)
    obs_ana_out = np.concatenate(obs_ana_list)
    
    # Save the returned values to a file including the current year in the file name
    np.savez(f'smap_ascat_multivariate_test_obsfcstana_extend_datetime_{current_year}.npz', date_time=date_time_out, obs_species=obs_species_out, obs_tilenum=obs_tilenum_out, obs_lon=obs_lon_out, obs_lat=obs_lat_out, obs_obs=obs_obs_out, obs_fcst=obs_fcst_out, obs_ana=obs_ana_out)

# %%
# Define the list of years
years = ['2015', '2016', '2017', '2018', '2019', '2020', '2021']

# Define the common file name start
file_name_start = 'DAv7_M36.ens_avg.ldas_ObsFcstAna.20'

# Define the print flag
printflag = False

# Loop over the years
for i in range(len(years)-1):
    # Define the current and next year
    current_year = years[i]
    next_year = years[i+1]
    # Define the list of paths
    paths = []
    for month in range(4, 13):
        path = f'/home/amfox/smap/SMAP_Nature/SMAP_Nature_v10/DAv7_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y{current_year}/M{month:02d}'
        paths.append(path)

    for month in range(1, 4):
        path = f'/home/amfox/smap/SMAP_Nature/SMAP_Nature_v10/DAv7_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y{next_year}/M{month:02d}'
        paths.append(path)
    
    # Initialize lists to store the returned values
    date_times = []
    obs_species_list = []
    obs_tilenum_list = []
    obs_lon_list = []
    obs_lat_list = []
    obs_obs_list = []
    obs_fcst_list = []
    obs_ana_list = []
    
    # Loop over the paths for the current year
    for path in paths:
        # Print the current path
        print("Current path:", path)

        # Call the read_obsfcstana function for the current path
        date_time, obs_species, obs_tilenum, obs_lon, obs_lat, obs_obs, obs_obsvar, obs_fcst, obs_fcstvar, obs_ana, obs_anavar = read_obsfcstana(path, file_name_start, printflag)
        
        # Append the returned values to the lists
        date_times.append(date_time)
        obs_species_list.append(obs_species)
        obs_tilenum_list.append(obs_tilenum)
        obs_lon_list.append(obs_lon)
        obs_lat_list.append(obs_lat)
        obs_obs_list.append(obs_obs)
        obs_fcst_list.append(obs_fcst)
        obs_ana_list.append(obs_ana)
    
    # Combine the returned values from all paths
    date_time_out = np.concatenate(date_times)
    obs_species_out = np.concatenate(obs_species_list)
    obs_tilenum_out = np.concatenate(obs_tilenum_list)
    obs_lon_out = np.concatenate(obs_lon_list)
    obs_lat_out = np.concatenate(obs_lat_list)
    obs_obs_out = np.concatenate(obs_obs_list)
    obs_fcst_out = np.concatenate(obs_fcst_list)
    obs_ana_out = np.concatenate(obs_ana_list)
    
    # Save the returned values to a file including the current year in the file name
    np.savez(f'DAv7_M36_obsfcstana_{current_year}.npz', date_time=date_time_out, obs_species=obs_species_out, obs_tilenum=obs_tilenum_out, obs_lon=obs_lon_out, obs_lat=obs_lat_out, obs_obs=obs_obs_out, obs_fcst=obs_fcst_out, obs_ana=obs_ana_out)

# %%
# Define the list of years
years = ['2015', '2016', '2017', '2018', '2019', '2020', '2021']

# Define the common file name start
file_name_start = 'OLv7_M36.ens_avg.ldas_ObsFcstAna.20'

# Define the print flag
printflag = False

# Loop over the years
for i in range(len(years)-1):
    # Define the current and next year
    current_year = years[i]
    next_year = years[i+1]
    # Define the list of paths
    paths = []
    for month in range(4, 13):
        path = f'/home/amfox/smap/SMAP_Nature/SMAP_Nature_v10/OLv7_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y{current_year}/M{month:02d}'
        paths.append(path)

    for month in range(1, 4):
        path = f'/home/amfox/smap/SMAP_Nature/SMAP_Nature_v10/OLv7_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y{next_year}/M{month:02d}'
        paths.append(path)
    
    # Initialize lists to store the returned values
    date_times = []
    obs_species_list = []
    obs_tilenum_list = []
    obs_lon_list = []
    obs_lat_list = []
    obs_obs_list = []
    obs_fcst_list = []
    obs_ana_list = []
    
    # Loop over the paths for the current year
    for path in paths:
        # Print the current path
        print("Current path:", path)

        # Call the read_obsfcstana function for the current path
        date_time, obs_species, obs_tilenum, obs_lon, obs_lat, obs_obs, obs_obsvar, obs_fcst, obs_fcstvar, obs_ana, obs_anavar = read_obsfcstana(path, file_name_start, printflag)
        
        # Append the returned values to the lists
        date_times.append(date_time)
        obs_species_list.append(obs_species)
        obs_tilenum_list.append(obs_tilenum)
        obs_lon_list.append(obs_lon)
        obs_lat_list.append(obs_lat)
        obs_obs_list.append(obs_obs)
        obs_fcst_list.append(obs_fcst)
        obs_ana_list.append(obs_ana)
    
    # Combine the returned values from all paths
    date_time_out = np.concatenate(date_times)
    obs_species_out = np.concatenate(obs_species_list)
    obs_tilenum_out = np.concatenate(obs_tilenum_list)
    obs_lon_out = np.concatenate(obs_lon_list)
    obs_lat_out = np.concatenate(obs_lat_list)
    obs_obs_out = np.concatenate(obs_obs_list)
    obs_fcst_out = np.concatenate(obs_fcst_list)
    obs_ana_out = np.concatenate(obs_ana_list)
    
    # Save the returned values to a file including the current year in the file name
    np.savez(f'OLv7_M36_obsfcstana_{current_year}.npz', date_time=date_time_out, obs_species=obs_species_out, obs_tilenum=obs_tilenum_out, obs_lon=obs_lon_out, obs_lat=obs_lat_out, obs_obs=obs_obs_out, obs_fcst=obs_fcst_out, obs_ana=obs_ana_out)

# %%
# Define the list of years
years = ['2015', '2016', '2017', '2018', '2019', '2020', '2021']

# Define the common file name start
file_name_start = 'DAv7_M36_ASCAT_type_2_fp_precip.ens_avg.ldas_ObsFcstAna.20'

# Define the print flag
printflag = False

# Loop over the years
for i in range(len(years)-1):
    # Define the current and next year
    current_year = years[i]
    next_year = years[i+1]
    # Define the list of paths
    paths = []
    for month in range(4, 13):
        path = f'/discover/nobackup/amfox/Experiments/DAv7_M36_ASCAT_type_2_fp_precip/DAv7_M36_ASCAT_type_2_fp_precip/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y{current_year}/M{month:02d}'
        paths.append(path)

    for month in range(1, 4):
        path = f'/discover/nobackup/amfox/Experiments/DAv7_M36_ASCAT_type_2_fp_precip/DAv7_M36_ASCAT_type_2_fp_precip/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y{next_year}/M{month:02d}'
        paths.append(path)
    
    # Initialize lists to store the returned values
    date_times = []
    obs_species_list = []
    obs_tilenum_list = []
    obs_lon_list = []
    obs_lat_list = []
    obs_obs_list = []
    obs_fcst_list = []
    obs_ana_list = []
    
    # Loop over the paths for the current year
    for path in paths:
        # Print the current path
        print("Current path:", path)

        # Call the read_obsfcstana function for the current path
        date_time, obs_species, obs_tilenum, obs_lon, obs_lat, obs_obs, obs_obsvar, obs_fcst, obs_fcstvar, obs_ana, obs_anavar = read_obsfcstana(path, file_name_start, printflag)
        
        # Append the returned values to the lists
        date_times.append(date_time)
        obs_species_list.append(obs_species)
        obs_tilenum_list.append(obs_tilenum)
        obs_lon_list.append(obs_lon)
        obs_lat_list.append(obs_lat)
        obs_obs_list.append(obs_obs)
        obs_fcst_list.append(obs_fcst)
        obs_ana_list.append(obs_ana)
    
    # Combine the returned values from all paths
    date_time_out = np.concatenate(date_times)
    obs_species_out = np.concatenate(obs_species_list)
    obs_tilenum_out = np.concatenate(obs_tilenum_list)
    obs_lon_out = np.concatenate(obs_lon_list)
    obs_lat_out = np.concatenate(obs_lat_list)
    obs_obs_out = np.concatenate(obs_obs_list)
    obs_fcst_out = np.concatenate(obs_fcst_list)
    obs_ana_out = np.concatenate(obs_ana_list)
    
    # Save the returned values to a file including the current year in the file name
    np.savez(f'DAv7_M36_ASCAT_type_2_fp_precip_obsfcstana_{current_year}.npz', date_time=date_time_out, obs_species=obs_species_out, obs_tilenum=obs_tilenum_out, obs_lon=obs_lon_out, obs_lat=obs_lat_out, obs_obs=obs_obs_out, obs_fcst=obs_fcst_out, obs_ana=obs_ana_out)

# %%
# Directory path to search for NetCDF files
root_directory = '/discover/nobackup/amfox/Experiments/DAv7_M36_ASCAT_type_2/DAv7_M36_ASCAT_type_2/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg'

# Initialize an empty list to store the calculated sfmc_increment values
sfmc_increment_list = []
rzmc_increment_list = []

# Recursively traverse the directory tree
for root, dirs, files in os.walk(root_directory):
    for filename in files:
        if filename.endswith('.nc4') and filename.startswith('DAv7_M36_ASCAT_type_2.inst3_1d_lndfcstana_Nt.2'):
            # Construct the full file path
            file_path = os.path.join(root, filename)
            
            # Open the NetCDF file using xarray
            ds = xr.open_dataset(file_path)
            
            # Extract the SFMC_ANA and SFMC_FCST variables
            sfmc_ana = ds['SFMC_ANA']
            sfmc_fcst = ds['SFMC_FCST']
            rzmc_ana = ds['RZMC_ANA']
            rzmc_fcst = ds['RZMC_FCST']
            
            # Calculate the sfmc_increment
            sfmc_increment = sfmc_ana - sfmc_fcst
            rzmc_increment = rzmc_ana - rzmc_fcst
            
            # Append the sfmc_increment values to the list
            sfmc_increment_list.append(sfmc_increment)
            rzmc_increment_list.append(rzmc_increment)
            
            # Close the NetCDF file
            ds.close()

# Concatenate the sfmc_increment values along the time dimension
sfmc_increment_concat = xr.concat(sfmc_increment_list, dim='time')
rzmc_increment_concat = xr.concat(rzmc_increment_list, dim='time')

# Save the concatenated sfmc_increment values to a new NetCDF file
sfmc_increment_concat.to_netcdf('DAv7_M36_ASCAT_type_2_sfmc_increments.nc')
rzmc_increment_concat.to_netcdf('DAv7_M36_ASCAT_type_2_rzmc_increments.nc')

# Calculate the mean sfmc_increment for each tile along the time dimension
mean_sfmc_increment = []
std_sfmc_increment = []
mean_rzmc_increment = []
std_rzmc_increment = []

for i in range(len(sfmc_increment_concat['tile'])):
    mean_sfmc_increment.append(np.mean(sfmc_increment_concat[:, i]))
    std_sfmc_increment.append(np.std(sfmc_increment_concat[:, i]))
    mean_rzmc_increment.append(np.mean(rzmc_increment_concat[:, i]))
    std_rzmc_increment.append(np.std(rzmc_increment_concat[:, i]))

# Save both the concatenated sfmc_increment and rzmc_increment values to a new npsavez file
np.savez('DAv7_M36_ASCAT_type_2_increments.npz', sfmc_increment=sfmc_increment_concat, rzmc_increment=rzmc_increment_concat, mean_sfmc_increment=mean_sfmc_increment, std_sfmc_increment=std_sfmc_increment, mean_rzmc_increment=mean_rzmc_increment, std_rzmc_increment=std_rzmc_increment)
np.savez('DAv7_M36_ASCAT_type_2_increment_stats.npz', mean_sfmc_increment=mean_sfmc_increment, std_sfmc_increment=std_sfmc_increment, mean_rzmc_increment=mean_rzmc_increment, std_rzmc_increment=std_rzmc_increment)

# %%
# Directory path to search for NetCDF files
root_directory = '/home/amfox/smap/SMAP_Nature/SMAP_Nature_v10/DAv7_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg'

# Initialize an empty list to store the calculated sfmc_increment values
sfmc_increment_list = []
rzmc_increment_list = []

# Recursively traverse the directory tree
for root, dirs, files in os.walk(root_directory):
    for filename in files:
        if filename.endswith('.nc4') and filename.startswith('DAv7_M36.inst3_1d_lndfcstana_Nt.2'):
            # Construct the full file path
            file_path = os.path.join(root, filename)
            
            # Open the NetCDF file using xarray
            ds = xr.open_dataset(file_path)
            
            # Extract the SFMC_ANA and SFMC_FCST variables
            sfmc_ana = ds['SFMC_ANA']
            sfmc_fcst = ds['SFMC_FCST']
            rzmc_ana = ds['RZMC_ANA']
            rzmc_fcst = ds['RZMC_FCST']
            
            # Calculate the sfmc_increment
            sfmc_increment = sfmc_ana - sfmc_fcst
            rzmc_increment = rzmc_ana - rzmc_fcst
            
            # Append the sfmc_increment values to the list
            sfmc_increment_list.append(sfmc_increment)
            rzmc_increment_list.append(rzmc_increment)
            
            # Close the NetCDF file
            ds.close()

# Concatenate the sfmc_increment values along the time dimension
sfmc_increment_concat = xr.concat(sfmc_increment_list, dim='time')
rzmc_increment_concat = xr.concat(rzmc_increment_list, dim='time')

# Save the concatenated sfmc_increment values to a new NetCDF file
sfmc_increment_concat.to_netcdf('DAv7_M36_sfmc_increments.nc')
rzmc_increment_concat.to_netcdf('DAv7_M36_rzmc_increments.nc')

# Calculate the mean sfmc_increment for each tile along the time dimension
mean_sfmc_increment = []
std_sfmc_increment = []
mean_rzmc_increment = []
std_rzmc_increment = []

for i in range(len(sfmc_increment_concat['tile'])):
    mean_sfmc_increment.append(np.mean(sfmc_increment_concat[:, i]))
    std_sfmc_increment.append(np.std(sfmc_increment_concat[:, i]))
    mean_rzmc_increment.append(np.mean(rzmc_increment_concat[:, i]))
    std_rzmc_increment.append(np.std(rzmc_increment_concat[:, i]))

# Save both the concatenated sfmc_increment and rzmc_increment values to a new npsavez file
np.savez('DAv7_M36_increments.npz', sfmc_increment=sfmc_increment_concat, rzmc_increment=rzmc_increment_concat, mean_sfmc_increment=mean_sfmc_increment, std_sfmc_increment=std_sfmc_increment, mean_rzmc_increment=mean_rzmc_increment, std_rzmc_increment=std_rzmc_increment)
np.savez('DAv7_M36_increment_stats.npz', mean_sfmc_increment=mean_sfmc_increment, std_sfmc_increment=std_sfmc_increment, mean_rzmc_increment=mean_rzmc_increment, std_rzmc_increment=std_rzmc_increment)

# %%
# Directory path to search for NetCDF files
root_directory = '/discover/nobackup/amfox/Experiments/smap_ascat_multivariate_test/smap_ascat_multivariate_test/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg'

# Initialize an empty list to store the calculated sfmc_increment values
sfmc_increment_list = []
rzmc_increment_list = []

# Recursively traverse the directory tree
for root, dirs, files in os.walk(root_directory):
    for filename in files:
        if filename.endswith('.nc4') and filename.startswith('smap_ascat_multivariate_test.inst3_1d_lndfcstana_Nt.2'):
            # Construct the full file path
            file_path = os.path.join(root, filename)
            
            # Open the NetCDF file using xarray
            ds = xr.open_dataset(file_path)
            
            # Extract the SFMC_ANA and SFMC_FCST variables
            sfmc_ana = ds['SFMC_ANA']
            sfmc_fcst = ds['SFMC_FCST']
            rzmc_ana = ds['RZMC_ANA']
            rzmc_fcst = ds['RZMC_FCST']
            
            # Calculate the sfmc_increment
            sfmc_increment = sfmc_ana - sfmc_fcst
            rzmc_increment = rzmc_ana - rzmc_fcst
            
            # Append the sfmc_increment values to the list
            sfmc_increment_list.append(sfmc_increment)
            rzmc_increment_list.append(rzmc_increment)
            
            # Close the NetCDF file
            ds.close()

# Concatenate the sfmc_increment values along the time dimension
sfmc_increment_concat = xr.concat(sfmc_increment_list, dim='time')
rzmc_increment_concat = xr.concat(rzmc_increment_list, dim='time')

# Save the concatenated sfmc_increment values to a new NetCDF file
sfmc_increment_concat.to_netcdf('smap_ascat_multivariate_test_sfmc_increments.nc')
rzmc_increment_concat.to_netcdf('smap_ascat_multivariate_test_rzmc_increments.nc')

# Calculate the mean sfmc_increment for each tile along the time dimension
mean_sfmc_increment = []
std_sfmc_increment = []
mean_rzmc_increment = []
std_rzmc_increment = []

for i in range(len(sfmc_increment_concat['tile'])):
    mean_sfmc_increment.append(np.mean(sfmc_increment_concat[:, i]))
    std_sfmc_increment.append(np.std(sfmc_increment_concat[:, i]))
    mean_rzmc_increment.append(np.mean(rzmc_increment_concat[:, i]))
    std_rzmc_increment.append(np.std(rzmc_increment_concat[:, i]))

# Save both the concatenated sfmc_increment and rzmc_increment values to a new npsavez file
np.savez('smap_ascat_multivariate_test_increments.npz', sfmc_increment=sfmc_increment_concat, rzmc_increment=rzmc_increment_concat, mean_sfmc_increment=mean_sfmc_increment, std_sfmc_increment=std_sfmc_increment, mean_rzmc_increment=mean_rzmc_increment, std_rzmc_increment=std_rzmc_increment)
np.savez('smap_ascat_multivariate_test_increment_stats.npz', mean_sfmc_increment=mean_sfmc_increment, std_sfmc_increment=std_sfmc_increment, mean_rzmc_increment=mean_rzmc_increment, std_rzmc_increment=std_rzmc_increment)

# %%
# Directory path to search for NetCDF files
root_directory = '/discover/nobackup/amfox/Experiments/DAv7_M36_ASCAT_type_2_fp_precip/DAv7_M36_ASCAT_type_2_fp_precip/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg'

# Initialize an empty list to store the calculated sfmc_increment values
sfmc_increment_list = []
rzmc_increment_list = []

# Recursively traverse the directory tree
for root, dirs, files in os.walk(root_directory):
    for filename in files:
        if filename.endswith('.nc4') and filename.startswith('DAv7_M36_ASCAT_type_2_fp_precip.inst3_1d_lndfcstana_Nt.2'):
            # Construct the full file path
            file_path = os.path.join(root, filename)
            
            # Open the NetCDF file using xarray
            ds = xr.open_dataset(file_path)
            
            # Extract the SFMC_ANA and SFMC_FCST variables
            sfmc_ana = ds['SFMC_ANA']
            sfmc_fcst = ds['SFMC_FCST']
            rzmc_ana = ds['RZMC_ANA']
            rzmc_fcst = ds['RZMC_FCST']
            
            # Calculate the sfmc_increment
            sfmc_increment = sfmc_ana - sfmc_fcst
            rzmc_increment = rzmc_ana - rzmc_fcst
            
            # Append the sfmc_increment values to the list
            sfmc_increment_list.append(sfmc_increment)
            rzmc_increment_list.append(rzmc_increment)
            
            # Close the NetCDF file
            ds.close()

# Concatenate the sfmc_increment values along the time dimension
sfmc_increment_concat = xr.concat(sfmc_increment_list, dim='time')
rzmc_increment_concat = xr.concat(rzmc_increment_list, dim='time')

# Save the concatenated sfmc_increment values to a new NetCDF file
sfmc_increment_concat.to_netcdf('DAv7_M36_ASCAT_type_2_fp_precip_sfmc_increments.nc')
rzmc_increment_concat.to_netcdf('DAv7_M36_ASCAT_type_2_fp_precip_rzmc_increments.nc')

# Calculate the mean sfmc_increment for each tile along the time dimension
mean_sfmc_increment = []
std_sfmc_increment = []
mean_rzmc_increment = []
std_rzmc_increment = []

for i in range(len(sfmc_increment_concat['tile'])):
    mean_sfmc_increment.append(np.mean(sfmc_increment_concat[:, i]))
    std_sfmc_increment.append(np.std(sfmc_increment_concat[:, i]))
    mean_rzmc_increment.append(np.mean(rzmc_increment_concat[:, i]))
    std_rzmc_increment.append(np.std(rzmc_increment_concat[:, i]))

# Save both the concatenated sfmc_increment and rzmc_increment values to a new npsavez file
np.savez('DAv7_M36_ASCAT_type_2_fp_precip_increments.npz', sfmc_increment=sfmc_increment_concat, rzmc_increment=rzmc_increment_concat, mean_sfmc_increment=mean_sfmc_increment, std_sfmc_increment=std_sfmc_increment, mean_rzmc_increment=mean_rzmc_increment, std_rzmc_increment=std_rzmc_increment)
np.savez('DAv7_M36_ASCAT_type_2_fp_precip_increment_stats.npz', mean_sfmc_increment=mean_sfmc_increment, std_sfmc_increment=std_sfmc_increment, mean_rzmc_increment=mean_rzmc_increment, std_rzmc_increment=std_rzmc_increment)
