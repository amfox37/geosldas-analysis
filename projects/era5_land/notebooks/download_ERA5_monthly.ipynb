# %%
# era5_monthly_download.py
import cdsapi, time, os, xarray as xr

# %%
DATASET = "reanalysis-era5-single-levels-monthly-means"

# These variable strings should work the same way in CDS for ERA5 monthly means.
VARS = [
    "soil_temperature_level_1",
    "snow_depth",
    "snow_density",
    "volumetric_soil_water_layer_1",
    "volumetric_soil_water_layer_2",
    "volumetric_soil_water_layer_3",
]
YEARS = list(range(2000, 2024))  # edit as needed
MONTHS = [f"{m:02d}" for m in range(1, 13)]

# Optional: subset to a region (N, W, S, E). Comment out 'area' to get global.
AREA = None  # e.g., [60, -130, 20, -60]

# (optional) rename output dir so you don't mix products
OUT_DIR = "era5_monthly_nc"
os.makedirs(OUT_DIR, exist_ok=True)

# %%
def retrieve_year(year, attempt=1, max_attempts=5):
    c = cdsapi.Client(timeout=600)
    req = {
        "product_type": "monthly_averaged_reanalysis",
        "variable": VARS,
        "year": f"{year}",
        "month": MONTHS,
        "time": "00:00",      # monthly means carry a nominal time
        "data_format": "netcdf",   # CDS supports NetCDF for many ERA5 requests
        # Optional: force grid (ERA5 monthly means are commonly delivered on 0.25°)
        # "grid": [0.25, 0.25],
    }
    if AREA:
        req["area"] = AREA    # N, W, S, E (CDS order)

    target = os.path.join(OUT_DIR, f"era5_monthly_{year}.nc")
    if os.path.exists(target):
        print(f"[skip] {target} exists.")
        return target

    try:
        print(f"[CDS] Requesting {year} ...")
        c.retrieve(DATASET, req, target)
        print(f"[ok] Wrote {target}")
        return target
    except Exception as e:
        if attempt < max_attempts:
            wait = 30 * attempt
            print(f"[warn] {e}\nRetrying year {year} in {wait}s (attempt {attempt+1}/{max_attempts})")
            time.sleep(wait)
            return retrieve_year(year, attempt+1, max_attempts)
        raise

# %%
# 1) retrieve year-by-year
paths = [retrieve_year(y) for y in YEARS]
# Out:
# [CDS] Requesting 2000 ...
# 2026-01-25 12:50:28,855 INFO Request ID is 5f8412c9-7de3-438b-b403-b9a294153a50
# 2026-01-25 12:50:29,066 INFO status has been updated to accepted
# 2026-01-25 12:50:43,317 INFO status has been updated to running
# 2026-01-25 12:51:02,822 INFO status has been updated to successful
# [ok] Wrote era5_monthly_nc/era5_monthly_2000.nc
# [CDS] Requesting 2001 ...
# 2026-01-25 12:51:27,411 INFO Request ID is 9733ecec-71e0-4fb0-b7d8-275a7ad27876
# 2026-01-25 12:51:27,614 INFO status has been updated to accepted
# 2026-01-25 12:51:41,823 INFO status has been updated to running
# 2026-01-25 12:52:01,254 INFO status has been updated to successful
# [ok] Wrote era5_monthly_nc/era5_monthly_2001.nc
# [CDS] Requesting 2002 ...
# 2026-01-25 12:52:20,669 INFO Request ID is 0b2ae816-472a-49af-ab61-e19e0e2a247f
# 2026-01-25 12:52:20,939 INFO status has been updated to accepted
# 2026-01-25 12:52:42,959 INFO status has been updated to running
# 2026-01-25 12:52:54,559 INFO status has been updated to successful
# [ok] Wrote era5_monthly_nc/era5_monthly_2002.nc
# [CDS] Requesting 2003 ...
# 2026-01-25 12:53:15,857 INFO Request ID is 26f7d019-bee7-4984-a6ce-e372b21bf2a9
# 2026-01-25 12:53:16,051 INFO status has been updated to accepted
# 2026-01-25 12:53:30,251 INFO status has been updated to running
# 2026-01-25 12:53:49,675 INFO status has been updated to successful
# [ok] Wrote era5_monthly_nc/era5_monthly_2003.nc
# [CDS] Requesting 2004 ...
# 2026-01-25 12:54:10,235 INFO Request ID is 307f11d8-abf3-42f3-8c2e-da36e93cf1be
# 2026-01-25 12:54:10,438 INFO status has been updated to accepted
# 2026-01-25 12:54:19,395 INFO status has been updated to running
# 2026-01-25 12:54:32,610 INFO status has been updated to successful
# [ok] Wrote era5_monthly_nc/era5_monthly_
INFO status has been updated to successful
# [ok] Wrote era5_monthly_nc/era5_monthly_2015.nc
# [CDS] Requesting 2016 ...
# 2026-01-25 13:05:47,550 INFO Request ID is 0729b8aa-b6d3-4fef-adb5-522271a91473
# 2026-01-25 13:05:47,751 INFO status has been updated to accepted
# 2026-01-25 13:06:02,061 INFO status has been updated to running
# 2026-01-25 13:06:09,854 INFO status has been updated to successful
# [ok] Wrote era5_monthly_nc/era5_monthly_2016.nc
# [CDS] Requesting 2017 ...
# 2026-01-25 13:06:39,727 INFO Request ID is fd3a0c59-d4eb-4d95-8846-f46521fead3a
# 2026-01-25 13:06:39,928 INFO status has been updated to accepted
# 2026-01-25 13:06:54,328 INFO status has been updated to running
# 2026-01-25 13:07:13,708 INFO status has been updated to successful
# [ok] Wrote era5_monthly_nc/era5_monthly_2017.nc
# [CDS] Requesting 2018 ...
# 2026-01-25 13:07:38,565 INFO Request ID is 2c5d5846-f6ea-4ebb-858f-eb298867238a
# 2026-01-25 13:07:38,763 INFO status has been updated to accepted
# 2026-01-25 13:07:47,763 INFO status has been updated to running
# 2026-01-25 13:08:00,839 INFO status has been updated to successful
# [ok] Wrote era5_monthly_nc/era5_monthly_2018.nc
# [CDS] Requesting 2019 ...
# 2026-01-25 13:08:22,230 INFO Request ID is 6ff62019-2355-436a-a65c-bc6d46cd0656
# 2026-01-25 13:08:22,412 INFO status has been updated to accepted
# 2026-01-25 13:08:36,609 INFO status has been updated to running
# 2026-01-25 13:08:56,016 INFO status has been updated to successful
# [ok] Wrote era5_monthly_nc/era5_monthly_2019.nc
# [CDS] Requesting 2020 ...
# 2026-01-25 13:09:16,656 INFO Request ID is 9cfc0186-dcfe-4dff-905c-7d56be9fda27
# 2026-01-25 13:09:16,853 INFO status has been updated to accepted
# 2026-01-25 13:09:25,827 INFO status has been updated to running
# 2026-01-25 13:09:50,607 INFO status has been updated to successful
# [ok] Wrote era5_monthly_nc/era5_monthly_2020.nc
# [CDS] Requesting 2021 ...
# 2026-01-25 13:10:09,805 INFO Request ID is 61f89a85-77c7-4b51-8be4-564a618f65c8
# 2026-01-25 13:10:10,005 INFO status has been updated to accepted
# 2026-01-25 13:10:18,923 INFO status has been updated to running
# 2026-01-25 13:10:43,603 INFO status has been updated to successful
# [ok] Wrote era5_monthly_nc/era5_monthly_2021.nc
# [CDS] Requesting 2022 ...
# 2026-01-25 13:11:00,742 INFO Request ID is b2bb434c-3eea-4232-8978-20296976722a
# 2026-01-25 13:11:00,925 INFO status has been updated to accepted
# 2026-01-25 13:11:15,201 INFO status has been updated to running
# 2026-01-25 13:11:34,604 INFO status has been updated to successful
# [ok] Wrote era5_monthly_nc/era5_monthly_2022.nc
# [CDS] Requesting 2023 ...
# 2026-01-25 13:11:48,987 INFO Request ID is 7917bc55-00ca-424f-a902-1825f1ee376d
# 2026-01-25 13:11:49,182 INFO status has been updated to accepted
# 2026-01-25 13:12:03,520 INFO status has been updated to running
# 2026-01-25 13:12:22,893 INFO status has been updated to successful
# [ok] Wrote era5_monthly_nc/era5_monthly_2023.nc

# %% [markdown]
# # Optional alternative merge: `cdo -O mergetime era5_monthly_*.nc era5_monthly_merged.nc`

# %%
# 2) merge to a single file
print("[merge] Concatenating yearly NetCDFs ...")
dsets = [xr.open_dataset(p) for p in paths]
ds = xr.concat(dsets, dim="time")
for d in dsets:
    d.close()

# 3) write one consolidated file
out_all = os.path.join(OUT_DIR, f"era5_monthly_{YEARS[0]}_{YEARS[-1]}.nc")
encoding = {v: {"zlib": True, "complevel": 4} for v in ds.data_vars}
encoding.update({c: {"zlib": True, "complevel": 4} for c in ["latitude", "longitude"] if c in ds.coords})
ds.to_netcdf(out_all, encoding=encoding)
print(f"[done] {out_all}")

# %%
# 4) quick sanity check
print("Variables:", list(ds.data_vars))
print("Time span:", str(ds['time'].values[0])[:10], "to", str(ds['time'].values[-1])[:10])
print("Grid:", ds.sizes.get('latitude', None), "x", ds.sizes.get('longitude', None))
