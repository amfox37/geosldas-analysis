# %%
# era5land_monthly_download.py
import cdsapi, time, os, xarray as xr

# %%
DATASET = "reanalysis-era5-land-monthly-means"
# VARS = [
#     "soil_temperature_level_1",
#     "snow_cover",
#     "volumetric_soil_water_layer_1",
#     "volumetric_soil_water_layer_2",
#     "volumetric_soil_water_layer_3",
# ]
VARS = [
    "snow_depth",                         # <-- NEW
    "snow_depth_water_equivalent",        # <-- NEW (SWE)
]
YEARS = list(range(2000, 2026))  # edit as needed
MONTHS = [f"{m:02d}" for m in range(1,13)]

# Optional: subset to a region (N, W, S, E). Comment out 'area' to get global.
AREA = None  # e.g., [90, -180, -90, 180] for global; or [60, -130, 20, -60] (CONUS-ish)

OUT_DIR = "era5l_monthly_snow_nc"
os.makedirs(OUT_DIR, exist_ok=True)

# %%
def retrieve_year(year, attempt=1, max_attempts=5):
    c = cdsapi.Client(timeout=600)
    req = {
        "product_type": "monthly_averaged_reanalysis",
        "variable": VARS,
        "year": f"{year}",
        "month": MONTHS,
        "time": "00:00",           # monthly means carry a nominal time
        "format": "netcdf",        # NetCDF out
    }
    if AREA:
        req["area"] = AREA        # N, W, S, E (CDS order)
    target = os.path.join(OUT_DIR, f"era5l_monthly_{year}.nc")
    if os.path.exists(target):
        print(f"[skip] {target} exists.")
        return target
    try:
        print(f"[CDS] Requesting {year} ...")
        c.retrieve(DATASET, req, target)
        print(f"[ok] Wrote {target}")
        return target
    except Exception as e:
        if attempt < max_attempts:
            wait = 30 * attempt
            print(f"[warn] {e}\nRetrying year {year} in {wait}s (attempt {attempt+1}/{max_attempts})")
            time.sleep(wait)
            return retrieve_year(year, attempt+1, max_attempts)
        raise

# %%
# 1) retrieve year-by-year
paths = [retrieve_year(y) for y in YEARS]
# Out:
# [CDS] Requesting 2000 ...
# 2026-04-01 15:02:24,661 INFO Request ID is c7c43e03-8d92-4aa6-b6a4-bec3870e4d92
# 2026-04-01 15:02:24,843 INFO status has been updated to accepted
# 2026-04-01 15:02:33,768 INFO status has been updated to running
# 2026-04-01 15:02:58,352 INFO status has been updated to successful
# [ok] Wrote era5l_monthly_snow_nc/era5l_monthly_2000.nc
# [CDS] Requesting 2001 ...
# 2026-04-01 15:03:08,524 INFO Request ID is 12121c82-530a-4cfc-9258-e197c76fb9be
# 2026-04-01 15:03:08,702 INFO status has been updated to accepted
# 2026-04-01 15:03:17,571 INFO status has been updated to running
# 2026-04-01 15:03:42,171 INFO status has been updated to successful
# [ok] Wrote era5l_monthly_snow_nc/era5l_monthly_2001.nc
# [CDS] Requesting 2002 ...
# 2026-04-01 15:03:54,210 INFO Request ID is 2b9b40d0-7c3a-44bf-bb0b-8805e22491d7
# 2026-04-01 15:03:54,376 INFO status has been updated to accepted
# 2026-04-01 15:04:08,556 INFO status has been updated to running
# 2026-04-01 15:04:28,103 INFO status has been updated to successful
# [ok] Wrote era5l_monthly_snow_nc/era5l_monthly_2002.nc
# [CDS] Requesting 2003 ...
# 2026-04-01 15:04:38,226 INFO Request ID is 7dced405-1a90-4e84-be84-298ffe6a55f1
# 2026-04-01 15:04:38,402 INFO status has been updated to accepted
# 2026-04-01 15:04:47,221 INFO status has been updated to running
# 2026-04-01 15:05:11,946 INFO status has been updated to successful
# [ok] Wrote era5l_monthly_snow_nc/era5l_monthly_2003.nc
# [CDS] Requesting 2004 ...
# 2026-04-01 15:05:23,868 INFO Request ID is 9fca589c-215e-4076-89ae-8960078c1489
# 2026-04-01 15:05:24,035 INFO status has been updated to accepted
# 2026-04-01 15:05:38,150 INFO status has been updated to running
# 2026-04-01 15:05:57,485 INFO status has been updated to successful
# [ok] Wrote era5l_monthly_snow_nc/era5l_monthly_2004.nc
# [CDS] Requesting 2005 ...
# 2026-04-01 15:06:11,044 INFO Request ID is 3d797b7f-d5f5-45fa-a8d5-d7848a5eed5b
# 2026-04-01 15:06:11,215 INFO status has been updated to accepted
# 2026-04-01 15:06:25,334 INFO status has been updated to running
# 2026-04-01 15:06:44,933 INFO status has been updated to successful
# [ok] Wrote era5l_monthly_snow_nc/era5l_monthly_
INFO status has been updated to successful
# [ok] Wrote era5l_monthly_snow_nc/era5l_monthly_2017.nc
# [CDS] Requesting 2018 ...
# 2026-04-01 15:16:36,620 INFO Request ID is 31fb28ab-791b-4bd6-a967-9ceb4d482b7d
# 2026-04-01 15:16:36,787 INFO status has been updated to accepted
# 2026-04-01 15:16:45,611 INFO status has been updated to running
# 2026-04-01 15:17:10,210 INFO status has been updated to successful
# [ok] Wrote era5l_monthly_snow_nc/era5l_monthly_2018.nc
# [CDS] Requesting 2019 ...
# 2026-04-01 15:17:22,499 INFO Request ID is acdf3691-cb43-406a-9c16-713200da4e78
# 2026-04-01 15:17:22,683 INFO status has been updated to accepted
# 2026-04-01 15:17:36,766 INFO status has been updated to running
# 2026-04-01 15:17:56,107 INFO status has been updated to successful
# [ok] Wrote era5l_monthly_snow_nc/era5l_monthly_2019.nc
# [CDS] Requesting 2020 ...
# 2026-04-01 15:18:08,949 INFO Request ID is 98149559-8e43-4728-9584-2ca9cd60e367
# 2026-04-01 15:18:09,128 INFO status has been updated to accepted
# 2026-04-01 15:18:18,034 INFO status has been updated to running
# 2026-04-01 15:18:25,147 INFO status has been updated to accepted
# 2026-04-01 15:18:32,922 INFO status has been updated to running
# 2026-04-01 15:19:01,773 INFO status has been updated to successful
# [ok] Wrote era5l_monthly_snow_nc/era5l_monthly_2020.nc
# [CDS] Requesting 2021 ...
# 2026-04-01 15:19:09,668 INFO Request ID is f074fa87-64de-4522-975f-915e8709b9e5
# 2026-04-01 15:19:09,844 INFO status has been updated to accepted
# 2026-04-01 15:19:23,954 INFO status has been updated to running
# 2026-04-01 15:19:43,321 INFO status has been updated to successful
# [ok] Wrote era5l_monthly_snow_nc/era5l_monthly_2021.nc
# [CDS] Requesting 2022 ...
# 2026-04-01 15:19:57,274 INFO Request ID is 309d41e7-f9d2-4d1d-91b3-ad4146761d1f
# 2026-04-01 15:19:57,445 INFO status has been updated to accepted
# 2026-04-01 15:20:11,689 INFO status has been updated to running
# 2026-04-01 15:20:31,029 INFO status has been updated to successful
# [ok] Wrote era5l_monthly_snow_nc/era5l_monthly_2022.nc
# [CDS] Requesting 2023 ...
# 2026-04-01 15:20:41,132 INFO Request ID is b80498c3-8af8-4ca8-bd2b-0f06ce773cb3
# 2026-04-01 15:20:41,310 INFO status has been updated to accepted
# 2026-04-01 15:20:50,145 INFO status has been updated to running
# 2026-04-01 15:21:14,732 INFO status has been updated to successful
# [ok] Wrote era5l_monthly_snow_nc/era5l_monthly_2023.nc
# [CDS] Requesting 2024 ...
# 2026-04-01 15:21:25,276 INFO Request ID is ed87e244-7c21-4271-82a5-ca938f5a6f50
# 2026-04-01 15:21:25,447 INFO status has been updated to accepted
# 2026-04-01 15:21:39,574 INFO status has been updated to running
# 2026-04-01 15:21:58,920 INFO status has been updated to successful
# [ok] Wrote era5l_monthly_snow_nc/era5l_monthly_2024.nc
# [CDS] Requesting 2025 ...
# 2026-04-01 15:22:08,243 INFO Request ID is cc5ad067-228b-45c1-bea3-5640ebbf7985
# 2026-04-01 15:22:08,404 INFO status has been updated to accepted
# 2026-04-01 15:22:22,500 INFO status has been updated to running
# 2026-04-01 15:22:41,861 INFO status has been updated to successful
# [ok] Wrote era5l_monthly_snow_nc/era5l_monthly_2025.nc

# %% [markdown]
# # Command to use to merge: cdo -O mergetime era5l_monthly_*_unzipped.nc ERA5L_monthly_merged.nc

# %%
# 2) merge to a single file (preserves CF, times)
print("[merge] Concatenating yearly NetCDFs ...")
dsets = [xr.open_dataset(p) for p in paths]
ds = xr.concat(dsets, dim="time")
for d in dsets: d.close()

# 3) (optional) ensure variable names are exactly what you expect
# (They already are in ERA5-Land monthly means.)
# print(list(ds.data_vars))

# 4) write one consolidated file
out_all = os.path.join(OUT_DIR, f"era5l_monthly_{YEARS[0]}_{YEARS[-1]}.nc")
encoding = {v: {"zlib": True, "complevel": 4} for v in ds.data_vars}
encoding.update({c: {"zlib": True, "complevel": 4} for c in ["latitude","longitude"] if c in ds.coords})
ds.to_netcdf(out_all, encoding=encoding)
print(f"[done] {out_all}")
