# %%
# --- Setup: file paths and cache options ---

from pathlib import Path
import sys
import numpy as np
import xarray as xr

REPO_ROOT = Path.cwd().resolve()
if not (REPO_ROOT / "common/python/plotting/geospatial_plotting.py").exists():
    for parent in REPO_ROOT.parents:
        if (parent / "common/python/plotting/geospatial_plotting.py").exists():
            REPO_ROOT = parent
            break
sys.path.insert(0, str(REPO_ROOT / "common/python/plotting"))

from geospatial_plotting import plot_region, REGION_BOUNDS

FN_DA = str(REPO_ROOT / "projects/era5_land/notebooks/ERA5L_vs_DAv8_M36_strict_summary.nc")
FN_OL = str(REPO_ROOT / "projects/era5_land/notebooks/ERA5L_vs_OLv8_M36_strict_summary.nc")
out_csv = "ERA5_Land_periodized_metrics_summary.csv"
RUN_LAND_VS_ERA5 = True

# FN_DA = str(REPO_ROOT / "ERA5_vs_DAv8_M36_summary.nc")  # optional ERA5 reference
# FN_OL = str(REPO_ROOT / "ERA5_vs_OLv8_M36_summary.nc")  # optional ERA5 reference
# out_csv = "ERA5_Land_periodized_metrics_summary.csv"

# Cache controls for periodized metric recomputation
USE_CACHE = True
REBUILD_CACHE = False   # set True to force recompute and overwrite cache
CACHE_DIR = REPO_ROOT / "projects/era5_land/cache/era5_periodized_metrics"
CACHE_DIR.mkdir(parents=True, exist_ok=True)

metrics = ['anomR_sfc', 'ubRMSE_sfc', 'anomR_rz', 'ubRMSE_rz', 'anomR_scf', 'ubRMSE_scf', 'anomR_swe', 'ubRMSE_swe', 'anomR_snwd', 'ubRMSE_snwd']

# %%
def anomalies_monthly(da, dim="time"):
    """
    Monthly anomalies: remove month-of-year climatology (NaN-safe).
    """
    clim = da.groupby(f"{dim}.month").mean(dim=dim, skipna=True)
    return da.groupby(f"{dim}.month") - clim

def anom_metrics_monthly(a, b, dim="time", min_pairs=24):
    """
    NaN-safe anomR and ubRMSE on valid pairs only.
    Enforces a minimum number of valid pairs (default 24 months).
    """
    valid = xr.where(xr.ufuncs.isfinite(a) & xr.ufuncs.isfinite(b), True, False)
    n = valid.sum(dim=dim)

    a_v = a.where(valid)
    b_v = b.where(valid)

    cov   = (a_v * b_v).mean(dim=dim, skipna=True)
    var_a = (a_v**2).mean(dim=dim, skipna=True)
    var_b = (b_v**2).mean(dim=dim, skipna=True)

    denom = xr.ufuncs.sqrt(var_a * var_b)
    anomR  = xr.where(denom > 0, cov / denom, np.nan)
    ubRMSE = xr.ufuncs.sqrt(((a_v - b_v)**2).mean(dim=dim, skipna=True))

    # require enough valid months
    anomR  = xr.where(n >= min_pairs, anomR, np.nan)
    ubRMSE = xr.where(n >= min_pairs, ubRMSE, np.nan)
    return anomR, ubRMSE

def corr_monthly(a, b, dim="time", min_pairs=24):
    """
    Pearson R on raw monthly series (no anomaly removal).
    NaN-safe; requires at least `min_pairs` valid months.
    """
    valid = xr.where(xr.ufuncs.isfinite(a) & xr.ufuncs.isfinite(b), True, False)
    n = valid.sum(dim=dim)

    a_v = a.where(valid)
    b_v = b.where(valid)

    # remove means over time (on valid pairs only)
    a_dm = a_v - a_v.mean(dim=dim, skipna=True)
    b_dm = b_v - b_v.mean(dim=dim, skipna=True)

    cov   = (a_dm * b_dm).mean(dim=dim, skipna=True)
    var_a = (a_dm**2).mean(dim=dim, skipna=True)
    var_b = (b_dm**2).mean(dim=dim, skipna=True)

    denom = xr.ufuncs.sqrt(var_a * var_b)
    R = xr.where(denom > 0, cov / denom, np.nan)

    # require enough valid months
    R = xr.where(n >= min_pairs, R, np.nan)
    return R

def rmse_bias_monthly(a, b, dim="time", min_pairs=24):
    """
    NaN-safe RMSE and bias on raw monthly series (valid pairs only).
    Requires at least `min_pairs` valid months.
    """
    valid = xr.where(xr.ufuncs.isfinite(a) & xr.ufuncs.isfinite(b), True, False)
    n = valid.sum(dim=dim)

    a_v = a.where(valid)
    b_v = b.where(valid)
    diff = a_v - b_v

    rmse = xr.ufuncs.sqrt((diff**2).mean(dim=dim, skipna=True))
    bias = diff.mean(dim=dim, skipna=True)

    rmse = xr.where(n >= min_pairs, rmse, np.nan)
    bias = xr.where(n >= min_pairs, bias, np.nan)
    return rmse, bias

# %%
# --- Recompute monthly anomaly metrics over limited time periods ---
# Reuses: anomalies_monthly(), anom_metrics_monthly()

import numpy as np
import xarray as xr
import pandas as pd

# Files to process (do one or both)
FILES = [
    FN_DA,
    FN_OL,
]

# Sub-periods (inclusive)
PERIODS = [
    ("2000-06-01", "2007-05-31"),
    ("2007-06-01", "2015-03-31"),
    ("2015-04-01", "2024-05-31"),
    ("2000-06-01", "2024-05-31"),
]

MIN_PAIRS = 24  # minimum valid months for metrics

def compute_metrics_for_period(ds, t0, t1, min_pairs=24, snow_eps=0.01):
    import xarray as xr
    import numpy as np
    import pandas as pd

    sub = xr.decode_cf(ds).sel(time=slice(pd.to_datetime(t0), pd.to_datetime(t1)))

    for v in ["SM_model","SM_era","SCF_model","SCF_era"]:
        if v not in sub:
            raise KeyError(f"Required variable '{v}' missing from dataset.")

    mask_both = sub["mask_both"] if "mask_both" in sub else xr.full_like(sub["SM_model"], True, dtype=bool)

    # ----- Surface SM -----
    sm_mod_raw = sub["SM_model"].where(mask_both).astype("float64")
    sm_era_raw = sub["SM_era"  ].where(mask_both).astype("float64")

    # anomalies → anomR & ubRMSE (unchanged)
    sm_mod_an = anomalies_monthly(sm_mod_raw)
    sm_era_an = anomalies_monthly(sm_era_raw)
    anomR_sfc, ubRMSE_sfc = anom_metrics_monthly(sm_mod_an, sm_era_an, min_pairs=min_pairs)

    # raw correlation R
    R_sfc = corr_monthly(sm_mod_raw, sm_era_raw, min_pairs=min_pairs)

    # ----- Root-zone SM (if present) -----
    if ("RZ_model" in sub) and ("RZ_era" in sub):
        rz_mod_raw = sub["RZ_model"].where(mask_both).astype("float64")
        rz_era_raw = sub["RZ_era"  ].where(mask_both).astype("float64")

        rz_mod_an = anomalies_monthly(rz_mod_raw)
        rz_era_an = anomalies_monthly(rz_era_raw)
        anomR_rz,  ubRMSE_rz  = anom_metrics_monthly(rz_mod_an, rz_era_an, min_pairs=min_pairs)
        R_rz = corr_monthly(rz_mod_raw, rz_era_raw, min_pairs=min_pairs)
    else:
        anomR_rz  = xr.full_like(anomR_sfc, np.nan)
        ubRMSE_rz = xr.full_like(ubRMSE_sfc, np.nan)
        R_rz      = xr.full_like(anomR_sfc, np.nan)

    # ----- SCF (ever-snow mask over FULL record) -----
    snow_any  = ((ds["SCF_model"] > snow_eps) | (ds["SCF_era"] > snow_eps)).any(dim="time")
    snow_mask = xr.where(snow_any, True, False)

    scf_mod_raw = sub["SCF_model"].where(snow_mask).astype("float64")
    scf_era_raw = sub["SCF_era"  ].where(snow_mask).astype("float64")

    scf_mod_an = anomalies_monthly(scf_mod_raw)
    scf_era_an = anomalies_monthly(scf_era_raw)
    anomR_scf,  ubRMSE_scf = anom_metrics_monthly(scf_mod_an, scf_era_an, min_pairs=min_pairs)
    R_scf = corr_monthly(scf_mod_raw, scf_era_raw, min_pairs=min_pairs)
    rmse_scf, bias_scf = rmse_bias_monthly(scf_mod_raw, scf_era_raw, min_pairs=min_pairs)

    # ----- SWE (optional; use ever-snow mask) -----
    if ("SWE_model" in sub) and ("SWE_era" in sub):
        swe_mod_raw = sub["SWE_model"].where(snow_mask).astype("float64")
        swe_era_raw = sub["SWE_era"  ].where(snow_mask).astype("float64")

        swe_mod_an = anomalies_monthly(swe_mod_raw)
        swe_era_an = anomalies_monthly(swe_era_raw)
        anomR_swe, ubRMSE_swe = anom_metrics_monthly(swe_mod_an, swe_era_an, min_pairs=min_pairs)
        R_swe = corr_monthly(swe_mod_raw, swe_era_raw, min_pairs=min_pairs)
        rmse_swe, bias_swe = rmse_bias_monthly(swe_mod_raw, swe_era_raw, min_pairs=min_pairs)
    else:
        anomR_swe = xr.full_like(anomR_sfc, np.nan)
        ubRMSE_swe = xr.full_like(ubRMSE_sfc, np.nan)
        R_swe = xr.full_like(anomR_sfc, np.nan)
        rmse_swe = xr.full_like(ubRMSE_sfc, np.nan)
        bias_swe = xr.full_like(anomR_sfc, np.nan)

    # ----- Snow depth (optional; use ever-snow mask) -----
    if ("SNWD_model" in sub) and ("SNWD_era" in sub):
        snwd_mod_raw = sub["SNWD_model"].where(snow_mask).astype("float64")
        snwd_era_raw = sub["SNWD_era"  ].where(snow_mask).astype("float64")

        snwd_mod_an = anomalies_monthly(snwd_mod_raw)
        snwd_era_an = anomalies_monthly(snwd_era_raw)
        anomR_snwd, ubRMSE_snwd = anom_metrics_monthly(snwd_mod_an, snwd_era_an, min_pairs=min_pairs)
        R_snwd = corr_monthly(snwd_mod_raw, snwd_era_raw, min_pairs=min_pairs)
        rmse_snwd, bias_snwd = rmse_bias_monthly(snwd_mod_raw, snwd_era_raw, min_pairs=min_pairs)
    else:
        anomR_snwd = xr.full_like(anomR_sfc, np.nan)
        ubRMSE_snwd = xr.full_like(ubRMSE_sfc, np.nan)
        R_snwd = xr.full_like(anomR_sfc, np.nan)
        rmse_snwd = xr.full_like(ubRMSE_sfc, np.nan)
        bias_snwd = xr.full_like(anomR_sfc, np.nan)

    return xr.Dataset(dict(
        # anomalies-based metrics
        anomR_sfc=anomR_sfc,   ubRMSE_sfc=ubRMSE_sfc,
        anomR_rz=anomR_rz,     ubRMSE_rz=ubRMSE_rz,
        anomR_scf=anomR_scf,   ubRMSE_scf=ubRMSE_scf, rmse_scf=rmse_scf, bias_scf=bias_scf,
        anomR_swe=anomR_swe,   ubRMSE_swe=ubRMSE_swe, rmse_swe=rmse_swe, bias_swe=bias_swe,
        anomR_snwd=anomR_snwd, ubRMSE_snwd=ubRMSE_snwd, rmse_snwd=rmse_snwd, bias_snwd=bias_snwd,
        # raw correlations
        R_sfc=R_sfc, R_rz=R_rz, R_scf=R_scf, R_swe=R_swe, R_snwd=R_snwd,
    ))


# Process each file → stack results along "period" (with optional on-disk cache)
import hashlib


def _cache_file_for(fn, periods, min_pairs):
    stem = Path(fn).stem
    sig = {
        "fn": str(Path(fn).resolve()),
        "periods": periods,
        "min_pairs": int(min_pairs),
        "schema": "periodized_metrics_v3_era5l_zero_snow",
    }
    key = hashlib.md5(repr(sig).encode("utf-8")).hexdigest()[:12]
    return CACHE_DIR / f"{stem}__{key}.nc"


def _fill_era5l_no_snow_nan_with_zero(ds, fn_hint=""):
    """For ERA5-Land summaries, enforce 0 for no-snow (SWE_era/SNWD_era) before stats."""
    name = str(fn_hint).upper()
    if ("ERA5L" not in name) and ("ERA5-LAND" not in name):
        return ds

    ds = ds.copy()
    applied = []
    for v in ("SWE_era", "SNWD_era"):
        if v in ds.data_vars:
            ds[v] = ds[v].fillna(0.0)
            applied.append(v)

    if applied:
        print(f"Applied ERA5-Land no-snow NaN→0 for {applied} in {str(fn_hint).split('/')[-1]}")
    return ds


results = {}
for fn in FILES:
    cache_file = _cache_file_for(fn, PERIODS, MIN_PAIRS)

    if USE_CACHE and cache_file.exists() and not REBUILD_CACHE:
        ds_cached = xr.open_dataset(cache_file)
        ds_all = ds_cached.load()
        ds_cached.close()
        results[fn] = ds_all
        print(f"Loaded cached periodized metrics: {cache_file}")
        continue

    ds = xr.open_dataset(fn)
    # ensure CF-time decoding just in case
    ds = xr.decode_cf(ds)
    ds = _fill_era5l_no_snow_nan_with_zero(ds, fn_hint=fn)

    per_list = []
    per_labels = []
    for (t0, t1) in PERIODS:
        ds_per = compute_metrics_for_period(ds, t0, t1, min_pairs=MIN_PAIRS)
        per_list.append(ds_per)
        per_labels.append(f"{pd.to_datetime(t0).date()}–{pd.to_datetime(t1).date()}")

        print(f"{fn}  [{t0} → {t1}]  "
            f"SM anomR mean={float(ds_per['anomR_sfc'].mean(skipna=True)):.3f}  "
            f"SM R mean={float(ds_per['R_sfc'].mean(skipna=True)):.3f}  "
            f"SCF anomR mean={float(ds_per['anomR_scf'].mean(skipna=True)):.3f}  "
            f"SWE anomR mean={float(ds_per['anomR_swe'].mean(skipna=True)):.3f}  "
            f"SNWD anomR mean={float(ds_per['anomR_snwd'].mean(skipna=True)):.3f}")

    ds_all = xr.concat(per_list, dim=xr.DataArray(per_labels, dims=("period",), name="period"))
    results[fn] = ds_all

    if USE_CACHE:
        ds_all.to_netcdf(cache_file)
        print(f"Saved cached periodized metrics: {cache_file}")


# Example: access DA vs OL periodized metrics
# results["ERA5L_vs_DAv8_M36_summary.nc"]  -> Dataset with dim "period","y","x"
# results["ERA5L_vs_OLv8_M36_summary.nc"]  -> same structure

# If you want to difference DA − OL per period:
if len(FILES) == 2:
    da_key = FILES[0]; ol_key = FILES[1]
    assert set(results[da_key].data_vars) == set(results[ol_key].data_vars)
    diff_period = xr.Dataset(
        {v: (results[da_key][v] - results[ol_key][v]) for v in results[da_key].data_vars}
    )
    # Now diff_period has dims ("period","y","x") and the six metrics differenced per period.
    # You can flatten any [period slice] the same way you did before to map it.
    print("Built DA−OL periodized metrics in 'diff_period' (dims:", diff_period.dims, ")")

# %%
# --- Snow-only DA−OL difference maps (full period): SCF, SWE, SD; 3x1 Robinson per variable ---

import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# Build diff_period if needed (DA − OL)
if 'diff_period' not in globals():
    da_key = FN_DA
    ol_key = FN_OL
    diff_period = xr.Dataset({v: (results[da_key][v] - results[ol_key][v]) for v in results[da_key].data_vars})

LAT_MIN = -60.0  # do not show/use values south of 60°S
print('Map reference dataset source inferred from FN_DA/FN_OL setup')
print(f'Applying latitude cutoff: lat >= {LAT_MIN} degrees')


def _infer_ref_label(fn_da, fn_ol):
    s = f"{Path(str(fn_da)).name} {Path(str(fn_ol)).name}".upper()
    if ('ERA5L' in s) or ('ERA5-LAND' in s):
        return 'ERA5-Land'
    if 'ERA5' in s:
        return 'ERA5'
    return 'Reference'


REF_LABEL = _infer_ref_label(FN_DA, FN_OL)
print('Reference in plots:', REF_LABEL)


def _pick_full_period_label(period_vals):
    labels = [str(p) for p in period_vals]
    # Prefer explicit full-span labels if present.
    for lab in labels:
        if ('2000-06-01' in lab) and ('2024-05-31' in lab):
            return lab

    # Fallback: choose the longest period by parsed date span.
    best = labels[-1]
    best_days = -1
    for lab in labels:
        parts = lab.replace('—', '–').split('–')
        if len(parts) != 2:
            continue
        try:
            t0 = np.datetime64(parts[0].strip())
            t1 = np.datetime64(parts[1].strip())
            days = int((t1 - t0) / np.timedelta64(1, 'D'))
        except Exception:
            continue
        if days > best_days:
            best = lab
            best_days = days
    return best


def _robinson_panel(ax, lon2d, lat2d, z2d, title, cbar_label, cmap='RdBu_r', vlim=None, lat_min=-60.0):
    z = np.asarray(z2d, dtype=float)

    # Mask/crop south of cutoff before any stats/plotting.
    keep_lat = np.isfinite(lat2d) & (lat2d >= lat_min)
    z = np.where(keep_lat, z, np.nan)

    finite_xy = np.isfinite(lon2d) & np.isfinite(lat2d) & keep_lat
    finite_all = finite_xy & np.isfinite(z)

    ax.set_global()
    ax.set_extent([-180.0, 180.0, lat_min, 90.0], crs=ccrs.PlateCarree())
    ax.add_feature(cfeature.LAND, facecolor='0.9', zorder=0)
    ax.add_feature(cfeature.OCEAN, facecolor='white', zorder=0)
    ax.add_feature(cfeature.COASTLINE, linewidth=0.5, zorder=2)
    ax.add_feature(cfeature.BORDERS, linewidth=0.25, zorder=2)
    _ = ax.gridlines(draw_labels=False, linewidth=0.35, color='gray', alpha=0.35, linestyle='--')

    if int(finite_all.sum()) == 0:
        ax.set_title(title)
        ax.text(0.5, 0.5, 'No finite data', ha='center', va='center', transform=ax.transAxes)
        return

    if vlim is None:
        vals = z[finite_all]
        p2, p98 = np.nanpercentile(vals, [2, 98])
        vmax = float(max(abs(p2), abs(p98)))
        if (not np.isfinite(vmax)) or (vmax <= 0):
            vmax = float(np.nanmax(np.abs(vals)))
        if (not np.isfinite(vmax)) or (vmax <= 0):
            vmax = 1.0
        vlim = (-vmax, vmax)

    if bool(np.all(finite_xy)):
        artist = ax.pcolormesh(
            lon2d,
            lat2d,
            z,
            transform=ccrs.PlateCarree(),
            shading='auto',
            cmap=cmap,
            vmin=vlim[0],
            vmax=vlim[1],
            zorder=1,
        )
    else:
        artist = ax.scatter(
            lon2d[finite_all],
            lat2d[finite_all],
            c=z[finite_all],
            transform=ccrs.PlateCarree(),
            s=5,
            marker='s',
            linewidths=0,
            cmap=cmap,
            vmin=vlim[0],
            vmax=vlim[1],
            zorder=1,
        )

    spatial_mean = float(np.nanmean(z[finite_all]))

    ax.set_title(title)
    ax.text(
        0.02,
        0.03,
        f'Spatial mean: {spatial_mean:.3g}',
        transform=ax.transAxes,
        ha='left',
        va='bottom',
        fontsize=9,
        bbox=dict(facecolor='white', edgecolor='none', alpha=0.8, pad=2.0),
        zorder=3,
    )

    cb = plt.colorbar(artist, ax=ax, orientation='horizontal', fraction=0.045, pad=0.03)
    cb.set_label(cbar_label)


period_labels = [str(p) for p in diff_period['period'].values]
full_period = _pick_full_period_label(period_labels)
print('Using full snow period:', full_period)

lat2d = np.asarray(diff_period['lat'].values)
lon2d = np.asarray(diff_period['lon'].values)

# (suffix in variable names, figure title token, units)
snow_specs = [
    ('scf',  'SCF', 'Δ (1)'),
    ('swe',  'SWE', 'Δ (m)'),
    ('snwd', 'SD',  'Δ (m)'),
]

metric_specs = [
    ('rmse',   'RMSE'),
    ('ubRMSE', 'ubRMSE'),
    ('bias',   'Bias'),
]

for suffix, title_token, unit in snow_specs:
    fields = [f'{m}_{suffix}' for m, _ in metric_specs]
    missing = [f for f in fields if f not in diff_period.data_vars]
    if missing:
        print(f'Skipping {title_token}; missing fields: {missing}')
        continue

    # Precompute symmetric limits per metric panel from full period only,
    # after applying the same latitude cutoff used in the map.
    vlims = {}
    lat_keep = np.isfinite(lat2d) & (lat2d >= LAT_MIN)
    for field in fields:
        z = np.asarray(diff_period[field].sel(period=full_period).values, dtype=float)
        z = np.where(lat_keep, z, np.nan)
        finite = np.isfinite(z)
        if not np.any(finite):
            vlims[field] = (-1.0, 1.0)
            continue
        vals = z[finite]
        p2, p98 = np.nanpercentile(vals, [2, 98])
        vmax = float(max(abs(p2), abs(p98)))
        if (not np.isfinite(vmax)) or (vmax <= 0):
            vmax = float(np.nanmax(np.abs(vals)))
        if (not np.isfinite(vmax)) or (vmax <= 0):
            vmax = 1.0
        vlims[field] = (-vmax, vmax)

    fig, axes = plt.subplots(
        nrows=3,
        ncols=1,
        figsize=(14, 13),
        subplot_kw={'projection': ccrs.Robinson()},
        constrained_layout=True,
    )

    for ax, (_, metric_title), field in zip(axes, metric_specs, fields):
        da2d = diff_period[field].sel(period=full_period)
        panel_title = f'DAv8_M36 − OLv8_M36 vs {REF_LABEL} • {title_token} • {metric_title}'
        _robinson_panel(
            ax=ax,
            lon2d=lon2d,
            lat2d=lat2d,
            z2d=da2d.values,
            title=panel_title,
            cbar_label=unit,
            cmap='RdBu_r',
            vlim=vlims[field],
            lat_min=LAT_MIN,
        )

    fig.suptitle(f'{title_token} Difference Maps vs {REF_LABEL} (Full Period: {full_period})', fontsize=14)
    plt.show()

# %%
# --- Surface/RZ DA−OL maps by period: R, anomR, ubRMSE (3x1 Robinson; 4 periods) ---

import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# Build diff_period if needed (DA − OL)
if 'diff_period' not in globals():
    da_key = FN_DA
    ol_key = FN_OL
    diff_period = xr.Dataset({v: (results[da_key][v] - results[ol_key][v]) for v in results[da_key].data_vars})

LAT_MIN_SM = float(globals().get('LAT_MIN', -60.0))


def _infer_ref_label_local(fn_da, fn_ol):
    s = f"{Path(str(fn_da)).name} {Path(str(fn_ol)).name}".upper()
    if ('ERA5L' in s) or ('ERA5-LAND' in s):
        return 'ERA5-Land'
    if 'ERA5' in s:
        return 'ERA5'
    return 'Reference'


REF_LABEL_SM = globals().get('REF_LABEL', _infer_ref_label_local(FN_DA, FN_OL))
print('Reference in plots:', REF_LABEL_SM)
print(f'Applying latitude cutoff: lat >= {LAT_MIN_SM} degrees')


def _robinson_panel_sm(ax, lon2d, lat2d, z2d, title, cbar_label, cmap='RdBu_r', vlim=None, lat_min=-60.0):
    z = np.asarray(z2d, dtype=float)

    # Mask/crop south of cutoff before stats/plotting.
    keep_lat = np.isfinite(lat2d) & (lat2d >= lat_min)
    z = np.where(keep_lat, z, np.nan)

    finite_xy = np.isfinite(lon2d) & np.isfinite(lat2d) & keep_lat
    finite_all = finite_xy & np.isfinite(z)

    ax.set_global()
    ax.set_extent([-180.0, 180.0, lat_min, 90.0], crs=ccrs.PlateCarree())
    ax.add_feature(cfeature.LAND, facecolor='0.9', zorder=0)
    ax.add_feature(cfeature.OCEAN, facecolor='white', zorder=0)
    ax.add_feature(cfeature.COASTLINE, linewidth=0.5, zorder=2)
    ax.add_feature(cfeature.BORDERS, linewidth=0.25, zorder=2)
    _ = ax.gridlines(draw_labels=False, linewidth=0.35, color='gray', alpha=0.35, linestyle='--')

    if int(finite_all.sum()) == 0:
        ax.set_title(title)
        ax.text(0.5, 0.5, 'No finite data', ha='center', va='center', transform=ax.transAxes)
        return

    if vlim is None:
        vals = z[finite_all]
        p2, p98 = np.nanpercentile(vals, [2, 98])
        vmax = float(max(abs(p2), abs(p98)))
        if (not np.isfinite(vmax)) or (vmax <= 0):
            vmax = float(np.nanmax(np.abs(vals)))
        if (not np.isfinite(vmax)) or (vmax <= 0):
            vmax = 1.0
        vlim = (-vmax, vmax)

    if bool(np.all(finite_xy)):
        artist = ax.pcolormesh(
            lon2d,
            lat2d,
            z,
            transform=ccrs.PlateCarree(),
            shading='auto',
            cmap=cmap,
            vmin=vlim[0],
            vmax=vlim[1],
            zorder=1,
        )
    else:
        artist = ax.scatter(
            lon2d[finite_all],
            lat2d[finite_all],
            c=z[finite_all],
            transform=ccrs.PlateCarree(),
            s=5,
            marker='s',
            linewidths=0,
            cmap=cmap,
            vmin=vlim[0],
            vmax=vlim[1],
            zorder=1,
        )

    spatial_mean = float(np.nanmean(z[finite_all]))

    ax.set_title(title)
    ax.text(
        0.02,
        0.03,
        f'Spatial mean: {spatial_mean:.3g}',
        transform=ax.transAxes,
        ha='left',
        va='bottom',
        fontsize=9,
        bbox=dict(facecolor='white', edgecolor='none', alpha=0.8, pad=2.0),
        zorder=3,
    )

    cb = plt.colorbar(artist, ax=ax, orientation='horizontal', fraction=0.045, pad=0.03)
    cb.set_label(cbar_label)


period_labels = [str(p) for p in diff_period['period'].values]
lat2d = np.asarray(diff_period['lat'].values)
lon2d = np.asarray(diff_period['lon'].values)

sm_specs = [
    ('sfc', 'Surface SM', 'Δ (m$^3$ m$^{-3}$)'),
    ('rz', 'RZ SM', 'Δ (m$^3$ m$^{-3}$)'),
]

metric_specs = [
    ('R', 'R', 'Δ (1)'),
    ('anomR', 'AnomR', 'Δ (1)'),
    ('ubRMSE', 'ubRMSE', None),
]

for suffix, var_title, ubrmse_unit in sm_specs:
    fields = [f'{m}_{suffix}' for m, _, _ in metric_specs]
    missing = [f for f in fields if f not in diff_period.data_vars]
    if missing:
        print(f'Skipping {var_title}; missing fields: {missing}')
        continue

    for per in period_labels:
        # Precompute symmetric limits for this variable+period.
        vlims = {}
        lat_keep = np.isfinite(lat2d) & (lat2d >= LAT_MIN_SM)
        for field in fields:
            z = np.asarray(diff_period[field].sel(period=per).values, dtype=float)
            z = np.where(lat_keep, z, np.nan)
            finite = np.isfinite(z)
            if not np.any(finite):
                vlims[field] = (-1.0, 1.0)
                continue
            vals = z[finite]
            p2, p98 = np.nanpercentile(vals, [2, 98])
            vmax = float(max(abs(p2), abs(p98)))
            if (not np.isfinite(vmax)) or (vmax <= 0):
                vmax = float(np.nanmax(np.abs(vals)))
            if (not np.isfinite(vmax)) or (vmax <= 0):
                vmax = 1.0
            vlims[field] = (-vmax, vmax)

        fig, axes = plt.subplots(
            nrows=3,
            ncols=1,
            figsize=(14, 13),
            subplot_kw={'projection': ccrs.Robinson()},
            constrained_layout=True,
        )

        for ax, (m_key, m_title, m_unit), field in zip(axes, metric_specs, fields):
            da2d = diff_period[field].sel(period=per)
            panel_title = f'DAv8_M36 − OLv8_M36 vs {REF_LABEL_SM} • {var_title} • {m_title}'
            cbar_unit = ubrmse_unit if m_key == 'ubRMSE' else m_unit
            _robinson_panel_sm(
                ax=ax,
                lon2d=lon2d,
                lat2d=lat2d,
                z2d=da2d.values,
                title=panel_title,
                cbar_label=cbar_unit,
                cmap='RdBu_r',
                vlim=vlims[field],
                lat_min=LAT_MIN_SM,
            )

        fig.suptitle(f'{var_title} Difference Maps vs {REF_LABEL_SM} ({per})', fontsize=14)
        plt.show()

# %%
# --- SMAP-era Surface SM maps: OL vs reference (top), DA vs reference (bottom); R/anomR/ubRMSE ---

import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from pathlib import Path

if 'results' not in globals():
    raise RuntimeError('results not found. Run the periodized metrics cell first.')

if FN_OL not in results or FN_DA not in results:
    raise RuntimeError('Expected FN_OL/FN_DA datasets in results. Re-run periodized metrics cell.')


def _infer_ref_label_local(fn_da, fn_ol):
    s = f"{Path(str(fn_da)).name} {Path(str(fn_ol)).name}".upper()
    if ('ERA5L' in s) or ('ERA5-LAND' in s):
        return 'ERA5-Land'
    if 'ERA5' in s:
        return 'ERA5'
    return 'Reference'


def _pick_smap_period(period_vals):
    labels = [str(p) for p in period_vals]
    # Prefer explicit SMAP-era span
    for lab in labels:
        if ('2015-04-01' in lab) and ('2024-05-31' in lab):
            return lab
    # Fallback: any period containing 2015
    for lab in labels:
        if '2015' in lab:
            return lab
    # Final fallback: latest label
    return labels[-1]


def _panel_map(ax, lon2d, lat2d, z2d, title, cbar_label, cmap, vlim, lat_min=-60.0):
    z = np.asarray(z2d, dtype=float)

    keep_lat = np.isfinite(lat2d) & (lat2d >= lat_min)
    z = np.where(keep_lat, z, np.nan)

    finite_xy = np.isfinite(lon2d) & np.isfinite(lat2d) & keep_lat
    finite_all = finite_xy & np.isfinite(z)

    ax.set_global()
    ax.set_extent([-180.0, 180.0, lat_min, 90.0], crs=ccrs.PlateCarree())
    ax.add_feature(cfeature.LAND, facecolor='0.9', zorder=0)
    ax.add_feature(cfeature.OCEAN, facecolor='white', zorder=0)
    ax.add_feature(cfeature.COASTLINE, linewidth=0.5, zorder=2)
    ax.add_feature(cfeature.BORDERS, linewidth=0.25, zorder=2)
    _ = ax.gridlines(draw_labels=False, linewidth=0.35, color='gray', alpha=0.35, linestyle='--')

    if int(finite_all.sum()) == 0:
        ax.set_title(title)
        ax.text(0.5, 0.5, 'No finite data', ha='center', va='center', transform=ax.transAxes)
        return

    if bool(np.all(finite_xy)):
        artist = ax.pcolormesh(
            lon2d,
            lat2d,
            z,
            transform=ccrs.PlateCarree(),
            shading='auto',
            cmap=cmap,
            vmin=vlim[0],
            vmax=vlim[1],
            zorder=1,
        )
    else:
        artist = ax.scatter(
            lon2d[finite_all],
            lat2d[finite_all],
            c=z[finite_all],
            transform=ccrs.PlateCarree(),
            s=5,
            marker='s',
            linewidths=0,
            cmap=cmap,
            vmin=vlim[0],
            vmax=vlim[1],
            zorder=1,
        )

    spatial_mean = float(np.nanmean(z[finite_all]))

    ax.set_title(title)
    ax.text(
        0.02,
        0.03,
        f'Spatial mean: {spatial_mean:.3g}',
        transform=ax.transAxes,
        ha='left',
        va='bottom',
        fontsize=9,
        bbox=dict(facecolor='white', edgecolor='none', alpha=0.8, pad=2.0),
        zorder=3,
    )

    cb = plt.colorbar(artist, ax=ax, orientation='horizontal', fraction=0.045, pad=0.03)
    cb.set_label(cbar_label)


REF_LABEL_2X3 = globals().get('REF_LABEL_SM', globals().get('REF_LABEL', _infer_ref_label_local(FN_DA, FN_OL)))
LAT_MIN_2X3 = float(globals().get('LAT_MIN_SM', globals().get('LAT_MIN', -60.0)))

ol_ds = results[FN_OL]
da_ds = results[FN_DA]

smap_period = _pick_smap_period(ol_ds['period'].values)
print('Reference in plots:', REF_LABEL_2X3)
print('Using SMAP-era period:', smap_period)
print(f'Applying latitude cutoff: lat >= {LAT_MIN_2X3} degrees')

lat2d = np.asarray(ol_ds['lat'].values)
lon2d = np.asarray(ol_ds['lon'].values)
lat_keep = np.isfinite(lat2d) & (lat2d >= LAT_MIN_2X3)

col_specs = [
    ('R_sfc', 'R', '1', 'corr', 'RdBu_r'),
    ('anomR_sfc', 'anomR', '1', 'corr', 'RdBu_r'),
    ('ubRMSE_sfc', 'ubRMSE', 'm$^3$ m$^{-3}$', 'nonneg', 'viridis'),
]

missing = [f for f, *_ in col_specs if (f not in ol_ds.data_vars) or (f not in da_ds.data_vars)]
if missing:
    raise RuntimeError(f'Missing expected Surface SM fields for 2x3 panel: {missing}')

# Shared limits by column (pooled across OL and DA rows) for the selected period.
vlims = {}
for field, _, _, mode, _ in col_specs:
    z_ol = np.asarray(ol_ds[field].sel(period=smap_period).values, dtype=float)
    z_da = np.asarray(da_ds[field].sel(period=smap_period).values, dtype=float)
    z_ol = np.where(lat_keep, z_ol, np.nan)
    z_da = np.where(lat_keep, z_da, np.nan)

    vals = np.concatenate([z_ol[np.isfinite(z_ol)], z_da[np.isfinite(z_da)]])
    if vals.size == 0:
        vlims[field] = (-1.0, 1.0) if mode == 'corr' else (0.0, 1.0)
        continue

    if mode == 'corr':
        vlims[field] = (-1.0, 1.0)
    else:
        p98 = float(np.nanpercentile(vals, 98))
        vmax = p98 if np.isfinite(p98) and p98 > 0 else float(np.nanmax(vals))
        if (not np.isfinite(vmax)) or (vmax <= 0):
            vmax = 1.0
        vlims[field] = (0.0, vmax)

fig, axes = plt.subplots(
    nrows=2,
    ncols=3,
    figsize=(18, 10),
    subplot_kw={'projection': ccrs.Robinson()},
    constrained_layout=True,
)

row_specs = [
    ('OL vs ' + REF_LABEL_2X3, ol_ds),
    ('DA vs ' + REF_LABEL_2X3, da_ds),
]

for r, (row_title, ds_row) in enumerate(row_specs):
    for c, (field, metric_title, unit, _, cmap) in enumerate(col_specs):
        da2d = ds_row[field].sel(period=smap_period)
        panel_title = f'{row_title} • Surface SM • {metric_title}'
        _panel_map(
            ax=axes[r, c],
            lon2d=lon2d,
            lat2d=lat2d,
            z2d=da2d.values,
            title=panel_title,
            cbar_label=unit,
            cmap=cmap,
            vlim=vlims[field],
            lat_min=LAT_MIN_2X3,
        )

fig.suptitle(f'Surface SM Maps vs {REF_LABEL_2X3} (SMAP-era: {smap_period})', fontsize=15)
plt.show()

# %%
# --- First-period Surface SM maps: OL vs reference (top), DA vs reference (bottom); R/anomR/ubRMSE ---

import numpy as np
import matplotlib.pyplot as plt

if 'results' not in globals():
    raise RuntimeError('results not found. Run the periodized metrics cell first.')

if FN_OL not in results or FN_DA not in results:
    raise RuntimeError('Expected FN_OL/FN_DA datasets in results. Re-run periodized metrics cell.')

# Reuse helpers from previous 2x3 cell if available; otherwise define minimal fallback.
if '_panel_map' not in globals():
    import cartopy.crs as ccrs
    import cartopy.feature as cfeature
    def _panel_map(ax, lon2d, lat2d, z2d, title, cbar_label, cmap, vlim, lat_min=-60.0):
        z = np.asarray(z2d, dtype=float)
        keep_lat = np.isfinite(lat2d) & (lat2d >= lat_min)
        z = np.where(keep_lat, z, np.nan)
        finite_xy = np.isfinite(lon2d) & np.isfinite(lat2d) & keep_lat
        finite_all = finite_xy & np.isfinite(z)

        ax.set_global()
        ax.set_extent([-180.0, 180.0, lat_min, 90.0], crs=ccrs.PlateCarree())
        ax.add_feature(cfeature.LAND, facecolor='0.9', zorder=0)
        ax.add_feature(cfeature.OCEAN, facecolor='white', zorder=0)
        ax.add_feature(cfeature.COASTLINE, linewidth=0.5, zorder=2)
        ax.add_feature(cfeature.BORDERS, linewidth=0.25, zorder=2)
        _ = ax.gridlines(draw_labels=False, linewidth=0.35, color='gray', alpha=0.35, linestyle='--')

        if int(finite_all.sum()) == 0:
            ax.set_title(title)
            ax.text(0.5, 0.5, 'No finite data', ha='center', va='center', transform=ax.transAxes)
            return

        if bool(np.all(finite_xy)):
            artist = ax.pcolormesh(
                lon2d, lat2d, z,
                transform=ccrs.PlateCarree(),
                shading='auto', cmap=cmap,
                vmin=vlim[0], vmax=vlim[1], zorder=1,
            )
        else:
            artist = ax.scatter(
                lon2d[finite_all], lat2d[finite_all], c=z[finite_all],
                transform=ccrs.PlateCarree(), s=5, marker='s', linewidths=0,
                cmap=cmap, vmin=vlim[0], vmax=vlim[1], zorder=1,
            )

        spatial_mean = float(np.nanmean(z[finite_all]))
        ax.set_title(title)
        ax.text(
            0.02, 0.03, f'Spatial mean: {spatial_mean:.3g}',
            transform=ax.transAxes, ha='left', va='bottom', fontsize=9,
            bbox=dict(facecolor='white', edgecolor='none', alpha=0.8, pad=2.0), zorder=3,
        )

        cb = plt.colorbar(artist, ax=ax, orientation='horizontal', fraction=0.045, pad=0.03)
        cb.set_label(cbar_label)

if '_infer_ref_label_local' not in globals():
    from pathlib import Path
    def _infer_ref_label_local(fn_da, fn_ol):
        s = f"{Path(str(fn_da)).name} {Path(str(fn_ol)).name}".upper()
        if ('ERA5L' in s) or ('ERA5-LAND' in s):
            return 'ERA5-Land'
        if 'ERA5' in s:
            return 'ERA5'
        return 'Reference'

REF_LABEL_2X3_FIRST = globals().get('REF_LABEL_2X3', globals().get('REF_LABEL_SM', globals().get('REF_LABEL', _infer_ref_label_local(FN_DA, FN_OL))))
LAT_MIN_2X3_FIRST = float(globals().get('LAT_MIN_2X3', globals().get('LAT_MIN_SM', globals().get('LAT_MIN', -60.0))))

ol_ds = results[FN_OL]
da_ds = results[FN_DA]

period_values = [str(p) for p in ol_ds['period'].values]
if len(period_values) == 0:
    raise RuntimeError('No period values found in results[FN_OL].')

first_period = period_values[0]
print('Reference in plots:', REF_LABEL_2X3_FIRST)
print('Using FIRST period:', first_period)
print(f'Applying latitude cutoff: lat >= {LAT_MIN_2X3_FIRST} degrees')

lat2d = np.asarray(ol_ds['lat'].values)
lon2d = np.asarray(ol_ds['lon'].values)
lat_keep = np.isfinite(lat2d) & (lat2d >= LAT_MIN_2X3_FIRST)

col_specs = [
    ('R_sfc', 'R', '1', 'corr', 'RdBu_r'),
    ('anomR_sfc', 'anomR', '1', 'corr', 'RdBu_r'),
    ('ubRMSE_sfc', 'ubRMSE', 'm$^3$ m$^{-3}$', 'nonneg', 'viridis'),
]

missing = [f for f, *_ in col_specs if (f not in ol_ds.data_vars) or (f not in da_ds.data_vars)]
if missing:
    raise RuntimeError(f'Missing expected Surface SM fields for 2x3 panel: {missing}')

vlims = {}
for field, _, _, mode, _ in col_specs:
    z_ol = np.asarray(ol_ds[field].sel(period=first_period).values, dtype=float)
    z_da = np.asarray(da_ds[field].sel(period=first_period).values, dtype=float)
    z_ol = np.where(lat_keep, z_ol, np.nan)
    z_da = np.where(lat_keep, z_da, np.nan)

    vals = np.concatenate([z_ol[np.isfinite(z_ol)], z_da[np.isfinite(z_da)]])
    if vals.size == 0:
        vlims[field] = (-1.0, 1.0) if mode == 'corr' else (0.0, 1.0)
        continue

    if mode == 'corr':
        vlims[field] = (-1.0, 1.0)
    else:
        p98 = float(np.nanpercentile(vals, 98))
        vmax = p98 if np.isfinite(p98) and p98 > 0 else float(np.nanmax(vals))
        if (not np.isfinite(vmax)) or (vmax <= 0):
            vmax = 1.0
        vlims[field] = (0.0, vmax)

fig, axes = plt.subplots(
    nrows=2,
    ncols=3,
    figsize=(18, 10),
    subplot_kw={'projection': ccrs.Robinson()},
    constrained_layout=True,
)

row_specs = [
    ('OL vs ' + REF_LABEL_2X3_FIRST, ol_ds),
    ('DA vs ' + REF_LABEL_2X3_FIRST, da_ds),
]

for r, (row_title, ds_row) in enumerate(row_specs):
    for c, (field, metric_title, unit, _, cmap) in enumerate(col_specs):
        da2d = ds_row[field].sel(period=first_period)
        panel_title = f'{row_title} • Surface SM • {metric_title}'
        _panel_map(
            ax=axes[r, c],
            lon2d=lon2d,
            lat2d=lat2d,
            z2d=da2d.values,
            title=panel_title,
            cbar_label=unit,
            cmap=cmap,
            vlim=vlims[field],
            lat_min=LAT_MIN_2X3_FIRST,
        )

fig.suptitle(f'Surface SM Maps vs {REF_LABEL_2X3_FIRST} (First period: {first_period})', fontsize=15)
plt.show()

# %%
# --- Build a tidy summary table of periodized metrics: DA, OL, and Δ = DA−OL ---

# Map filenames → short labels used in the table
label_for = {}
for fn in FILES:
    if "DA" in fn or "DAv" in fn:
        label_for[fn] = "DA"
    elif "OL" in fn or "OLv" in fn:
        label_for[fn] = "OL"
    else:
        # fallback: use stem without extension
        label_for[fn] = fn.replace(".nc","")

metrics = [
    'anomR_sfc','R_sfc','ubRMSE_sfc',
    'anomR_rz','R_rz','ubRMSE_rz',
    'anomR_scf','R_scf','ubRMSE_scf','rmse_scf','bias_scf',
    'anomR_swe','R_swe','ubRMSE_swe','rmse_swe','bias_swe',
    'anomR_snwd','R_snwd','ubRMSE_snwd','rmse_snwd','bias_snwd'
]

pretty  = {
    'anomR_sfc':'AnomCorr (Surf SM)',
    'R_sfc'    :'RawCorr (Surf SM)',
    'ubRMSE_sfc':'ubRMSE (Surf SM)',

    'anomR_rz' :'AnomCorr (RZ SM)',
    'R_rz'     :'RawCorr (RZ SM)',
    'ubRMSE_rz':'ubRMSE (RZ SM)',

    'anomR_scf':'AnomCorr (SCF)',
    'R_scf'    :'RawCorr (SCF)',
    'ubRMSE_scf':'ubRMSE (SCF)',
    'rmse_scf':'RMSE (SCF)',
    'bias_scf':'Bias (SCF)',

    'anomR_swe':'AnomCorr (SWE)',
    'R_swe'    :'RawCorr (SWE)',
    'ubRMSE_swe':'ubRMSE (SWE)',
    'rmse_swe':'RMSE (SWE)',
    'bias_swe':'Bias (SWE)',

    'anomR_snwd':'AnomCorr (Snow Depth)',
    'R_snwd'    :'RawCorr (Snow Depth)',
    'ubRMSE_snwd':'ubRMSE (Snow Depth)',
    'rmse_snwd':'RMSE (Snow Depth)',
    'bias_snwd':'Bias (Snow Depth)',
}

# Collect rows
rows = []
periods = list(next(iter(results.values())).coords['period'].values)
for per in periods:
    row = {'Period': str(per)}
    # Per-file means and valid counts
    for fn, ds_per in results.items():
        tag = label_for[fn]
        for m in metrics:
            if m in ds_per:
                da2d = ds_per[m].sel(period=per)  # (y,x)
                mean_val = float(da2d.mean(skipna=True).values)
                n_valid  = int(np.isfinite(da2d.values).sum())
                row[(tag, pretty[m])] = mean_val
                row[(tag, f"N valid ({pretty[m]})")] = n_valid
    rows.append(row)

# Build DataFrame with MultiIndex columns
df = pd.DataFrame(rows).set_index("Period")
# Ensure both DA and OL exist before computing deltas
if len(FILES) >= 2:
    # Add Δ = DA − OL columns for each metric (means only)
    for m in metrics:
        col_da = ("DA",  pretty[m])
        col_ol = ("OL",  pretty[m])
        if col_da in df.columns and col_ol in df.columns:
            df[("Δ (DA−OL)", pretty[m])] = df[col_da] - df[col_ol]

# Sort columns: DA | OL | Δ
new_cols = []
for group in ["DA", "OL", "Δ (DA−OL)"]:
    sub = [c for c in df.columns if c[0] == group and "N valid" not in c[1]]
    sub_valid = [c for c in df.columns if c[0] == group and "N valid" in c[1]]
    # keep metric order
    ordered = []
    for m in metrics:
        mean_label = pretty[m]
        n_label = f"N valid ({mean_label})"
        for c in sub:
            if c[1] == mean_label:
                ordered.append(c)
        for c in sub_valid:
            if c[1] == n_label:
                ordered.append(c)
    new_cols.extend(ordered)
df = df.reindex(columns=new_cols)

# Formatting: 3 decimals for metric means, integers for counts
fmt = {}
for c in df.columns:
    if "N valid" in c[1]:
        fmt[c] = "{:d}"
    else:
        fmt[c] = "{:.3f}"

# Display (pandas)
try:
    from IPython.display import display
    display(df.style.format(fmt).set_caption(
    "ERA5-Land vs Model: Periodized Metrics (AnomCorr, RawCorr, ubRMSE; spatial medians and valid counts)"
))
except Exception:
    print(df.to_string())

# Also save to CSV for records

df.to_csv(out_csv)
print(f"Saved summary table → {out_csv}")

# %%
# --- OL vs DA bar charts for Surface SM, Root-zone SM, and SCF ---
# Uses `results` (periodized datasets) and `FILES` from earlier cells.

import numpy as np
import matplotlib.pyplot as plt

# Map filenames → labels
label_for = {}
for fn in FILES:
    if "DA" in fn or "DAv" in fn:
        label_for[fn] = "DA"
    elif "OL" in fn or "OLv" in fn:
        label_for[fn] = "OL"
    else:
        label_for[fn] = fn.replace(".nc","")

period_labels = list(next(iter(results.values())).coords["period"].values)

# Colors
COL_OL = "#2878B5"   # blue
COL_DA = "#F28E2B"   # orange

def mean_se_2d(da2d):
    """NaN-safe spatial mean & standard error across y,x + N."""
    v = np.asarray(da2d.values)
    mask = np.isfinite(v)
    n = int(mask.sum())
    if n == 0:
        return np.nan, np.nan, 0
    vals = v[mask]
    mean = float(np.nanmean(vals))
    se   = float(np.nanstd(vals, ddof=1) / np.sqrt(n)) if n > 1 else np.nan
    return mean, se, n

def pooled_ylim(means_errs, pad=0.18, hard=(None, None)):
    """
    Compute common y-lims from all (mean, err) pairs across periods/tags,
    then add generous padding. `hard` can clamp (min,max) if desired.
    """
    lows  = []
    highs = []
    for (mean, err) in means_errs:
        m = mean
        e = 0.0 if not np.isfinite(err) else err
        if np.isfinite(m):
            lows.append(m - e)
            highs.append(m + e)
    if not lows:
        return (0.0, 1.0)
    lo = np.nanmin(lows)
    hi = np.nanmax(highs)
    if hard[0] is not None: lo = max(lo, hard[0])
    if hard[1] is not None: hi = min(hi, hard[1])
    if not np.isfinite(lo) or not np.isfinite(hi) or lo == hi:
        lo, hi = 0.0, 1.0
    span = hi - lo
    pad_abs = pad * (span if span > 0 else 1.0)
    return (lo - pad_abs, hi + pad_abs)

def collect_stats(ds_per_all, metric_key):
    """Return dict: per period → {'OL': (mean,se,n), 'DA': (mean,se,n)}."""
    stats = {str(per): {} for per in period_labels}
    for fn, ds_all in ds_per_all.items():
        tag = label_for[fn]  # "OL" or "DA"
        if metric_key not in ds_all.data_vars:
            for per in stats: stats[per][tag] = (np.nan, np.nan, 0)
            continue
        for per in period_labels:
            da2d = ds_all[metric_key].sel(period=per)
            stats[str(per)][tag] = mean_se_2d(da2d)
    return stats

def plot_group(group_name, metrics, ylabels, hard_corr_bounds=None):
    """
    group_name: title string
    metrics   : list of metric variable names (length 3)
    ylabels   : list of y-axis labels for rows (length 3)
    hard_corr_bounds: (min,max) to clamp corr axes, e.g. (0.5, 0.75) or None
    """
    nrows = 3
    ncols = len(period_labels)
    fig, axes = plt.subplots(nrows, ncols, figsize=(4.4*ncols, 4.1*nrows), constrained_layout=True)
    if nrows == 1:
        axes = np.array([axes])

    fig.suptitle(f"{group_name} statistics (spatial means ± SE) for OL vs DA",
                 fontsize=16, weight="bold", y=1.02)

    # Pre-compute common y-lims per row across all periods
    common_lims = []
    for r, mkey in enumerate(metrics):
        S = collect_stats(results, mkey)
        # gather all mean±err across periods & tags
        all_me = []
        for per in period_labels:
            for tag in ("OL", "DA"):
                mean, se, _ = S[str(per)][tag]
                all_me.append((mean, se))
        # clamp correlations between [0,1] or given bounds if applicable
        if mkey.startswith(("R_", "anomR_")):
            hard = hard_corr_bounds if hard_corr_bounds is not None else (0.0, 1.0)
        else:
            hard = (None, None)
        common_lims.append(pooled_ylim(all_me, pad=0.22, hard=hard))

    # Now plot using the pre-computed y-lims
    for r, (mkey, ylabel) in enumerate(zip(metrics, ylabels)):
        S = collect_stats(results, mkey)
        for c, per in enumerate(period_labels):
            ax = axes[r, c]
            ol_mean, ol_se, ol_n = S[str(per)]["OL"]
            da_mean, da_se, da_n = S[str(per)]["DA"]

            means = [ol_mean, da_mean]
            errs  = [ol_se, da_se]
            ns    = [ol_n, da_n]

            x = np.arange(2)
            ax.bar(x, means, width=0.72,
                   color=[COL_OL, COL_DA], edgecolor="black", linewidth=0.8,
                   yerr=errs, capsize=6)

            ax.set_xticks(x)
            ax.set_xticklabels(["LS_OL", "LS_DA"])
            ax.set_ylim(*common_lims[r])
            ax.grid(axis="y", alpha=0.3, linestyle="--")

            # Titles: show period + n=min(OL,DA)
            ax.set_title(f"{per} (n = {min(ns)})", fontsize=11)

            # y-label on first column only
            if c == 0:
                ax.set_ylabel(ylabel)

    # Optional save
    # fig.savefig(f"bars_{group_name.replace(' ','_').lower()}.png", dpi=200, bbox_inches="tight")
    plt.show()

# ---- Make the three figures ----
# Surface SM
plot_group(
    group_name="Surface SM",
    metrics = ["R_sfc", "anomR_sfc", "ubRMSE_sfc"],
    ylabels = ["R Mean", "anomR Mean", "ubRMSE Mean (m³ m⁻³)"],
    hard_corr_bounds=(0.0, 1.0)  # keep correlations within 0..1; change if you prefer
)

# Root-zone SM
plot_group(
    group_name="Root-zone SM",
    metrics = ["R_rz", "anomR_rz", "ubRMSE_rz"],
    ylabels = ["R Mean", "anomR Mean", "ubRMSE Mean (m³ m⁻³)"],
    hard_corr_bounds=(0.0, 1.0)
)

# Snow Cover Fraction
plot_group(
    group_name="SCF",
    metrics = ["rmse_scf", "ubRMSE_scf", "bias_scf"],
    ylabels = ["RMSE Mean (1)", "ubRMSE Mean (1)", "Bias Mean (1)"],
    hard_corr_bounds=None
)


# Snow Water Equivalent
plot_group(
    group_name="SWE",
    metrics = ["rmse_swe", "ubRMSE_swe", "bias_swe"],
    ylabels = ["RMSE Mean (m)", "ubRMSE Mean (m)", "Bias Mean (m)"],
    hard_corr_bounds=None
)

# Snow Depth
plot_group(
    group_name="Snow Depth",
    metrics = ["rmse_snwd", "ubRMSE_snwd", "bias_snwd"],
    ylabels = ["RMSE Mean (m)", "ubRMSE Mean (m)", "Bias Mean (m)"],
    hard_corr_bounds=None
)

# %%
RUN_LAND_VS_ERA5 = globals().get("RUN_LAND_VS_ERA5", False)
if not RUN_LAND_VS_ERA5:
    print("Skipping ERA5-Land vs ERA5 bar charts (set RUN_LAND_VS_ERA5=True to enable).")
else:
    # --- ERA5-Land vs ERA5 bar charts (OL/DA) using summary CSVs ---
    import numpy as np
    import pandas as pd
    import matplotlib.pyplot as plt
    import ast
    from pathlib import Path

    # Resolve repo root defensively so this cell works even when run standalone.
    if 'REPO_ROOT' in globals():
        _root = Path(REPO_ROOT)
    else:
        _root = Path.cwd().resolve()
        if not (_root / "common/python/plotting/geospatial_plotting.py").exists():
            for parent in _root.parents:
                if (parent / "common/python/plotting/geospatial_plotting.py").exists():
                    _root = parent
                    break

    def _pick_existing(*candidates):
        for c in candidates:
            c = Path(c)
            if c.exists():
                return str(c)
        raise FileNotFoundError(
            "Could not find required summary CSV. Checked: "
            + ", ".join(str(Path(c)) for c in candidates)
        )

    csv_land = _pick_existing(
        _root / "ERA5_Land_periodized_metrics_summary.csv",
        Path.cwd() / "ERA5_Land_periodized_metrics_summary.csv",
    )
    csv_era5 = _pick_existing(
        _root / "ERA5_periodized_metrics_summary.csv",
        Path.cwd() / "ERA5_periodized_metrics_summary.csv",
    )

    print(f"Using csv_land: {csv_land}")
    print(f"Using csv_era5: {csv_era5}")
    def load_summary_csv(path):
        # Read without forcing MultiIndex; infer from content
        df = pd.read_csv(path)
        if "Period" in df.columns:
            df = df.set_index("Period")

        # If columns are tuple-like strings, parse safely; tolerate pandas suffixes like '.1'
        if all(isinstance(c, str) and c.startswith("(") for c in df.columns):
            parsed = []
            for c in df.columns:
                c0 = c
                try:
                    parsed.append(ast.literal_eval(c0))
                    continue
                except Exception:
                    pass

                # remove trailing .<int> added by pandas for duplicate names
                if isinstance(c0, str) and ")\." in c0:
                    base, suf = c0.rsplit(".", 1)
                    if suf.isdigit():
                        try:
                            parsed.append(ast.literal_eval(base))
                            continue
                        except Exception:
                            pass

                # fallback: keep as a generic single-level tuple
                parsed.append((str(c0), ""))

            df.columns = pd.MultiIndex.from_tuples(parsed)
        return df

    df_land = load_summary_csv(csv_land)
    df_era5 = load_summary_csv(csv_era5)

    # align periods
    common_periods = [p for p in df_land.index if p in df_era5.index]
    if not common_periods:
        raise RuntimeError("No overlapping periods between ERA5-Land and ERA5 summaries.")

    df_land = df_land.loc[common_periods]
    df_era5 = df_era5.loc[common_periods]

    pretty = {
        'anomR_sfc':'AnomCorr (Surf SM)',
        'R_sfc'    :'RawCorr (Surf SM)',
        'ubRMSE_sfc':'ubRMSE (Surf SM)',

        'anomR_rz' :'AnomCorr (RZ SM)',
        'R_rz'     :'RawCorr (RZ SM)',
        'ubRMSE_rz':'ubRMSE (RZ SM)',

        'anomR_scf':'AnomCorr (SCF)',
        'R_scf'    :'RawCorr (SCF)',
        'ubRMSE_scf':'ubRMSE (SCF)',

        'anomR_swe':'AnomCorr (SWE)',
        'R_swe'    :'RawCorr (SWE)',
        'ubRMSE_swe':'ubRMSE (SWE)',

        'anomR_snwd':'AnomCorr (Snow Depth)',
        'R_snwd'    :'RawCorr (Snow Depth)',
        'ubRMSE_snwd':'ubRMSE (Snow Depth)',

        'rmse_scf':'RMSE (SCF)',
        'bias_scf':'Bias (SCF)',
        'rmse_swe':'RMSE (SWE)',
        'bias_swe':'Bias (SWE)',
        'rmse_snwd':'RMSE (Snow Depth)',
        'bias_snwd':'Bias (Snow Depth)',
    }

    def get_val(df, tag, metric_label):
        col = (tag, metric_label)
        if col not in df.columns:
            return pd.Series(np.nan, index=df.index)
        return pd.to_numeric(df[col], errors="coerce")

    def get_n(df, tag, metric_label):
        col = (tag, f"N valid ({metric_label})")
        if col not in df.columns:
            return pd.Series(0, index=df.index)
        return pd.to_numeric(df[col], errors="coerce")

    # Colors: two blues for OL, two oranges for DA
    COL_OL_LAND = "#4C78A8"
    COL_OL_ERA5 = "#9ecae1"
    COL_DA_LAND = "#F28E2B"
    COL_DA_ERA5 = "#FDB462"

    labels = ["ERA5-Land OL", "ERA5 OL", "ERA5-Land DA", "ERA5 DA"]
    colors = [COL_OL_LAND, COL_OL_ERA5, COL_DA_LAND, COL_DA_ERA5]

    # pooled y-lims helper (same idea as earlier bar plots)

    def pooled_ylim(values, pad=0.22, hard=(None, None)):
        v = np.array(values, dtype=float)
        v = v[np.isfinite(v)]
        if v.size == 0:
            return (0.0, 1.0)
        lo = float(np.nanmin(v))
        hi = float(np.nanmax(v))
        if hard[0] is not None:
            lo = max(lo, hard[0])
        if hard[1] is not None:
            hi = min(hi, hard[1])
        if not np.isfinite(lo) or not np.isfinite(hi) or lo == hi:
            lo, hi = 0.0, 1.0
        span = hi - lo
        pad_abs = pad * (span if span > 0 else 1.0)
        return (lo - pad_abs, hi + pad_abs)


    def plot_group_from_csv(group_name, metrics, ylabels):
        nrows = 3
        ncols = len(common_periods)
        fig, axes = plt.subplots(nrows, ncols, figsize=(4.6*ncols, 4.2*nrows), constrained_layout=True)
        if nrows == 1:
            axes = np.array([axes])

        fig.suptitle(f"{group_name} statistics (ERA5-Land vs ERA5; OL & DA)",
                     fontsize=16, weight="bold", y=1.02)

        # precompute pooled y-lims per row
        row_lims = []
        for mkey in metrics:
            mlabel = pretty[mkey]
            vals = []
            for per in common_periods:
                vals.extend([
                    get_val(df_land, "OL", mlabel).loc[per],
                    get_val(df_era5, "OL", mlabel).loc[per],
                    get_val(df_land, "DA", mlabel).loc[per],
                    get_val(df_era5, "DA", mlabel).loc[per],
                ])
            hard = (0.0, 1.0) if mkey.startswith(("R_", "anomR_")) else (None, None)
            row_lims.append(pooled_ylim(vals, pad=0.22, hard=hard))

        for r, (mkey, ylabel) in enumerate(zip(metrics, ylabels)):
            mlabel = pretty[mkey]
            for c, per in enumerate(common_periods):
                ax = axes[r, c]

                vals = [
                    get_val(df_land, "OL", mlabel).loc[per],
                    get_val(df_era5, "OL", mlabel).loc[per],
                    get_val(df_land, "DA", mlabel).loc[per],
                    get_val(df_era5, "DA", mlabel).loc[per],
                ]
                ns = [
                    get_n(df_land, "OL", mlabel).loc[per],
                    get_n(df_era5, "OL", mlabel).loc[per],
                    get_n(df_land, "DA", mlabel).loc[per],
                    get_n(df_era5, "DA", mlabel).loc[per],
                ]

                x = np.arange(4)
                ax.bar(x, vals, width=0.72, color=colors, edgecolor="black", linewidth=0.7)
                ax.set_xticks(x)
                ax.set_xticklabels(["OL-L", "OL-E", "DA-L", "DA-E"], rotation=0)
                ax.set_ylim(*row_lims[r])
                ax.grid(axis="y", alpha=0.3, linestyle="--")

                # Title with min n across the four bars
                try:
                    n_min = int(np.nanmin(ns))
                except Exception:
                    n_min = 0
                ax.set_title(f"{per} (n = {n_min})", fontsize=11)

                if c == 0:
                    ax.set_ylabel(ylabel)

        # Legend
        handles = [plt.Rectangle((0, 0), 1, 1, color=c) for c in colors]
        fig.legend(handles, labels, loc="upper center", ncol=4, bbox_to_anchor=(0.5, 0.98))
        plt.show()

    # ---- Make the three figures ----
    plot_group_from_csv(
        group_name="Surface SM",
        metrics=["R_sfc", "anomR_sfc", "ubRMSE_sfc"],
        ylabels=["R Mean", "anomR Mean", "ubRMSE Mean (m³ m⁻³)"]
    )

    plot_group_from_csv(
        group_name="Root-zone SM",
        metrics=["R_rz", "anomR_rz", "ubRMSE_rz"],
        ylabels=["R Mean", "anomR Mean", "ubRMSE Mean (m³ m⁻³)"]
    )

    plot_group_from_csv(
        group_name="SCF",
        metrics=["rmse_scf", "ubRMSE_scf", "bias_scf"],
        ylabels=["RMSE Mean (1)", "ubRMSE Mean (1)", "Bias Mean (1)"]
    )


    plot_group_from_csv(
        group_name="SWE",
        metrics=["rmse_swe", "ubRMSE_swe", "bias_swe"],
        ylabels=["RMSE Mean (m)", "ubRMSE Mean (m)", "Bias Mean (m)"]
    )

    plot_group_from_csv(
        group_name="Snow Depth",
        metrics=["rmse_snwd", "ubRMSE_snwd", "bias_snwd"],
        ylabels=["RMSE Mean (m)", "ubRMSE Mean (m)", "Bias Mean (m)"]
    )

# %%
print("LAND columns:", df_land.columns[:10])
print("ERA5 columns:", df_era5.columns[:10])
print("LAND index:", df_land.index.tolist())
print("ERA5 index:", df_era5.index.tolist())
print("Example LAND row:\n", df_land.head(1))

# %%
# --- Land-fraction-weighted global monthly time series (ERA5, ERA5-Land, OL, DA) ---
import struct
from pathlib import Path

import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt

SNOW_EPS = 1e-6  # threshold for "ever snow" mask


def _resolve_repo_root():
    if 'REPO_ROOT' in globals():
        return Path(REPO_ROOT)
    p = Path.cwd().resolve()
    if (p / 'common/python/plotting/geospatial_plotting.py').exists():
        return p
    for parent in p.parents:
        if (parent / 'common/python/plotting/geospatial_plotting.py').exists():
            return parent
    return p


def _pick_existing(*candidates):
    for c in candidates:
        if c is None:
            continue
        p = Path(c)
        if p.exists():
            return p
    raise FileNotFoundError('Could not find any of: ' + ', '.join(str(Path(c)) for c in candidates if c is not None))


def _read_tilecoord(fname):
    """Read GEOS-LDAS tilecoord Fortran binary (little-endian)."""
    fields = [
        'tile_id', 'typ', 'pfaf', 'com_lon', 'com_lat', 'min_lon', 'max_lon',
        'min_lat', 'max_lat', 'i_indg', 'j_indg', 'frac_cell', 'frac_pfaf',
        'area', 'elev'
    ]
    ints = {'tile_id', 'typ', 'pfaf', 'i_indg', 'j_indg'}

    out = {}
    with open(fname, 'rb') as f:
        _ = struct.unpack('<i', f.read(4))[0]
        nt = struct.unpack('<i', f.read(4))[0]
        _ = struct.unpack('<i', f.read(4))[0]

        for fld in fields:
            _ = struct.unpack('<i', f.read(4))[0]
            dtype = 'i' if fld in ints else 'f'
            arr = np.frombuffer(f.read(nt * 4), dtype=f'<{dtype}')
            out[fld] = arr.astype(np.int32 if dtype == 'i' else np.float64)
            _ = struct.unpack('<i', f.read(4))[0]
    return out


def _land_frac_m36_from_tilecoord(tc):
    """
    Build M36 cell weights by summing frac_cell per grid cell.
    Prefer typ==1 land tiles when that mask is populated; otherwise use all positive frac_cell.
    Handles either 0-based or 1-based tilecoord grid indices.
    """
    ix = tc['i_indg'].astype(np.int64)
    iy = tc['j_indg'].astype(np.int64)

    if ix.min() == 1 and iy.min() == 1:
        ix = ix - 1
        iy = iy - 1
    elif ix.min() != 0 or iy.min() != 0:
        ix = ix - ix.min()
        iy = iy - iy.min()

    frac = tc['frac_cell'].astype(np.float64)
    typ = tc['typ'].astype(np.int64)
    finite_pos = np.isfinite(frac) & (frac > 0)

    ny = int(iy.max()) + 1
    nx = int(ix.max()) + 1

    w_all = np.zeros((ny, nx), dtype=np.float64)
    np.add.at(w_all, (iy[finite_pos], ix[finite_pos]), frac[finite_pos])

    typ1 = finite_pos & (typ == 1)
    w_typ1 = np.zeros((ny, nx), dtype=np.float64)
    if np.any(typ1):
        np.add.at(w_typ1, (iy[typ1], ix[typ1]), frac[typ1])

    nnz_all = int(np.count_nonzero(w_all > 0))
    nnz_typ1 = int(np.count_nonzero(w_typ1 > 0))
    print('tilecoord typ unique:', np.unique(typ))
    print(f'weights coverage cells: typ==1={nnz_typ1}, all_frac={nnz_all}')

    if nnz_typ1 > 0 and nnz_typ1 >= max(1000, int(0.2 * max(nnz_all, 1))):
        w = w_typ1
        print('Using typ==1-based weights')
    else:
        w = w_all
        print('Using all positive frac_cell weights (typ==1 sparse or empty)')

    return xr.DataArray(w, dims=('y', 'x'), name='land_frac')


def _weighted_global_mean_ts(da_tyx, w_yx):
    """Weighted mean with denominator based on finite pairs (default behavior)."""
    if not {'time', 'y', 'x'}.issubset(set(da_tyx.dims)):
        raise ValueError(f'Expected dims time,y,x; got {da_tyx.dims}')

    w = w_yx.astype('float64')
    valid = xr.ufuncs.isfinite(da_tyx) & xr.ufuncs.isfinite(w) & (w > 0)
    num = (da_tyx.where(valid) * w.where(valid)).sum(dim=('y', 'x'), skipna=True)
    den = w.where(valid).sum(dim=('y', 'x'), skipna=True)
    return num / den, den


def _weighted_global_mean_ts_fixed_mask(da_tyx, w_yx):
    """
    Weighted mean using a fixed spatial mask through time.
    Cells in mask are always counted in denominator; NaN data are treated as 0 in numerator.
    """
    if not {'time', 'y', 'x'}.issubset(set(da_tyx.dims)):
        raise ValueError(f'Expected dims time,y,x; got {da_tyx.dims}')

    w = w_yx.where(xr.ufuncs.isfinite(w_yx) & (w_yx > 0), 0.0).astype('float64')
    den0 = float(w.sum(dim=('y', 'x'), skipna=True).values)
    if not np.isfinite(den0) or den0 <= 0:
        raise RuntimeError('Fixed-mask denominator is not positive.')

    num = (da_tyx.where(xr.ufuncs.isfinite(da_tyx), 0.0) * w).sum(dim=('y', 'x'), skipna=True)
    ts = num / den0
    den = xr.full_like(ts, den0)
    return ts, den


ROOT = _resolve_repo_root()

fn_era5_ol = _pick_existing(
    ROOT / 'projects/era5_land/notebooks/ERA5_vs_OLv8_M36_strict_summary.nc',
    Path.cwd() / 'ERA5_vs_OLv8_M36_strict_summary.nc',
)
fn_era5_da = _pick_existing(
    ROOT / 'projects/era5_land/notebooks/ERA5_vs_DAv8_M36_strict_summary.nc',
    Path.cwd() / 'ERA5_vs_DAv8_M36_strict_summary.nc',
)
fn_era5l_ref = _pick_existing(
    ROOT / 'projects/era5_land/notebooks/ERA5L_vs_OLv8_M36_strict_summary.nc',
    ROOT / 'projects/era5_land/notebooks/ERA5L_vs_DAv8_M36_strict_summary.nc',
    Path.cwd() / 'ERA5L_vs_OLv8_M36_strict_summary.nc',
    Path.cwd() / 'ERA5L_vs_DAv8_M36_strict_summary.nc',
)

fn_tilecoord = _pick_existing(
    globals().get('ftc', None),
    ROOT / 'projects/M21C_ls/output/daily_snow_seasonal/LS_OLv8_M36.ldas_tilecoord.bin',
    Path.cwd() / 'projects/M21C_ls/output/daily_snow_seasonal/LS_OLv8_M36.ldas_tilecoord.bin',
    Path('/Users/amfox/Desktop/GEOSldas_diagnostics/test_data/land_sweeper/LS_OLv8_M36/output/SMAP_EASEv2_M36_GLOBAL/rc_out/LS_OLv8_M36.ldas_tilecoord.bin'),
)

print('Using files:')
print('  ERA5 OL  :', fn_era5_ol)
print('  ERA5 DA  :', fn_era5_da)
print('  ERA5L ref:', fn_era5l_ref)
print('  tilecoord:', fn_tilecoord)
print(f'  SNOW_EPS={SNOW_EPS}')

ds_era5_ol = xr.open_dataset(fn_era5_ol)
ds_era5_da = xr.open_dataset(fn_era5_da)
ds_era5l_ref = xr.open_dataset(fn_era5l_ref)

_applied_era5l = []
for _v in ('SWE_era', 'SNWD_era'):
    if _v in ds_era5l_ref.data_vars:
        ds_era5l_ref[_v] = ds_era5l_ref[_v].fillna(0.0)
        _applied_era5l.append(_v)
if _applied_era5l:
    print(f"Applied ERA5-Land no-snow NaN→0 for {_applied_era5l} in {Path(fn_era5l_ref).name}")

try:
    tc = _read_tilecoord(fn_tilecoord)
    w_land = _land_frac_m36_from_tilecoord(tc)

    ny = int(ds_era5_ol.sizes['y'])
    nx = int(ds_era5_ol.sizes['x'])
    if tuple(w_land.shape) != (ny, nx):
        raise ValueError(
            f'land-fraction grid shape {tuple(w_land.shape)} does not match summary grid {(ny, nx)}'
        )

    model_coverage = xr.ufuncs.isfinite(ds_era5_ol['SM_model']).any(dim='time')
    w_land = w_land.where(model_coverage, 0.0)
    print('nonzero weight cells (base land mask):', int(np.count_nonzero((w_land.values > 0))))

    # Fixed snow mask through time (strict): include a cell only if model AND reanalysis ever have snow.
    model_ever_snow = ((ds_era5_ol['SCF_model'] > SNOW_EPS) | (ds_era5_da['SCF_model'] > SNOW_EPS)).any(dim='time')
    rean_ever_snow = ((ds_era5_ol['SCF_era'] > SNOW_EPS) | (ds_era5l_ref['SCF_era'] > SNOW_EPS)).any(dim='time')
    snow_mask_fixed = model_ever_snow & rean_ever_snow
    w_snow = w_land.where(snow_mask_fixed, 0.0)

    print('nonzero weight cells (fixed snow mask, AND):', int(np.count_nonzero((w_snow.values > 0))))
    print('fixed snow-mask weight sum:', float(np.nansum(w_snow.values)))

    var_specs = [
        ('Surface SM',     'SM_model',   'SM_era',   'm$^3$ m$^{-3}$', False),
        ('RZ',             'RZ_model',   'RZ_era',   'm$^3$ m$^{-3}$', False),
        ('SCF',            'SCF_model',  'SCF_era',  '1',              True),
        ('SWE',            'SWE_model',  'SWE_era',  'm',              True),
        ('SD',             'SNWD_model', 'SNWD_era', 'm',              True),
    ]

    colors = {
        'ERA5': '#1f77b4',
        'ERA5-Land': '#2ca02c',
        'OL': '#d62728',
        'DA': '#ff7f0e',
    }

    # Compute all time series once, then plot in two figures.
    series_by_var = {}
    for title, model_var, ref_var, units, is_snow_var in var_specs:
        w_use = w_snow if is_snow_var else w_land
        agg_fn = _weighted_global_mean_ts_fixed_mask if is_snow_var else _weighted_global_mean_ts

        ts_era5, den_era5 = agg_fn(ds_era5_ol[ref_var].astype('float64'), w_use)
        ts_era5l, den_era5l = agg_fn(ds_era5l_ref[ref_var].astype('float64'), w_use)
        ts_ol, den_ol = agg_fn(ds_era5_ol[model_var].astype('float64'), w_use)
        ts_da, den_da = agg_fn(ds_era5_da[model_var].astype('float64'), w_use)

        ts_era5, ts_era5l, ts_ol, ts_da, den_era5, den_era5l, den_ol, den_da = xr.align(
            ts_era5, ts_era5l, ts_ol, ts_da, den_era5, den_era5l, den_ol, den_da, join='inner'
        )

        ntime = int(ts_era5.sizes.get('time', 0))
        if ntime == 0:
            raise RuntimeError(f'No overlapping time points for {title}.')

        nfin = (
            int(np.isfinite(ts_era5.values).sum()),
            int(np.isfinite(ts_era5l.values).sum()),
            int(np.isfinite(ts_ol.values).sum()),
            int(np.isfinite(ts_da.values).sum()),
        )
        print(f"{title}: ntime={ntime}, fixed_snow_mask={is_snow_var}, finite counts [ERA5, ERA5L, OL, DA] = {nfin}")
        print(
            f"  denom min/max [ERA5, ERA5L, OL, DA] = "
            f"({float(np.nanmin(den_era5.values)):.3e}, {float(np.nanmax(den_era5.values)):.3e}) / "
            f"({float(np.nanmin(den_era5l.values)):.3e}, {float(np.nanmax(den_era5l.values)):.3e}) / "
            f"({float(np.nanmin(den_ol.values)):.3e}, {float(np.nanmax(den_ol.values)):.3e}) / "
            f"({float(np.nanmin(den_da.values)):.3e}, {float(np.nanmax(den_da.values)):.3e})"
        )

        try:
            t = pd.to_datetime(ts_era5['time'].values)
        except Exception:
            t = np.arange(ntime)

        series_by_var[title] = {
            'time': t,
            'units': units,
            'ERA5': ts_era5.values,
            'ERA5-Land': ts_era5l.values,
            'OL': ts_ol.values,
            'DA': ts_da.values,
        }

    def _plot_group(var_titles, fig_title):
        panel_h = 3.2
        fig_w = 16
        top_pad = 1.0
        fig_h = top_pad + panel_h * len(var_titles)

        fig, axes = plt.subplots(
            len(var_titles),
            1,
            figsize=(fig_w, fig_h),
            sharex=True,
            constrained_layout=False,
        )
        if len(var_titles) == 1:
            axes = [axes]

        for ax, title in zip(axes, var_titles):
            d = series_by_var[title]
            t = d['time']

            ax.plot(t, d['ERA5'], label='ERA5', color=colors['ERA5'], lw=1.8)
            ax.plot(t, d['ERA5-Land'], label='ERA5-Land', color=colors['ERA5-Land'], lw=1.8)
            ax.plot(t, d['OL'], label='OL', color=colors['OL'], lw=1.6, linestyle=':')
            ax.plot(t, d['DA'], label='DA', color=colors['DA'], lw=1.6)

            ax.set_title(f'{title} global monthly mean (weighted)')
            ax.set_ylabel(d['units'])
            ax.grid(True, alpha=0.3, linestyle='--')

        axes[-1].set_xlabel('Time')
        handles, labels = axes[0].get_legend_handles_labels()
        fig.legend(handles, labels, loc='upper center', ncol=4, bbox_to_anchor=(0.5, 0.995))
        fig.suptitle(fig_title, y=0.995)
        fig.tight_layout(rect=[0, 0, 1, 0.95])
        plt.show()

    _plot_group(['Surface SM', 'RZ'], 'Global Monthly Means: Soil Moisture')
    _plot_group(['SCF', 'SWE', 'SD'], 'Global Monthly Means: Snow Variables')

finally:
    ds_era5_ol.close()
    ds_era5_da.close()
    ds_era5l_ref.close()

# %%
# --- Maps: Fixed Snow Mask + Mean August Snow Depth (ERA5, ERA5-Land, OL) | Robinson 4x1 ---
from pathlib import Path
import struct
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from matplotlib.colors import ListedColormap

# Match the strict mask logic used in the timeseries cell.
SNOW_EPS_MAP = float(globals().get('SNOW_EPS', 1e-6))
LAT_MIN_MAP = -60.0


def _resolve_repo_root_local():
    if 'REPO_ROOT' in globals():
        return Path(REPO_ROOT)
    p0 = Path.cwd().resolve()
    if (p0 / 'common/python/plotting/geospatial_plotting.py').exists():
        return p0
    for parent in p0.parents:
        if (parent / 'common/python/plotting/geospatial_plotting.py').exists():
            return parent
    return p0


def _pick_existing_local(*candidates):
    for c in candidates:
        if c is None:
            continue
        p1 = Path(c)
        if p1.exists():
            return p1
    raise FileNotFoundError('Could not find any of: ' + ', '.join(str(Path(c)) for c in candidates if c is not None))


def _nan_greenland_antarctica(lon2d, lat2d, z2d):
    """Mask Greenland + Antarctica before plotting."""
    lon = np.asarray(lon2d, dtype=float)
    lat = np.asarray(lat2d, dtype=float)
    z = np.asarray(z2d, dtype=float).copy()

    lon180 = ((lon + 180.0) % 360.0) - 180.0
    antarctica = lat <= -60.0
    greenland = (lat >= 58.0) & (lat <= 85.0) & (lon180 >= -75.0) & (lon180 <= -10.0)

    z[antarctica | greenland] = np.nan
    return z


def _read_tilecoord_local(fname):
    fields = [
        'tile_id', 'typ', 'pfaf', 'com_lon', 'com_lat', 'min_lon', 'max_lon',
        'min_lat', 'max_lat', 'i_indg', 'j_indg', 'frac_cell', 'frac_pfaf',
        'area', 'elev'
    ]
    ints = {'tile_id', 'typ', 'pfaf', 'i_indg', 'j_indg'}

    out = {}
    with open(fname, 'rb') as f:
        _ = struct.unpack('<i', f.read(4))[0]
        nt = struct.unpack('<i', f.read(4))[0]
        _ = struct.unpack('<i', f.read(4))[0]

        for fld in fields:
            _ = struct.unpack('<i', f.read(4))[0]
            dtype = 'i' if fld in ints else 'f'
            arr = np.frombuffer(f.read(nt * 4), dtype=f'<{dtype}')
            out[fld] = arr.astype(np.int32 if dtype == 'i' else np.float64)
            _ = struct.unpack('<i', f.read(4))[0]
    return out


def _land_frac_m36_from_tilecoord_local(tc):
    ix = tc['i_indg'].astype(np.int64)
    iy = tc['j_indg'].astype(np.int64)

    if ix.min() == 1 and iy.min() == 1:
        ix = ix - 1
        iy = iy - 1
    elif ix.min() != 0 or iy.min() != 0:
        ix = ix - ix.min()
        iy = iy - iy.min()

    frac = tc['frac_cell'].astype(np.float64)
    typ = tc['typ'].astype(np.int64)
    finite_pos = np.isfinite(frac) & (frac > 0)

    ny = int(iy.max()) + 1
    nx = int(ix.max()) + 1

    w_all = np.zeros((ny, nx), dtype=np.float64)
    np.add.at(w_all, (iy[finite_pos], ix[finite_pos]), frac[finite_pos])

    typ1 = finite_pos & (typ == 1)
    w_typ1 = np.zeros((ny, nx), dtype=np.float64)
    if np.any(typ1):
        np.add.at(w_typ1, (iy[typ1], ix[typ1]), frac[typ1])

    nnz_all = int(np.count_nonzero(w_all > 0))
    nnz_typ1 = int(np.count_nonzero(w_typ1 > 0))

    if nnz_typ1 > 0 and nnz_typ1 >= max(1000, int(0.2 * max(nnz_all, 1))):
        return w_typ1
    return w_all


ROOT = _resolve_repo_root_local()
fn_era5_ol = _pick_existing_local(
    ROOT / 'projects/era5_land/notebooks/ERA5_vs_OLv8_M36_strict_summary.nc',
    Path.cwd() / 'ERA5_vs_OLv8_M36_strict_summary.nc',
)
fn_era5_da = _pick_existing_local(
    ROOT / 'projects/era5_land/notebooks/ERA5_vs_DAv8_M36_strict_summary.nc',
    Path.cwd() / 'ERA5_vs_DAv8_M36_strict_summary.nc',
)
fn_era5l_ol = _pick_existing_local(
    ROOT / 'projects/era5_land/notebooks/ERA5L_vs_OLv8_M36_strict_summary.nc',
    Path.cwd() / 'ERA5L_vs_OLv8_M36_strict_summary.nc',
)

print('Using:')
print('  ERA5/OL file   :', fn_era5_ol)
print('  ERA5/DA file   :', fn_era5_da)
print('  ERA5L/OL file  :', fn_era5l_ol)
print('  SNOW_EPS_MAP   :', SNOW_EPS_MAP)

ds_era5 = xr.open_dataset(fn_era5_ol)
ds_era5_da = xr.open_dataset(fn_era5_da)
ds_era5l = xr.open_dataset(fn_era5l_ol)

_applied_era5l = []
for _v in ('SWE_era', 'SNWD_era'):
    if _v in ds_era5l.data_vars:
        ds_era5l[_v] = ds_era5l[_v].fillna(0.0)
        _applied_era5l.append(_v)
if _applied_era5l:
    print(f"Applied ERA5-Land no-snow NaN→0 for {_applied_era5l} in {Path(fn_era5l_ol).name}")

try:
    # Snow depth fields for August maps
    snwd_era5 = ds_era5['SNWD_era'].astype('float64')
    snwd_era5l = ds_era5l['SNWD_era'].astype('float64')
    snwd_ol = ds_era5['SNWD_model'].astype('float64')

    # Align to common monthly timestamps across all three series.
    snwd_era5, snwd_era5l, snwd_ol = xr.align(snwd_era5, snwd_era5l, snwd_ol, join='inner')

    t = pd.to_datetime(snwd_era5['time'].values)
    aug_idx = np.where(t.month == 8)[0]
    if aug_idx.size == 0:
        raise RuntimeError('No August months found in aligned time axis.')

    aug_years = sorted(set(pd.DatetimeIndex(t[aug_idx]).year.tolist()))
    print(f'Common August samples: {aug_idx.size} ({aug_years[0]}..{aug_years[-1]})')

    mean_aug_era5 = snwd_era5.isel(time=aug_idx).mean(dim='time', skipna=True)
    mean_aug_era5l = snwd_era5l.isel(time=aug_idx).mean(dim='time', skipna=True)
    mean_aug_ol = snwd_ol.isel(time=aug_idx).mean(dim='time', skipna=True)

    # Keep unmasked August means for weighted annotation (match monthly-timeseries style).
    mean_aug_era5_raw = np.asarray(mean_aug_era5.values, dtype=float)
    mean_aug_era5l_raw = np.asarray(mean_aug_era5l.values, dtype=float)
    mean_aug_ol_raw = np.asarray(mean_aug_ol.values, dtype=float)

    # Fixed strict snow mask (AND): model ever snow AND reanalysis ever snow
    model_ever_snow = ((ds_era5['SCF_model'] > SNOW_EPS_MAP) | (ds_era5_da['SCF_model'] > SNOW_EPS_MAP)).any(dim='time')
    rean_ever_snow = ((ds_era5['SCF_era'] > SNOW_EPS_MAP) | (ds_era5l['SCF_era'] > SNOW_EPS_MAP)).any(dim='time')
    snow_mask_fixed = (model_ever_snow & rean_ever_snow).astype('float64')

    lat2d = ds_era5['lat'].values
    lon2d = ds_era5['lon'].values

    # Land-fraction weights for fixed-mask means (to match monthly-timeseries weighting).
    if 'w_land' in globals():
        _wl = globals()['w_land']
        w_land_map = np.asarray(_wl.values if hasattr(_wl, 'values') else _wl, dtype=float)
        print('Using w_land from globals for annotation weights')
    else:
        fn_tilecoord = _pick_existing_local(
            globals().get('ftc', None),
            ROOT / 'projects/M21C_ls/output/daily_snow_seasonal/LS_OLv8_M36.ldas_tilecoord.bin',
            Path.cwd() / 'projects/M21C_ls/output/daily_snow_seasonal/LS_OLv8_M36.ldas_tilecoord.bin',
            Path('/Users/amfox/Desktop/GEOSldas_diagnostics/test_data/land_sweeper/LS_OLv8_M36/output/SMAP_EASEv2_M36_GLOBAL/rc_out/LS_OLv8_M36.ldas_tilecoord.bin'),
        )
        if '_read_tilecoord' in globals() and '_land_frac_m36_from_tilecoord' in globals():
            tc = globals()['_read_tilecoord'](fn_tilecoord)
            w_land_map = np.asarray(globals()['_land_frac_m36_from_tilecoord'](tc).values, dtype=float)
            print(f'Using tilecoord weights via existing helpers: {fn_tilecoord}')
        else:
            tc = _read_tilecoord_local(fn_tilecoord)
            w_land_map = _land_frac_m36_from_tilecoord_local(tc)
            print(f'Using tilecoord weights via local helpers: {fn_tilecoord}')

    if w_land_map.shape != np.asarray(lat2d).shape:
        raise ValueError(f'Land-fraction weight shape {w_land_map.shape} does not match map grid {np.asarray(lat2d).shape}')

    model_coverage = np.isfinite(np.asarray(ds_era5['SM_model'].values)).any(axis=0)
    w_land_map = np.where(model_coverage & np.isfinite(w_land_map) & (w_land_map > 0), w_land_map, 0.0)

    snow_mask_bool_ts = np.isfinite(np.asarray(snow_mask_fixed.values)) & (np.asarray(snow_mask_fixed.values) > 0.5)
    w_snow_annot = np.where(snow_mask_bool_ts, w_land_map, 0.0)
    den_w_snow = float(np.nansum(w_snow_annot))
    print('fixed snow-mask land-fraction denominator:', den_w_snow)

    # Mask Greenland + Antarctica before mapping
    mean_aug_era5 = xr.DataArray(
        _nan_greenland_antarctica(lon2d, lat2d, mean_aug_era5.values),
        coords=mean_aug_era5.coords,
        dims=mean_aug_era5.dims,
    )
    mean_aug_era5l = xr.DataArray(
        _nan_greenland_antarctica(lon2d, lat2d, mean_aug_era5l.values),
        coords=mean_aug_era5l.coords,
        dims=mean_aug_era5l.dims,
    )
    mean_aug_ol = xr.DataArray(
        _nan_greenland_antarctica(lon2d, lat2d, mean_aug_ol.values),
        coords=mean_aug_ol.coords,
        dims=mean_aug_ol.dims,
    )
    snow_mask_fixed = xr.DataArray(
        _nan_greenland_antarctica(lon2d, lat2d, snow_mask_fixed.values),
        coords=snow_mask_fixed.coords,
        dims=snow_mask_fixed.dims,
    )

    finite_xy = np.isfinite(lat2d) & np.isfinite(lon2d) & (lat2d >= LAT_MIN_MAP)

    def _fixed_mask_landfrac_mean(z_raw):
        if (not np.isfinite(den_w_snow)) or (den_w_snow <= 0):
            return np.nan
        z_num = np.where(np.isfinite(z_raw), z_raw, 0.0)
        return float(np.nansum(z_num * w_snow_annot) / den_w_snow)

    mean_fixed_era5 = _fixed_mask_landfrac_mean(mean_aug_era5_raw)
    mean_fixed_era5l = _fixed_mask_landfrac_mean(mean_aug_era5l_raw)
    mean_fixed_ol = _fixed_mask_landfrac_mean(mean_aug_ol_raw)

    # Shared color scale for the three snow-depth maps only
    pool = np.concatenate([
        np.asarray(mean_aug_era5.values).ravel(),
        np.asarray(mean_aug_era5l.values).ravel(),
        np.asarray(mean_aug_ol.values).ravel(),
    ])
    pool = pool[np.isfinite(pool)]
    if pool.size == 0:
        raise RuntimeError('No finite values to plot for August snow depth maps.')

    vmin = 0.0
    vmax = float(np.nanquantile(pool, 0.99))
    if not np.isfinite(vmax) or vmax <= vmin:
        vmax = float(np.nanmax(pool))
    if not np.isfinite(vmax) or vmax <= vmin:
        vmax = 1.0

    def _plot_panel(ax, da2d, title, cmap, vmin0, vmax0, annotate_text=None):
        z = np.asarray(da2d.values)
        finite_all = finite_xy & np.isfinite(z)

        ax.set_global()
        ax.set_extent([-180.0, 180.0, LAT_MIN_MAP, 90.0], crs=ccrs.PlateCarree())
        ax.add_feature(cfeature.LAND, facecolor='0.9', zorder=0)
        ax.add_feature(cfeature.OCEAN, facecolor='white', zorder=0)
        ax.add_feature(cfeature.COASTLINE, linewidth=0.5, zorder=2)
        ax.add_feature(cfeature.BORDERS, linewidth=0.25, zorder=2)
        gl = ax.gridlines(draw_labels=False, linewidth=0.4, color='gray', alpha=0.35, linestyle='--')
        _ = gl

        if int(finite_all.sum()) == 0:
            ax.set_title(title)
            ax.text(0.5, 0.5, 'No finite data', ha='center', va='center', transform=ax.transAxes)
            return None

        if bool(np.all(finite_xy)):
            artist = ax.pcolormesh(
                lon2d,
                lat2d,
                z,
                transform=ccrs.PlateCarree(),
                shading='auto',
                cmap=cmap,
                vmin=vmin0,
                vmax=vmax0,
                zorder=1,
            )
        else:
            artist = ax.scatter(
                lon2d[finite_all],
                lat2d[finite_all],
                c=z[finite_all],
                transform=ccrs.PlateCarree(),
                s=5,
                marker='s',
                linewidths=0,
                cmap=cmap,
                vmin=vmin0,
                vmax=vmax0,
                zorder=1,
            )

        if annotate_text is not None:
            ax.text(
                0.02,
                0.03,
                annotate_text,
                transform=ax.transAxes,
                ha='left',
                va='bottom',
                fontsize=9,
                bbox=dict(facecolor='white', edgecolor='none', alpha=0.8, pad=2.0),
                zorder=3,
            )

        ax.set_title(title, fontsize=12)
        return artist

    proj = ccrs.Robinson(central_longitude=0)
    fig, axes = plt.subplots(4, 1, figsize=(14, 19), subplot_kw={'projection': proj}, constrained_layout=True)

    mask_cmap = ListedColormap(['#f2f2f2', '#1f78b4'])
    a_mask = _plot_panel(
        axes[0],
        snow_mask_fixed,
        'Fixed Snow Mask (AND): model ever snow ∩ reanalysis ever snow',
        cmap=mask_cmap,
        vmin0=0.0,
        vmax0=1.0,
    )

    txt_era5 = (f'Fixed-mask land-frac mean: {mean_fixed_era5:.3g} m' if np.isfinite(mean_fixed_era5) else 'Fixed-mask land-frac mean: NaN')
    txt_era5l = (f'Fixed-mask land-frac mean: {mean_fixed_era5l:.3g} m' if np.isfinite(mean_fixed_era5l) else 'Fixed-mask land-frac mean: NaN')
    txt_ol = (f'Fixed-mask land-frac mean: {mean_fixed_ol:.3g} m' if np.isfinite(mean_fixed_ol) else 'Fixed-mask land-frac mean: NaN')

    a0 = _plot_panel(axes[1], mean_aug_era5, 'ERA5: Mean August Snow Depth (m)', cmap='Blues', vmin0=vmin, vmax0=vmax, annotate_text=txt_era5)
    a1 = _plot_panel(axes[2], mean_aug_era5l, 'ERA5-Land: Mean August Snow Depth (m)', cmap='Blues', vmin0=vmin, vmax0=vmax, annotate_text=txt_era5l)
    a2 = _plot_panel(axes[3], mean_aug_ol, 'OL: Mean August Snow Depth (m)', cmap='Blues', vmin0=vmin, vmax0=vmax, annotate_text=txt_ol)

    if a_mask is not None:
        cbm = fig.colorbar(a_mask, ax=[axes[0]], orientation='horizontal', fraction=0.04, pad=0.03)
        cbm.set_ticks([0, 1])
        cbm.set_ticklabels(['No', 'Yes'])
        cbm.set_label('In fixed snow mask')

    artist_for_cb = a0 if a0 is not None else (a1 if a1 is not None else a2)
    if artist_for_cb is not None:
        cb = fig.colorbar(artist_for_cb, ax=axes[1:], orientation='horizontal', fraction=0.03, pad=0.03)
        cb.set_label('Snow depth (m)')

    plt.show()

    # Additional 3x1 figure: the three snow-depth panels only (same fields as lower 3 in 4x1).
    fig3, axes3 = plt.subplots(3, 1, figsize=(14, 14.5), subplot_kw={'projection': proj}, constrained_layout=True)

    b0 = _plot_panel(axes3[0], mean_aug_era5, 'ERA5: Mean August Snow Depth (m)', cmap='Blues', vmin0=vmin, vmax0=vmax, annotate_text=txt_era5)
    b1 = _plot_panel(axes3[1], mean_aug_era5l, 'ERA5-Land: Mean August Snow Depth (m)', cmap='Blues', vmin0=vmin, vmax0=vmax, annotate_text=txt_era5l)
    b2 = _plot_panel(axes3[2], mean_aug_ol, 'OL: Mean August Snow Depth (m)', cmap='Blues', vmin0=vmin, vmax0=vmax, annotate_text=txt_ol)

    artist3 = b0 if b0 is not None else (b1 if b1 is not None else b2)
    if artist3 is not None:
        cb3 = fig3.colorbar(artist3, ax=axes3, orientation='horizontal', fraction=0.03, pad=0.04)
        cb3.set_label('Snow depth (m)')

    plt.show()

finally:
    ds_era5.close()
    ds_era5_da.close()
    ds_era5l.close()

# %%
# --- Distribution diagnostics: August Snow Depth (ERA5, ERA5-Land, OL) ---
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


def _as_array_from_globals(raw_name, da_name):
    if raw_name in globals():
        return np.asarray(globals()[raw_name], dtype=float)
    if da_name in globals():
        obj = globals()[da_name]
        return np.asarray(obj.values if hasattr(obj, "values") else obj, dtype=float)
    raise RuntimeError(f"Missing both {raw_name} and {da_name}; run the August snow map cell first.")


def _weighted_ecdf(x, w):
    idx = np.argsort(x)
    xs = x[idx]
    ws = w[idx]
    cw = np.cumsum(ws)
    cw = cw / cw[-1]
    return xs, cw


def _weighted_quantile(x, w, q):
    idx = np.argsort(x)
    xs = x[idx]
    ws = w[idx]
    cw = np.cumsum(ws)
    cw = cw / cw[-1]
    return np.interp(q, cw, xs, left=xs[0], right=xs[-1])


def _prep_series(z2d, w2d):
    valid = np.isfinite(z2d) & np.isfinite(w2d) & (w2d > 0)
    if not np.any(valid):
        raise RuntimeError("No valid weighted cells for distribution diagnostics.")
    return z2d[valid], w2d[valid]


# Inputs from the August snow map cell
z_era5 = _as_array_from_globals("mean_aug_era5_raw", "mean_aug_era5")
z_era5l = _as_array_from_globals("mean_aug_era5l_raw", "mean_aug_era5l")
z_ol = _as_array_from_globals("mean_aug_ol_raw", "mean_aug_ol")

if "snow_mask_fixed" not in globals():
    raise RuntimeError("snow_mask_fixed not found; run the August snow map cell first.")
snow_mask = globals()["snow_mask_fixed"]
snow_mask = np.asarray(snow_mask.values if hasattr(snow_mask, "values") else snow_mask, dtype=float)

if "w_land_map" in globals():
    w_land_arr = np.asarray(globals()["w_land_map"], dtype=float)
elif "w_land" in globals():
    _w = globals()["w_land"]
    w_land_arr = np.asarray(_w.values if hasattr(_w, "values") else _w, dtype=float)
else:
    raise RuntimeError("No land-fraction weights found (w_land_map or w_land).")

if "lat2d" not in globals() or "lon2d" not in globals():
    raise RuntimeError("lat2d/lon2d not found; run the August snow map cell first.")
lat = np.asarray(globals()["lat2d"], dtype=float)
lon = np.asarray(globals()["lon2d"], dtype=float)

shape_ref = z_era5.shape
for nm, arr in [
    ("ERA5", z_era5),
    ("ERA5-Land", z_era5l),
    ("OL", z_ol),
    ("snow_mask", snow_mask),
    ("w_land", w_land_arr),
    ("lat", lat),
    ("lon", lon),
]:
    if arr.shape != shape_ref:
        raise ValueError(f"Shape mismatch for {nm}: {arr.shape} vs {shape_ref}")

# Match map domain: fixed snow mask, south cutoff at -60, Greenland masked
snow_bool = np.isfinite(snow_mask) & (snow_mask > 0.5)
lon180 = ((lon + 180.0) % 360.0) - 180.0
greenland = (lat >= 58.0) & (lat <= 85.0) & (lon180 >= -75.0) & (lon180 <= -10.0)
domain = snow_bool & np.isfinite(lat) & np.isfinite(lon) & (lat >= -60.0) & (~greenland)

w_domain = np.where(domain & np.isfinite(w_land_arr) & (w_land_arr > 0), w_land_arr, 0.0)
den_domain = float(np.nansum(w_domain))
if (not np.isfinite(den_domain)) or den_domain <= 0:
    raise RuntimeError("Domain weight denominator is invalid.")

series = {
    "ERA5": _prep_series(z_era5, w_domain),
    "ERA5-Land": _prep_series(z_era5l, w_domain),
    "OL": _prep_series(z_ol, w_domain),
}
colors = {"ERA5": "#1f77b4", "ERA5-Land": "#2ca02c", "OL": "#d62728"}

print(f"Distribution domain: weighted cells={int(np.count_nonzero(w_domain > 0))}, weight sum={den_domain:.6g}")

# 1) Weighted ECDF
fig, ax = plt.subplots(figsize=(10.5, 6), constrained_layout=True)
for name in ["ERA5", "ERA5-Land", "OL"]:
    x, w = series[name]
    xs, ys = _weighted_ecdf(x, w)
    ax.plot(xs, ys, lw=2, color=colors[name], label=f"{name} (n={x.size:,})")
ax.set_xlabel("Mean August snow depth (m)")
ax.set_ylabel("Weighted cumulative fraction")
ax.set_title("Weighted ECDF: Mean August Snow Depth")
ax.grid(True, alpha=0.3, linestyle="--")
ax.legend()
plt.show()

# 2) Weighted histogram for positive snow + weighted zero fraction
pool_pos = np.concatenate([x[x > 0] for x, _ in series.values()])
if pool_pos.size > 0:
    p01 = float(np.nanquantile(pool_pos, 0.01))
    p99 = float(np.nanquantile(pool_pos, 0.99))
    lo = max(1e-5, p01)
    hi = max(lo * 1.25, p99)
    bins = np.geomspace(lo, hi, 35)
else:
    bins = np.linspace(0.0, 1.0, 35)

fig, ax = plt.subplots(figsize=(10.5, 6), constrained_layout=True)
zero_rows = []
for name in ["ERA5", "ERA5-Land", "OL"]:
    x, w = series[name]
    wsum = float(np.sum(w))
    frac_zero = float(np.sum(w[x <= 0]) / wsum)
    frac_pos = 1.0 - frac_zero
    zero_rows.append((name, frac_zero, frac_pos))

    pos = x > 0
    if np.any(pos):
        h, e = np.histogram(x[pos], bins=bins, weights=w[pos] / wsum)
        ax.step(e[:-1], h, where="post", lw=2, color=colors[name], label=f"{name} (zero={frac_zero:.1%})")
ax.set_xscale("log")
ax.set_xlabel("Mean August snow depth (m), positive bins")
ax.set_ylabel("Weighted area fraction per bin")
ax.set_title("Weighted Histogram (positive SD) + Zero-Snow Fraction")
ax.grid(True, which="both", alpha=0.3, linestyle="--")
ax.legend()
plt.show()

zero_df = pd.DataFrame(zero_rows, columns=["dataset", "zero_fraction", "positive_fraction"])
print("Weighted zero/positive fractions:")
display(zero_df.style.format({"zero_fraction": "{:.2%}", "positive_fraction": "{:.2%}"}))

# 3) Weighted quantile summary
q_levels = np.array([0.10, 0.25, 0.50, 0.75, 0.90, 0.99])
rows = []
for name in ["ERA5", "ERA5-Land", "OL"]:
    x, w = series[name]
    wsum = float(np.sum(w))
    qvals = _weighted_quantile(x, w, q_levels)
    rows.append({
        "dataset": name,
        "weighted_mean_m": float(np.sum(x * w) / wsum),
        "weighted_zero_fraction": float(np.sum(w[x <= 0]) / wsum),
        "P10_m": float(qvals[0]),
        "P25_m": float(qvals[1]),
        "P50_m": float(qvals[2]),
        "P75_m": float(qvals[3]),
        "P90_m": float(qvals[4]),
        "P99_m": float(qvals[5]),
        "n_valid_cells": int(x.size),
    })

q_df = pd.DataFrame(rows).set_index("dataset")
print("Weighted quantile summary (mean August SD):")
display(q_df.style.format({
    "weighted_mean_m": "{:.4f}",
    "weighted_zero_fraction": "{:.2%}",
    "P10_m": "{:.4f}",
    "P25_m": "{:.4f}",
    "P50_m": "{:.4f}",
    "P75_m": "{:.4f}",
    "P90_m": "{:.4f}",
    "P99_m": "{:.4f}",
}))

# 4) Q-Q plots vs ERA5
def _qq_against(ref_x, ref_w, cmp_x, cmp_w, n=250):
    p = np.linspace(0.01, 0.99, n)
    q_ref = _weighted_quantile(ref_x, ref_w, p)
    q_cmp = _weighted_quantile(cmp_x, cmp_w, p)
    return q_ref, q_cmp

ref_x, ref_w = series["ERA5"]
fig, axes = plt.subplots(1, 2, figsize=(13.5, 5.5), constrained_layout=True)
for ax, name in zip(axes, ["ERA5-Land", "OL"]):
    cmp_x, cmp_w = series[name]
    q_ref, q_cmp = _qq_against(ref_x, ref_w, cmp_x, cmp_w)
    mx = np.nanmax(np.concatenate([q_ref, q_cmp]))
    mn = np.nanmin(np.concatenate([q_ref, q_cmp]))
    ax.plot([mn, mx], [mn, mx], "k--", lw=1.2, label="1:1")
    ax.plot(q_ref, q_cmp, color=colors[name], lw=2)
    ax.set_xlabel("ERA5 weighted quantiles (m)")
    ax.set_ylabel(f"{name} weighted quantiles (m)")
    ax.set_title(f"Q-Q: {name} vs ERA5")
    ax.grid(True, alpha=0.3, linestyle="--")
    ax.legend(loc="upper left")

plt.show()

# %%
# --- Maps: Mean August Snow Depth Differences (ERA5-OL, ERA5-Land-OL) ---
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from matplotlib.colors import TwoSlopeNorm


def _arr_from_globals(raw_name, mapped_name):
    if raw_name in globals():
        return np.asarray(globals()[raw_name], dtype=float)
    if mapped_name in globals():
        v = globals()[mapped_name]
        return np.asarray(v.values if hasattr(v, "values") else v, dtype=float)
    raise RuntimeError(f"Missing both {raw_name} and {mapped_name}; run the August snow map cell first.")


if "lat2d" not in globals() or "lon2d" not in globals():
    raise RuntimeError("lat2d/lon2d not found; run the August snow map cell first.")
lat = np.asarray(globals()["lat2d"], dtype=float)
lon = np.asarray(globals()["lon2d"], dtype=float)

z_era5 = _arr_from_globals("mean_aug_era5_raw", "mean_aug_era5")
z_era5l = _arr_from_globals("mean_aug_era5l_raw", "mean_aug_era5l")
z_ol = _arr_from_globals("mean_aug_ol_raw", "mean_aug_ol")

shape_ref = z_era5.shape
for nm, arr in [("ERA5", z_era5), ("ERA5-Land", z_era5l), ("OL", z_ol), ("lat", lat), ("lon", lon)]:
    if arr.shape != shape_ref:
        raise ValueError(f"Shape mismatch for {nm}: {arr.shape} vs {shape_ref}")

# Domain/mask to match the snow maps
lon180 = ((lon + 180.0) % 360.0) - 180.0
greenland = (lat >= 58.0) & (lat <= 85.0) & (lon180 >= -75.0) & (lon180 <= -10.0)
domain = np.isfinite(lat) & np.isfinite(lon) & (lat >= -60.0) & (~greenland)

if "snow_mask_fixed" in globals():
    sm = globals()["snow_mask_fixed"]
    sm = np.asarray(sm.values if hasattr(sm, "values") else sm, dtype=float)
    if sm.shape == shape_ref:
        domain = domain & np.isfinite(sm) & (sm > 0.5)

d_era5_ol = np.where(domain, z_era5 - z_ol, np.nan)
d_era5l_ol = np.where(domain, z_era5l - z_ol, np.nan)

pool = np.concatenate([d_era5_ol.ravel(), d_era5l_ol.ravel()])
pool = pool[np.isfinite(pool)]
if pool.size == 0:
    raise RuntimeError("No finite values to plot for difference maps.")

vmax = float(np.nanquantile(np.abs(pool), 0.99))
if not np.isfinite(vmax) or vmax <= 0:
    vmax = float(np.nanmax(np.abs(pool)))
if not np.isfinite(vmax) or vmax <= 0:
    vmax = 1e-6

norm = TwoSlopeNorm(vmin=-vmax, vcenter=0.0, vmax=vmax)
finite_xy = np.isfinite(lat) & np.isfinite(lon)

def _plot(ax, z, title):
    valid = finite_xy & np.isfinite(z)
    ax.set_global()
    ax.add_feature(cfeature.LAND, facecolor="0.9", zorder=0)
    ax.add_feature(cfeature.OCEAN, facecolor="white", zorder=0)
    ax.add_feature(cfeature.COASTLINE, linewidth=0.5, zorder=2)
    ax.add_feature(cfeature.BORDERS, linewidth=0.25, zorder=2)
    ax.gridlines(draw_labels=False, linewidth=0.4, color="gray", alpha=0.35, linestyle="--")

    if int(valid.sum()) == 0:
        ax.set_title(title)
        ax.text(0.5, 0.5, "No finite data", ha="center", va="center", transform=ax.transAxes)
        return None

    if bool(np.all(finite_xy)):
        artist = ax.pcolormesh(
            lon, lat, z,
            transform=ccrs.PlateCarree(),
            shading="auto",
            cmap="RdBu_r",
            norm=norm,
            zorder=1,
        )
    else:
        artist = ax.scatter(
            lon[valid], lat[valid], c=z[valid],
            transform=ccrs.PlateCarree(),
            s=5, marker="s", linewidths=0,
            cmap="RdBu_r", norm=norm, zorder=1,
        )

    if "w_land_map" in globals():
        w = np.asarray(globals()["w_land_map"], dtype=float)
        if w.shape == z.shape:
            m = np.isfinite(z) & np.isfinite(w) & (w > 0)
            if np.any(m):
                mval = float(np.nansum(z[m] * w[m]) / np.nansum(w[m]))
                ax.text(
                    0.02, 0.03, f"Land-frac mean: {mval:.3g} m",
                    transform=ax.transAxes, ha="left", va="bottom", fontsize=9,
                    bbox=dict(facecolor="white", edgecolor="none", alpha=0.8, pad=2.0),
                    zorder=3,
                )

    ax.set_title(title, fontsize=12)
    return artist

proj = ccrs.Robinson(central_longitude=0)
fig, axes = plt.subplots(2, 1, figsize=(14, 10.5), subplot_kw={"projection": proj}, constrained_layout=True)

a0 = _plot(axes[0], d_era5_ol, "Mean August SD Difference: ERA5 - OL (m)")
a1 = _plot(axes[1], d_era5l_ol, "Mean August SD Difference: ERA5-Land - OL (m)")

artist = a0 if a0 is not None else a1
if artist is not None:
    cb = fig.colorbar(artist, ax=axes, orientation="horizontal", fraction=0.04, pad=0.04)
    cb.set_label("Snow depth difference (m)")

plt.show()

# %%
# --- Scatter: Mean August Snow Depth Comparisons (OL vs ERA5, OL vs ERA5-Land) ---
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


def _arr_from_globals_scatter(raw_name, mapped_name):
    if raw_name in globals():
        return np.asarray(globals()[raw_name], dtype=float)
    if mapped_name in globals():
        v = globals()[mapped_name]
        return np.asarray(v.values if hasattr(v, "values") else v, dtype=float)
    raise RuntimeError(f"Missing both {raw_name} and {mapped_name}; run the August snow map cell first.")


def _weighted_stats(x, y, w):
    wsum = float(np.sum(w))
    xbar = float(np.sum(w * x) / wsum)
    ybar = float(np.sum(w * y) / wsum)
    cov = float(np.sum(w * (x - xbar) * (y - ybar)) / wsum)
    varx = float(np.sum(w * (x - xbar) ** 2) / wsum)
    vary = float(np.sum(w * (y - ybar) ** 2) / wsum)
    r = cov / np.sqrt(varx * vary) if (varx > 0 and vary > 0) else np.nan
    bias = float(np.sum(w * (y - x)) / wsum)
    rmse = float(np.sqrt(np.sum(w * (y - x) ** 2) / wsum))
    return r, bias, rmse


# Load comparison fields
z_ol = _arr_from_globals_scatter("mean_aug_ol_raw", "mean_aug_ol")
z_era5 = _arr_from_globals_scatter("mean_aug_era5_raw", "mean_aug_era5")
z_era5l = _arr_from_globals_scatter("mean_aug_era5l_raw", "mean_aug_era5l")

shape_ref = z_ol.shape
for nm, arr in [("OL", z_ol), ("ERA5", z_era5), ("ERA5-Land", z_era5l)]:
    if arr.shape != shape_ref:
        raise ValueError(f"Shape mismatch for {nm}: {arr.shape} vs {shape_ref}")

# Land-fraction weights
if "w_land_map" in globals():
    w = np.asarray(globals()["w_land_map"], dtype=float)
elif "w_land" in globals():
    _w = globals()["w_land"]
    w = np.asarray(_w.values if hasattr(_w, "values") else _w, dtype=float)
else:
    w = np.ones(shape_ref, dtype=float)
    print("Warning: no land-fraction weights found; using uniform weights.")

if w.shape != shape_ref:
    raise ValueError(f"Weight shape mismatch: {w.shape} vs {shape_ref}")

# Same map domain/mask
if "lat2d" not in globals() or "lon2d" not in globals():
    raise RuntimeError("lat2d/lon2d not found; run the August snow map cell first.")
lat = np.asarray(globals()["lat2d"], dtype=float)
lon = np.asarray(globals()["lon2d"], dtype=float)
if lat.shape != shape_ref or lon.shape != shape_ref:
    raise ValueError("lat/lon shape mismatch")

lon180 = ((lon + 180.0) % 360.0) - 180.0
greenland = (lat >= 58.0) & (lat <= 85.0) & (lon180 >= -75.0) & (lon180 <= -10.0)
domain = np.isfinite(lat) & np.isfinite(lon) & (lat >= -60.0) & (~greenland)
if "snow_mask_fixed" in globals():
    sm = globals()["snow_mask_fixed"]
    sm = np.asarray(sm.values if hasattr(sm, "values") else sm, dtype=float)
    if sm.shape == shape_ref:
        domain = domain & np.isfinite(sm) & (sm > 0.5)

w = np.where(domain & np.isfinite(w) & (w > 0), w, 0.0)

def _prep_pair(x2d, y2d):
    m = np.isfinite(x2d) & np.isfinite(y2d) & np.isfinite(w) & (w > 0)
    if not np.any(m):
        raise RuntimeError("No valid cells after mask/weights.")

    x_all = x2d[m]
    y_all = y2d[m]
    w_all = w[m]
    w_all = w_all / w_all.sum()

    is_zero = (x_all == 0.0) | (y_all == 0.0)
    zero_frac = float(np.sum(w_all[is_zero]))
    keep = ~is_zero
    if not np.any(keep):
        raise RuntimeError("All valid points are zero in at least one axis.")

    x = x_all[keep]
    y = y_all[keep]
    ww = w_all[keep]
    ww = ww / ww.sum()
    return x, y, ww, zero_frac, int(np.count_nonzero(keep))


x1, y1, ww1, zf1, n1 = _prep_pair(z_ol, z_era5)
x2, y2, ww2, zf2, n2 = _prep_pair(z_ol, z_era5l)

r1, b1, rmse1 = _weighted_stats(x1, y1, ww1)
r2, b2, rmse2 = _weighted_stats(x2, y2, ww2)

all_vals = np.concatenate([x1, y1, x2, y2])
vmax = float(np.nanquantile(all_vals, 0.995))
vmin = 0.0
if not np.isfinite(vmax) or vmax <= vmin:
    vmax = float(np.nanmax(all_vals))
if not np.isfinite(vmax) or vmax <= vmin:
    vmax = 1.0

fig, axes = plt.subplots(1, 2, figsize=(14, 6), sharex=True, sharey=True, constrained_layout=True)

s1 = 8 + 1200 * ww1
axes[0].scatter(x1, y1, s=s1, alpha=0.35, color="#1f77b4", edgecolors="none", rasterized=True,
                label=f"nonzero points (zero excl={zf1:.1%})")
axes[0].plot([vmin, vmax], [vmin, vmax], "k--", lw=1.2, label="1:1")
axes[0].set_title("OL vs ERA5 (Mean August SD)")
axes[0].set_xlabel("OL snow depth (m)")
axes[0].set_ylabel("ERA5 snow depth (m)")
axes[0].grid(True, alpha=0.3, linestyle="--")
axes[0].legend(loc="upper left")
axes[0].text(0.03, 0.03, f"R={r1:.3f}\nBias={b1:.3g} m\nRMSE={rmse1:.3g} m\nn={n1:,}",
             transform=axes[0].transAxes, ha="left", va="bottom",
             bbox=dict(facecolor="white", edgecolor="none", alpha=0.8, pad=2.0), fontsize=9)

s2 = 8 + 1200 * ww2
axes[1].scatter(x2, y2, s=s2, alpha=0.35, color="#2ca02c", edgecolors="none", rasterized=True,
                label=f"nonzero points (zero excl={zf2:.1%})")
axes[1].plot([vmin, vmax], [vmin, vmax], "k--", lw=1.2, label="1:1")
axes[1].set_title("OL vs ERA5-Land (Mean August SD)")
axes[1].set_xlabel("OL snow depth (m)")
axes[1].grid(True, alpha=0.3, linestyle="--")
axes[1].legend(loc="upper left")
axes[1].text(0.03, 0.03, f"R={r2:.3f}\nBias={b2:.3g} m\nRMSE={rmse2:.3g} m\nn={n2:,}",
             transform=axes[1].transAxes, ha="left", va="bottom",
             bbox=dict(facecolor="white", edgecolor="none", alpha=0.8, pad=2.0), fontsize=9)

axes[0].set_xlim(vmin, vmax)
axes[0].set_ylim(vmin, vmax)
plt.show()

summary = pd.DataFrame([
    {"case": "OL vs ERA5", "weighted_zero_excluded": zf1, "R": r1, "bias_m": b1, "rmse_m": rmse1, "n_nonzero": n1},
    {"case": "OL vs ERA5-Land", "weighted_zero_excluded": zf2, "R": r2, "bias_m": b2, "rmse_m": rmse2, "n_nonzero": n2},
]).set_index("case")
display(summary.style.format({"weighted_zero_excluded": "{:.2%}", "R": "{:.3f}", "bias_m": "{:.4f}", "rmse_m": "{:.4f}"}))
